# %% [markdown]
# # Testando Cliente do GROBID:

# %%
import pandas as pd

# %%
import numpy as np

# %%
import os
import sys
import re

# %%
from rollet import grobid_service, get_content
from rollet.extractor import PDFExtractor

# %% [markdown]
# !pip install pdfToJson

# %% [markdown]
# !python -m pip install rollet

# %% [markdown]
# !pip install pygrobid

# %% [markdown]
# !pip install grobid-client

# %%
host = 'http://localhost'
port = 8070

url = "http://localhost:8070/"

grobid_service(host, port)

path = os.path.dirname(os.getcwd())
path_article = os.path.join(path,'artifacts','test_article','b000689k.pdf')
url = path_article

content_dict = get_content(url)

pdf_content_object = PDFExtractor(url)
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# <ipython-input-12-94f96a1a95a8> in <module>
#      12 content_dict = get_content(url)
#      13
# ---> 14 pdf_content_object = PDFExtractor(url)
#
# ~\anaconda3\lib\site-packages\rollet\extractor.py in __init__(self, url, **kwargs)
#     268         self.domain = extract(url).domain
#     269         self.date = datetime.now().strftime("%m/%d/%Y, %H:%M:%S")
# --> 270         self._scrap(**kwargs)
#     271
#     272     def _scrap(self, **kwargs):
#
# ~\anaconda3\lib\site-packages\rollet\extractor.py in _scrap(self, **kwargs)
#     280
#     281         if not hasattr(self, '_response'):
# --> 282             with get(self.url, timeout = timeout, headers = headers, verify = False) as response:
#     283                 response = response
#     284         else:
#
# ...

# %%
type(rsp)
# Out:
# tuple

# %%
dir(rsp)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']
