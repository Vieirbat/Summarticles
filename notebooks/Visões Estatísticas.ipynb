# %% [markdown]
# # Features de TextMining:

# %% [markdown]
# ---------------------------------

# %%
import os
import sys
import re
import datetime
import dateutil

sys.path.insert(0,os.path.dirname(os.getcwd()))
sys.path.insert(0,os.path.join(os.getcwd(),'grobid'))
sys.path.insert(0,os.getcwd())

import numpy as np
import pandas as pd

from grobid import grobid_client
import grobid_tei_xml
from grobid_to_dataframe import grobid_cli, xmltei_to_dataframe

import plotly

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

from pyvis.network import Network
import nltk

import random

# %% [markdown]
# !pip install markupsafe==2.0.1

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ### Comandos Docker

# %% [markdown]
# docker run -t --rm --init -p 8080:8070 -p 8081:8071 --memory="9g" lfoppiano/grobid:0.7.0
#
# docker run -t --rm --init -p 8080:8070 -p 8081:8071 lfoppiano/grobid:0.6.2

# %% [markdown]
# ### Definindo variáveis e caminhos

# %%
path = os.path.dirname(os.getcwd())
path_input = os.path.join(path,'artifacts','articles','ml_material','teste')

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ### Funções para execução em batch

# %%
def get_path(path_input_path):
    """"""
    if os.path.exists(path_input_path):
        return path_input_path
    
    return os.getcwd()


def batch_process_path(path_input_path, n_workers=2,
                       check_cache=True,
                       cache_folder_name='summarticles_cache',
                       config_path="./grobid/config.json"):
    
    """"""
    
    gcli = grobid_cli(config_path=config_path)
    result_batch = gcli.process_pdfs(input_path=path_input_path,
                                     check_cache=check_cache,
                                     cache_folder_name=cache_folder_name,
                                     n_workers=n_workers,
                                     service="processFulltextDocument",
                                     generateIDs=True,
                                     include_raw_citations=True,
                                     include_raw_affiliations=True,
                                     consolidate_header=False,
                                     consolidate_citations=False,
                                     tei_coordinates=False,
                                     segment_sentences=True,
                                     verbose=True)
    return result_batch


def get_dataframes(result_batch):
    
    """"""
    
    xml_to_df = xmltei_to_dataframe()
    dict_dfs, dic_errors = xml_to_df.get_dataframe_articles(result_batch)
    
    return dict_dfs, dic_errors


def files_path(path):
    list_dir = os.listdir(path)
    files = []
    for file in list_dir:
        if os.path.isfile(os.path.join(path,file)):
            files.append(os.path.join(path,file))
    return files

# %%
def run_batch_process(path_input, n_workers=6, check_cache=True, 
                      cache_folder_name='summarticles_cache', 
                      config_path="./grobid/config.json"):

    dict_exec = {'path':path_input}
    dict_exec['start_datetime'] = datetime.datetime.now()
    
    # path_input = os.path.join(path,'artifacts','test_article')
    config_path = os.path.join(os.getcwd(),'grobid','config.json')
    dict_exec['grobid_config'] = config_path
    
    gcli = grobid_client.GrobidClient(config_path=config_path, check_server=False)
    
    dict_exec['files'] = gcli.get_input_files(path_input)
    dict_exec['num_files'] = len(dict_exec['files'])
    dict_exec['n_workers'] = n_workers
    
    path_input_path = get_path(path_input)
    result_batch = batch_process_path(path_input_path, n_workers=dict_exec['n_workers'], check_cache=check_cache)
    dict_dfs, dic_errors = get_dataframes(result_batch)
    
    gcli.save_xmltei_files(result_batch, input_folder_path, cache_folder_name=cache_folder_name)
    
    dict_exec['end_datetime'] = datetime.datetime.now()
    dict_exec['time_exec_sec'] = (dict_exec['end_datetime']-dict_exec['start_datetime']).seconds
    dict_exec['time_exec_min'] = (dict_exec['end_datetime']-dict_exec['start_datetime']).seconds
    
    return dict_dfs, dict_exec, dic_errors

# %%
input_folder_path = r"""C:\Users\vierb\OneDrive\Área de Trabalho\Projetos\PGC\artifacts\articles\ml_material"""

# %%
# %%time
dict_dfs, dict_exec, dic_errors = run_batch_process(path_input=input_folder_path, 
                                                    n_workers=10, 
                                                    check_cache=True, 
                                                    cache_folder_name='summarticles_cache', 
                                                    config_path="./grobid/config.json")
# Out:
# GROBID server is up and running
# 587 files to process in current batch
# [Input Files] 587
# [Cache Files] 587
# In the end, we have: 0  new files to process!
# And we have : 587  files to back from cache!
# Processed articles: 581
# Number articles with errors: 6
# Wall time: 22.7 s

# %% [markdown]
# ---------------------------------

# %%
def getColumnsWithData(df, return_percent=False, n_round=2):
    
    """"""
    
    list_col_with_data = []
    for col in df.columns.tolist():
        rows = df[col].shape
        n_null = df[col].isnull().sum()
        not_null_data_perc = (1-n_null/rows)
        if not_null_data_perc:
            if return_percent:
                list_col_with_data.append((col,np.round(not_null_data_perc, n_round)))
            list_col_with_data.append(col)
            
    return list_col_with_data

# %%
dict_dfs.keys()
# Out:
# dict_keys(['df_doc_info', 'df_doc_head', 'df_doc_authors', 'df_doc_citations', 'df_doc_authors_citations'])

# %% [markdown]
# ### df_doc_info

# %%
100*(1-dict_dfs['df_doc_info'].isnull().sum()/dict_dfs['df_doc_info'].shape[0])
# Out:
# grobid_version      100.000000
# grobid_timestamp    100.000000
# pdf_md5             100.000000
# language_code       100.000000
# acknowledgement      78.313253
# abstract             97.074010
# body                100.000000
# annex                 0.000000
# file                100.000000
# status              100.000000
# raw_data            100.000000
# dtype: float64

# %%
df_doc_info = dict_dfs['df_doc_info'].loc[:,getColumnsWithData(dict_dfs['df_doc_info'])]

# %%
df_doc_info.head()
# Out:
#            grobid_version     grobid_timestamp  \
# article_id
# 1                   0.7.0  2022-05-15 02:10:00
# 2                   0.7.0  2022-05-15 02:11:00
# 3                   0.7.0  2022-05-15 02:11:00
# 4                   0.7.0  2022-05-15 02:08:00
# 5                   0.7.0  2022-05-15 02:09:00
#
#                                      pdf_md5 language_code  \
# article_id
# 1           8CE1384F014ADABF75594B977F2B5154            en
# 2           B8DEC8FF69E08FA8AE4BEE05EF959D6D            en
# 3           C8EDEEF53CAB54302B982065F0C04DC1            en
# 4           FB4B6762020302D85B1E2D4CB7DFC9CB            en
# 5           BBC020E57598118028F4953E38BCED09            en
#
#                                               acknowledgement  \
# article_id
# 1           Acknowledgement This work is supported by the ...
# 2                                            Acknowledgements
# 3           Acknowledgements The authors would like to tha...
# 4                                             Acknowledgments
# 5                                                         NaN
#
#                                                      abstract  \
# article_id
# 1           With the development of industrialization and ...
# 2                                                         NaN
# 3           This is a PDF file of an article that has unde...
# 4           The responses of the ultrasound-mediated disru...
# 5                                                         NaN
#
#                                                          body  \
# article_id
# 1           Introdution The modern nondestructive testing ...
# 2           Estimating the phase volume fraction of multi-...
# 3           Introduction: Conventional alloys such as Comm...
# 4           Introduction Arginine deiminase (ADI; E.C.  3....
# 5           a b s t r a c t Desired material synthesis and...
#
#                                                          file      status  \
# article_id
# 1           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 2           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 3           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 4           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 5           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
#
#                                                      raw_data
# article_id
# 1           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# 2           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# 3           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# 4           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# 5           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...

# %% [markdown]
# ### df_doc_head

# %%
100*(1-dict_dfs['df_doc_head'].isnull().sum()/dict_dfs['df_doc_head'].shape[0])
# Out:
# index_head              0.000000
# id_head                 0.000000
# unstructured_head       0.000000
# date_head              46.299484
# title_head             98.278830
# book_title_head         0.000000
# series_title_head       0.000000
# journal_head            0.000000
# journal_abbrev_head     0.000000
# publisher_head          0.000000
# institution_head        0.000000
# issn_head               0.688468
# eissn_head              0.000000
# volume_head             0.000000
# issue_head              0.000000
# pages_head              0.000000
# first_page_head         0.000000
# last_page_head          0.000000
# note_head               0.000000
# doi_head               97.418244
# pmid_head               0.000000
# pmcid_head              0.000000
# arxiv_id_head           0.172117
# ark_head                0.000000
# istex_id_head           0.000000
# url_head                0.000000
# dtype: float64

# %%
dict_dfs['df_doc_head'].dtypes
# Out:
# index_head             float64
# id_head                float64
# unstructured_head      float64
# date_head               object
# title_head              object
# book_title_head        float64
# series_title_head      float64
# journal_head           float64
# journal_abbrev_head    float64
# publisher_head         float64
# institution_head       float64
# issn_head               object
# eissn_head             float64
# volume_head            float64
# issue_head             float64
# pages_head             float64
# first_page_head        float64
# last_page_head         float64
# note_head              float64
# doi_head                object
# pmid_head              float64
# pmcid_head             float64
# arxiv_id_head           object
# ark_head               float64
# istex_id_head          float64
# url_head               float64
# dtype: object

# %%
df_doc_head = dict_dfs['df_doc_head'].loc[:,getColumnsWithData(dict_dfs['df_doc_head'])]

# %%
df_doc_head
# Out:
#              date_head                                         title_head  \
# article_id
# 1                  NaN  Laser ultrasonic quantitative recognition base...
# 2                  NaN                                                NaN
# 3                  NaN  Journal Pre-proof Artificial neural network ap...
# 4                  NaN  Ultrasonic disruption of Pseudomonas putida fo...
# 5                  NaN  Material synthesis and design from first princ...
# ...                ...                                                ...
# 583         2017-04-06  Functional regression-based fluid permeability...
# 584         2019-12-18  Utilization of Artificial Neural Network to ex...
# 585         2021-08-21  Automating Crystal-Structure Phase Mapping: Co...
# 586         2012-12-13  Microstructural prediction through artificial ...
# 587                NaN  Crowd-sourcing materials-science challenges wi...
#
#            issn_head                         doi_head        arxiv_id_head
# article_id
# 1                NaN      10.1016/j.ijleo.2017.08.105                  NaN
# 2                NaN       10.1038/s41598-021-85407-y                  NaN
# 3                NaN       10.1016/j.msea.2020.140059                  NaN
# 4                NaN   10.1016/j.biortech.2017.02.074                  NaN
# 5                NaN  10.1016/j.commatsci.2015.11.013                  NaN
# ...              ...                              ...                  ...
# 583              NaN  10.1016/j.commatsci.2017.03.042                  NaN
# 584              NaN    10.1016/j.jnucmat.2019.151957                  NaN
# 585              NaN                              NaN  2108.09523v1[cs.LG]
# 586              NaN       10.1016/j.msea.2012.11.110                  NaN
# 587              NaN        10.1038/s41524-019-0239-3                  NaN
#
# [581 rows x 5 columns]

# %%
df_doc_info_head = df_doc_info.join(df_doc_head, how='left')

# %%
df_doc_info_head.head(5)
# Out:
#            grobid_version     grobid_timestamp  \
# article_id
# 1                   0.7.0  2022-05-15 02:10:00
# 2                   0.7.0  2022-05-15 02:11:00
# 3                   0.7.0  2022-05-15 02:11:00
# 4                   0.7.0  2022-05-15 02:08:00
# 5                   0.7.0  2022-05-15 02:09:00
#
#                                      pdf_md5 language_code  \
# article_id
# 1           8CE1384F014ADABF75594B977F2B5154            en
# 2           B8DEC8FF69E08FA8AE4BEE05EF959D6D            en
# 3           C8EDEEF53CAB54302B982065F0C04DC1            en
# 4           FB4B6762020302D85B1E2D4CB7DFC9CB            en
# 5           BBC020E57598118028F4953E38BCED09            en
#
#                                               acknowledgement  \
# article_id
# 1           Acknowledgement This work is supported by the ...
# 2                                            Acknowledgements
# 3           Acknowledgements The authors would like to tha...
# 4                                             Acknowledgments
# 5                                                         NaN
#
#                                                      abstract  \
# article_id
# 1           With the development of industrialization and ...
# 2                                                         NaN
# 3           This is a PDF file of an article that has unde...
# 4           The responses of the ultrasound-mediated disru...
# 5                                                         NaN
#
#                                                          body  \
# article_id
# 1           Introdution The modern nondestructive testing ...
# 2           Estimating the phase volume fraction of multi-...
# 3           Introduction: Conventional alloys such as Comm...
# 4           Introduction Arginine deiminase (ADI; E.C.  3....
# 5           a b s t r a c t Desired material synthesis and...
#
#                                                          file      status  \
# article_id
# 1           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 2           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 3           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 4           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 5           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
#
#                                                      raw_data date_head  \
# article_id
# 1           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...       NaN
# 2           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...       NaN
# 3           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...       NaN
# 4           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...       NaN
# 5           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...       NaN
#
#                                                    title_head issn_head  \
# article_id
# 1           Laser ultrasonic quantitative recognition base...       NaN
# 2                                                         NaN       NaN
# 3           Journal Pre-proof Artificial neural network ap...       NaN
# 4           Ultrasonic disruption of Pseudomonas putida fo...       NaN
# 5           Material synthesis and design from first princ...       NaN
#
#                                    doi_head arxiv_id_head
# article_id
# 1               10.1016/j.ijleo.2017.08.105           NaN
# 2                10.1038/s41598-021-85407-y           NaN
# 3                10.1016/j.msea.2020.140059           NaN
# 4            10.1016/j.biortech.2017.02.074           NaN
# 5           10.1016/j.commatsci.2015.11.013           NaN

# %%
df_doc_info_head.date_head = df_doc_info_head.date_head.apply(lambda e: pd.to_datetime(e))

# %%
df_doc_info_head['year'] = df_doc_info_head.date_head.apply(lambda e: e if pd.isna(e) else int(e.year))

# %%
df_doc_info_head.date_head.value_counts(dropna=False)
# Out:
# NaT           312
# 2021-08-02      4
# 2021-03-10      3
# 2021-03-02      3
# 2021-04-23      3
#              ...
# 2021-01-22      1
# 2020-09-30      1
# 2017-09-14      1
# 2021-08-29      1
# 2012-12-13      1
# Name: date_head, Length: 240, dtype: int64

# %%
df_doc_info_head.year.value_counts(dropna=False).to_dict()
# Out:
# {NaT: 312,
#  2021: 109,
#  2020: 45,
#  2019: 25,
#  2011: 13,
#  2012: 12,
#  2008: 11,
#  2010: 10,
#  2009: 9,
#  2015: 8,
#  2018: 7,
#  2013: 5,
#  2017: 5,
#  2016: 4,
#  2014: 2,
#  2005: 1,
#  2007: 1,
#  2006: 1,
#  2000: 1}

# %%
pd.DataFrame(df_doc_info_head.year.value_counts(dropna=False).to_dict(), columns=['year','count'])
# Out:
# Empty DataFrame
# Columns: [year, count]
# Index: []

# %%
import plotly.express as px

df_doc_info_head.year = df_doc_info_head.year.fillna('Null Value')

fig = px.pie(df_doc_info_head, 
             values='year', 
             names='year',
             title='Number of Articles by Year',
             hover_data=['year'], 
             labels={'values':'Percentage','year':'Year of Article'}, hole=.5)

fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(showlegend=False)
fig.show()

# %% [markdown]
# ### df_doc_authors

# %%
100*(1-dict_dfs['df_doc_authors'].isnull().sum()/dict_dfs['df_doc_authors'].shape[0])
# Out:
# full_name_author      99.701715
# given_name_author     98.322148
# middle_name_author    24.086503
# surname_author        99.701715
# email_author          21.439224
# orcid_author           3.094705
# institution_author    82.662192
# department_author     72.073080
# laboratory_author     13.534676
# addr_line_author      20.208799
# post_code_author      66.853095
# settlement_author     78.225205
# country_author        85.160328
# dtype: float64

# %%
df_doc_authors = dict_dfs['df_doc_authors'].loc[:,getColumnsWithData(dict_dfs['df_doc_authors'])]

# %%
df_doc_authors.head()
# Out:
#            full_name_author given_name_author middle_name_author  \
# article_id
# 1                  Qiuji Yi             Qiuji                NaN
# 1               Haitao Wang            Haitao                NaN
# 1               Ruipeng Guo           Ruipeng                NaN
# 1                 Suyuan Li            Suyuan                NaN
# 1                  Yi Jiang                Yi                NaN
#
#            surname_author email_author orcid_author institution_author  \
# article_id
# 1                      Yi          NaN          NaN                NaN
# 1                    Wang          NaN          NaN                NaN
# 1                     Guo          NaN          NaN                NaN
# 1                      Li          NaN          NaN                NaN
# 1                   Jiang          NaN          NaN                NaN
#
#            department_author laboratory_author addr_line_author  \
# article_id
# 1                        NaN               NaN              NaN
# 1                        NaN               NaN              NaN
# 1                        NaN               NaN              NaN
# 1                        NaN               NaN              NaN
# 1                        NaN               NaN              NaN
#
#            post_code_author settlement_author country_author
# article_id
# 1                       NaN               NaN            NaN
# 1                       NaN               NaN            NaN
# 1                       NaN               NaN            NaN
# 1                       NaN               NaN            NaN
# 1                       NaN               NaN            NaN

# %%
columns_select = ['country_author','settlement_author']
df_sun_agg = df_doc_authors.groupby(by=columns_select, as_index=False, dropna=True)['full_name_author'].count()

# %%
df_sun_agg = df_sun_agg.fillna("")
df_sun_agg.rename(columns={'country_author':'Author Country',
                           'settlement_author':'Author Settlement',
                           'full_name_author':'Number of Authors'},
                  inplace=True)

# %%
df_sun_agg.head()
# Out:
#   Author Country Author Settlement  Number of Authors
# 0        Algeria           Tlemcen                  2
# 1      Argentina      Bahía Blanca                  4
# 2      Argentina      Buenos Aires                  5
# 3      Argentina          La Plata                  1
# 4      Argentina             Salta                  1

# %%
import plotly.express as px
fig = px.sunburst(df_sun_agg, 
                  path=['Author Country',
                        'Author Settlement'],
                  values='Number of Authors')
fig.show()
# Out:
# c:\Users\vierb\anaconda3\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\vierb\anaconda3\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
df_doc_authors.full_name_author.value_counts(dropna=False)
# Out:
# A R T I C L E I N F O    10
# Acta Materialia           8
# NaN                       8
# Yu Sun                    6
# N S Reddy                 6
#                          ..
# Hui Yan                   1
# Surya Prakash Mishra      1
# Prof G Zhang              1
# Prof H Snoussi            1
# Xiangyue Liu              1
# Name: full_name_author, Length: 2324, dtype: int64

# %%
list_delete_authors = ['A R T I C L E I N F O', np.nan, 'Null', 'NaN','nan', 'null', '', ' ']
filter_delete_authors = ~(df_doc_authors.full_name_author.isin(list_delete_authors))
df_doc_authors = df_doc_authors.loc[filter_delete_authors].copy()

# %%
top_authors = df_doc_authors.full_name_author.value_counts()
df_top_authors = pd.DataFrame({'Full Name':top_authors.index,
                               'Number of Articles':top_authors.values.tolist()})

df_top_authors
# Out:
#                  Full Name  Number of Articles
# 0          Acta Materialia                   8
# 1                N S Reddy                   6
# 2              Dane Morgan                   6
# 3                   Yu Sun                   6
# 4             Weidong Zeng                   6
# ...                    ...                 ...
# 2317               Hui Yan                   1
# 2318  Surya Prakash Mishra                   1
# 2319          Prof G Zhang                   1
# 2320        Prof H Snoussi                   1
# 2321          Xiangyue Liu                   1
#
# [2322 rows x 2 columns]

# %%
import plotly.express as px

top_authors = df_top_authors.nlargest(20,'Number of Articles')
top_authors = top_authors.sort_values('Number of Articles',ascending=True)
fig = px.bar(top_authors,
             y='Full Name',
             x='Number of Articles',
             color='Number of Articles',
             width=600,
             height=700,text='Number of Articles')
fig.update(layout_coloraxis_showscale=False)
# fig.update_traces(showlegend=False)
# fig.update_traces(marker_showscale=False)
fig.update_xaxes(visible=False)
fig.update_layout(yaxis_title=None, xaxis_title=None)
fig.show()

# %% [markdown]
# ### df_doc_authors_citations

# %%
100*(1-dict_dfs['df_doc_authors_citations'].isnull().sum()/dict_dfs['df_doc_authors_citations'].shape[0])
# Out:
# id                      100.000000
# index                   100.000000
# full_name_citation       99.371668
# given_name_citation      98.339759
# middle_name_citation     30.893282
# surname_citation         98.659667
# email_citation            0.000000
# orcid_citation            0.000000
# institution_citation      0.000000
# department_citation       0.000000
# laboratory_citation       0.000000
# addr_line_citation        0.000000
# post_code_citation        0.000000
# settlement_citation       0.000000
# country_citation          0.000000
# dtype: float64

# %%
df_doc_authors_citations = dict_dfs['df_doc_authors_citations'].loc[:,getColumnsWithData(dict_dfs['df_doc_authors_citations'])]

# %%
path_geo = os.path.join(path,'data','external')
country_latlong = pd.read_csv(os.path.join(path_geo,'countries_lat_long.csv'), sep=';', decimal='.')
shapes_correct = pd.read_csv(os.path.join(path_geo,'shapes_correct.csv'), encoding='latin-1',sep=';', decimal='.')


df_country_agg = df_doc_authors.groupby(by=['country_author'], as_index=False, dropna=True)['full_name_author'].count()
dictCorrectShapes = {e[0]:e[1] for e in zip(shapes_correct.convert, shapes_correct.name)}
df_country_agg.country_author = df_country_agg.country_author.apply(lambda e: dictCorrectShapes.get(e,e))
df_country_agg = df_country_agg.groupby(by=['country_author'], as_index=False)['full_name_author'].sum()
df_country_agg = df_country_agg.rename(columns={'country_author':'Country',
                                                'full_name_author':'count'})

# %%
df_country_agg = df_country_agg.merge(country_latlong, how='left', on=['Country'])
df_country_agg = df_country_agg.dropna()

# %%
m = folium.Map(location=[-15.7601, -47.8800], zoom_start=14)

# %%
import folium

# %%
folium.

# %%
df_country_agg.head()
# Out:
#       Country  count ISO 3166 Country Code  Latitude  Longitude
# 0     Algeria      6                    DZ     28.00       3.00
# 1   Argentina     14                    AR    -34.00     -64.00
# 2   Australia     47                    AU    -27.00     133.00
# 3     Austria     14                    AT     47.33      13.33
# 4  Bangladesh      3                    BD     24.00      90.00

# %%
row['Latitude']
# Out:
# 28.0

# %%
from folium.plugins import HeatMap

# %%
HeatMap()

# %%
map = folium.Map(location=[25.552354,14.814465], zoom_start=1.5)

heat_points = []
for i,row in df_country_agg.iterrows():
    heat_points.append([row['Latitude'], row['Longitude'], row['count']])
    folium.Marker([row['Latitude'], row['Longitude']],
                  popup="<i>Number of Authors {0}<i>".format(row['count']),
                  tooltip=f"Number of Authors {row['count']}").add_to(map)
    
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b1eef4a7d5b4274d40534c9c25a4d92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b1eef4a7d5b4274d40534c9c25a4d92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7b1eef4a7d5b4274d40534c9c25a4d92 = L.map(
#                 &quot;map_7b1eef4a7d5b4274d40534c9c25a4d92&quot;,
#                 {
#                     center: [25.552354, 14.814465],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46794ff633e76182123481401e8947a8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7b1eef4a7d5b4274d40534c9c25a4d92);
#
#
#             var marker_244ecb2b3d49e8c50851d1f6ab9c09e4 = L.marker(
#                 [28.0, 3.0],
#                 {}
#             ).addTo(map_7b1eef4a7d5b4274d40534c9c25a4d92);
#
#
#         var popup_5cee4c068a1f8469d6a903c7bc524481 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_ecfd7e8a7b5c498ace97d4d20082f0fc = $(`&lt;div id=&quot;html_ecfd7e8a7b5c498ace97d4d20082f0fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Number of Authors 6&lt;i&gt;&lt;/div&gt;`)[0];
#             popup_5cee4c068a1f8469d6a903c7bc524481.setContent(html_ecfd7e8a7b5c498ace97d4d20082f0fc);
#
#
#         marker_244ecb2b3d49e8c50851d1f6ab9c09e4.bindPopup(popup_5cee4c068a1f8469d6a903c7bc524481)
#         ;
#
#
#
#
#             marker_244ecb2b3d49e8c50851d1f6ab9c09e4.bindTooltip(
#                 `&lt;div&gt;
#                      Number of Authors 6
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4d047e1696a43eebea1d0ef7d6aebf5a = L.marker(
#                 [-34.0, -64.0],
#                 {}
#             ).addTo(map_7b1eef4a7d5b4274d40534c9c25a4d92);
#
#
#         var popup_dffb4b50a785650237845d5aad8f0eb3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7b65ca3984bde38690137908b206cbc6 = $(`&lt;div id=&quot;html_7b65ca3984bde38690137908b206cbc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Number of Authors 14&lt;i&gt;&lt;/div&gt;`)[0];
#             popup_dffb4b50a785650237845d5aad8f0eb3.setContent(html_7b65ca3984bde38690137908b206cbc6);
#
#
#         marker_4d047e1696a43eebea1d0ef7d6aebf5a.bindPopup(popup_dffb4b50a785650237845d5aad8f0eb3)
#         ;
#
#
#
#
#             marker_4d047e1696a43eebea1d0ef7d6aebf5a.bindTooltip(
#                 `&lt;div&gt;
#                      Number of Authors 14
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_517f3cd0c2cb5d1a77543101c9f643b8 = L.marker(
#                 [-27.0, 133.0],
#                 {}
#             ).addTo(map_7b1eef4a7d5b4274d40534c9c25a4d92);
#
#
#         var popup_2304d9bdd56641cf503365cc9248cb1d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b0654c6a183b8b027d7fb9049843b1a6 = $(`&lt;div id=&quot;html_b0654c6a183b8b027d7fb9049843b1a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Number of Authors 47&lt;i&gt;&lt;/div&gt;`)[0];
#             popup_2304d9bdd56641cf503365cc9248cb1d.setContent(html_b0654c6a183b8b027d7fb9049843b1a6);
#
#
#         marker_517f3cd0c2cb5d1a77543101c9f643b8.bindPopup(popup_2304d9bdd56641cf503365cc9248cb1d)
#         ;
#
#
#
#
#             marker_517f3cd0c2cb5d1a77543101c9f643b8.bindTooltip(
#                 `&lt;div&gt;
#                      Number of Authors 47
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_72d5976377861686469af089a853d5db = L.marker(
#                 [47.33, 13.33],
#                 {}
#             ).addTo(map_7b1eef4a7d5b4274d40534c9c25a4d92);
#
#
#         var popup_aa8754575010885ab1da2e22ed28ab77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e69fcd1555695abfe5806b441df5d14d = $(`&lt;div id=&quot;html_e69fcd1555695abfe5806b441df5d14d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;Number of Authors 14&lt;i&gt;&lt;/div&gt;`)[0];
#             popup_aa8754575010885ab1da2e22ed28ab77.setContent(html_e69fcd1555695abfe5806b441df5d14d);
#
#
#         marker_72d5976377861686469af089a853d5db.bindPopup(popup_aa8754575010885ab1da2e22ed28ab77)
#         ;
#
#
#
#
#             marker_72d5976377861686469af089a853d5db.bindTooltip(
#                 `&lt;div&gt;
#                      Number of Authors 14
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ae86238afd0d93d24ce62c4200728c1e = L.marker(
#                 [24.0, 90.0],
#                 {}
#             ).addTo(map_7b1eef4a7d5b4274d40534c9c

# %%
map = folium.Map(location=[25.552354,14.814465], zoom_start=2)
HeatMap(heat_points, radius=40, blur=20).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e95eaa13643a05f5d4c0504f35b86480 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@master/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e95eaa13643a05f5d4c0504f35b86480&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e95eaa13643a05f5d4c0504f35b86480 = L.map(
#                 &quot;map_e95eaa13643a05f5d4c0504f35b86480&quot;,
#                 {
#                     center: [25.552354, 14.814465],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e9d056c6b5b7056a9da07d14d3a0c00 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e95eaa13643a05f5d4c0504f35b86480);
#
#
#             var heat_map_706250973aaba70ca5608fb44cd68c8b = L.heatLayer(
#                 [[28.0, 3.0, 6], [-34.0, -64.0, 14], [-27.0, 133.0, 47], [47.33, 13.33, 14], [24.0, 90.0, 3], [50.83, 4.0, 21], [-10.0, -55.0, 15], [60.0, -95.0, 30], [35.0, 105.0, 645], [4.0, -72.0, 2], [49.75, 15.5, 1], [56.0, 10.0, 1], [59.0, 26.0, 1], [64.0, 26.0, 15], [46.0, 2.0, 39], [42.0, 43.5, 3], [51.0, 9.0, 83], [39.0, 22.0, 5], [47.0, 20.0, 3], [20.0, 77.0, 144], [32.0, 53.0, 72], [53.0, -8.0, 1], [31.5, 34.75, 3], [42.83, 12.83, 14], [36.0, 138.0, 68], [31.0, 36.0, 3], [1.0, 38.0, 4], [2.5, 112.5, 4], [23.0, -102.0, 18], [32.0, -5.0, 3], [52.5, 5.75, 6], [-41.0, 174.0, 1], [10.0, 8.0, 4], [37.0, 127.5, 61], [62.0, 10.0, 3], [21.0, 57.0, 1], [30.0, 70.0, 12], [52.0, 20.0, 8], [39.5, -8.0, 1], [25.5, 51.25, 5], [46.0, 25.0, 3], [60.0, 100.0, 34], [25.0, 45.0, 3], [1.37, 103.8, 26], [46.0, 15.0, 3], [40.0, 127.0, 23], [40.0, -4.0, 5], [62.0, 15.0, 22], [47.0, 8.0, 7], [23.5, 121.0, 14], [39.0, 35.0, 4], [54.0, -2.0, 77], [38.0, -97.0, 666], [16.0, 106.0, 2]],
#                 {&quot;blur&quot;: 20, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 40}
#             ).addTo(map_e95eaa13643a05f5d4c0504f35b86480);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_country_agg
# Out:
#                      Country  count ISO 3166 Country Code  Latitude  Longitude
# 0                    Algeria      6                    DZ     28.00       3.00
# 1                  Argentina     14                    AR    -34.00     -64.00
# 2                  Australia     47                    AU    -27.00     133.00
# 3                    Austria     14                    AT     47.33      13.33
# 4                 Bangladesh      3                    BD     24.00      90.00
# 5                    Belgium     21                    BE     50.83       4.00
# 6                     Brazil     15                    BR    -10.00     -55.00
# 7                     Canada     30                    CA     60.00     -95.00
# 8                      China    645                    CN     35.00     105.00
# 9                   Colombia      2                    CO      4.00     -72.00
# 10            Czech Republic      1                    CZ     49.75      15.50
# 11                   Denmark      1                    DK     56.00      10.00
# 12                   Estonia      1                    EE     59.00      26.00
# 13                   Finland     15                    FI     64.00      26.00
# 14                    France     39                    FR     46.00       2.00
# 15                   Georgia      3                    GE     42.00      43.50
# 16                   Germany     83                    DE     51.00       9.00
# 17                    Greece      5                    GR     39.00      22.00
# 18                   Hungary      3                    HU     47.00      20.00
# 19                     India    144                    IN     20.00      77.00
# 20                      Iran     72                    IR     32.00      53.00
# 21                   Ireland      1                    IE     53.00      -8.00
# 22                    Israel      3                    IL     31.50      34.75
# 23                     Italy     14                    IT     42.83      12.83
# 24                     Japan     68                    JP     36.00     138.00
# 25                    Jordan      3                    JO     31.00      36.00
# 26                     Kenya      4                    KE      1.00      38.00
# 27                  Malaysia      4                    MY      2.50     112.50
# 28                    Mexico     18                    MX     23.00    -102.00
# 29                   Morocco      3                    MA     32.00      -5.00
# 30               Netherlands      6                    NL     52.50       5.75
# 31               New Zealand      1                    NZ    -41.00     174.00
# 32                   Nigeria      4                    NG     10.00       8.00
# 33               North Korea     61                    KR     37.00     127.50
# 34                    Norway      3                    NO     62.00      10.00
# 35                      Oman      1                    OM     21.00      57.00
# 36                  Pakistan     12                    PK     30.00      70.00
# 38                    Poland      8                    PL     52.00      20.00
# 39                  Portugal      1                    PT     39.50      -8.00
# 40                     Qatar      5                    QA     25.50      51.25
# 41                   Romania      3                    RO     46.00      25.00
# 42                    Russia     34                    RU     60.00     100.00
# 43              Saudi Arabia      3                    SA     25.00      45.00
# 44                 Singapore     26                    SG      1.37     103.80
# 45                  Slovenia      3                    SI     46.00      15.00
# 46               South Korea     23                    KP     40.00     127.00
# 47                     Spain      5                    ES     40.00      -4.00
# 48                    Sweden     22                    SE     62.00      15.00
# 49               Switzerland      7                    CH     47.00       8.00
# 50                    Taiwan     14                    TW     23.50     121.00
# 51                    Turkey      4                    TR     39.00      35.00
# 53            United Kingdom     77                    GB     54.00      -2.00
# 54  United States of America    666                    US     38.00     -97.00
# 55                   Vietnam      2                    VN     16.00     106.00

# %%
df_country_agg.head()
# Out:
#   country_author  full_name_author
# 0        Algeria                 6
# 1      Argentina                14
# 2      Australia                47
# 3        Austria                14
# 4     Bangladesh                 3

# %%
shapes_geometry.head()
# Out:
#        continent                      name iso_a3  \
# 0        Oceania                      Fiji    FJI
# 1         Africa                  Tanzania    TZA
# 2         Africa                 W. Sahara    ESH
# 3  North America                    Canada    CAN
# 4  North America  United States of America    USA
#
#                                             geometry
# 0  MULTIPOLYGON (((180 -16.067132663642447, 180 -...
# 1  POLYGON ((33.90371119710453 -0.950000000000000...
# 2  POLYGON ((-8.665589565454809 27.65642588959235...
# 3  MULTIPOLYGON (((-122.84000000000003 49.0000000...
# 4  MULTIPOLYGON (((-122.84000000000003 49.0000000...

# %%
df_geo_plot = shapes_geometry.merge(df_country_agg, left_on='name', right_on='country_author')

# %%
df_geo_plot.head()
# Out:
#        continent                      name iso_a3  \
# 0  North America                    Canada    CAN
# 1  North America  United States of America    USA
# 2  North America  United States of America    USA
# 3  North America  United States of America    USA
# 4  South America                 Argentina    ARG
#
#                                             geometry  \
# 0  MULTIPOLYGON (((-122.84000000000003 49.0000000...
# 1  MULTIPOLYGON (((-122.84000000000003 49.0000000...
# 2  MULTIPOLYGON (((-122.84000000000003 49.0000000...
# 3  MULTIPOLYGON (((-122.84000000000003 49.0000000...
# 4  MULTIPOLYGON (((-68.63401022758323 -52.6363704...
#
#              country_author  full_name_author
# 0                    Canada                30
# 1  United States of America               489
# 2  United States of America               159
# 3  United States of America                18
# 4                 Argentina                14

# %%
df_geo_plot.full_name_author = df_geo_plot.full_name_author.fillna(0)

# %% [markdown]
# df_geo_plot = df_geo_plot.reset_index().set_index('index')
# df_geo_plot.geometry.to_json()

# %%
df_geo_plot.rename(columns={'full_name_author':'Number of Authors','name':'Country'}, inplace=True)

# %% [markdown]
# df_geo_plot.geometry.iat[0]

# %%
import folium

my_map = folium.Map()
# Add the data
folium.Choropleth(
    geo_data=pd.read_json(os.path.join(path_geo,'geometry.json')).to_json(),
    name='choropleth',
    data=df_geo_plot,
    columns=['name'],
    key_on='feature.properties.id',
    fill_color='OrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Authors by Location'
).add_to(my_map)
my_map.save('meat.html')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-8ec243541f3c> in <module>
#       3 my_map = folium.Map()
#       4 # Add the data
# ----> 5 folium.Choropleth(
#       6     geo_data=pd.read_json(os.path.join(path_geo,'geometry.json')).to_json(),
#       7     name='choropleth',
#
# c:\Users\vierb\anaconda3\lib\site-packages\folium\features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1198         if hasattr(data, 'set_index'):
#    1199             # This is a pd.DataFrame
# -> 1200             color_data = data.set_index(columns[0])[columns[1]].to_dict()
#    1201         elif hasattr(data, 'to_dict'):
#    1202             # This is a pd.Series
#
# c:\Users\vierb\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\vierb\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5492
#    5493         if missing:
# -> 5494             raise KeyError(f"None of {missing} are in the columns")
#    5495
#    5496         if inplace:
#
# KeyError: "None of ['name'] are in the columns"

# %% [markdown]
# https://stackoverflow.com/questions/43587960/gdal-installation-error-using-pip

# %%
    df_doc_info = dict_dfs['df_doc_info'].loc[:,getColumnsWithData(dict_dfs['df_doc_info'])]
    df_doc_head = dict_dfs['df_doc_head'].loc[:,getColumnsWithData(dict_dfs['df_doc_head'])]
    df_doc_authors = dict_dfs['df_doc_authors'].loc[:,getColumnsWithData(dict_dfs['df_doc_authors'])]
    df_doc_authors_citations = dict_dfs['df_doc_authors_citations'].loc[:,getColumnsWithData(dict_dfs['df_doc_authors_citations'])]

# %%
df_doc_info.head()
# Out:
#            grobid_version     grobid_timestamp  \
# article_id
# 1                   0.7.0  2022-05-15 02:11:00
# 2                   0.7.0  2022-05-15 02:09:00
# 3                   0.7.0  2022-05-15 02:10:00
# 4                   0.7.0  2022-05-15 02:09:00
# 5                   0.7.0  2022-05-15 02:09:00
#
#                                      pdf_md5 language_code  \
# article_id
# 1           915208F947D9A8C5F93F958AF4435A39            en
# 2           BD5CAA459269F9DDAEED89D25B28B4C8            en
# 3           A8D795899D1DE7A3D9CDA47F45F8885C            en
# 4           A89985654AE252596EE14410E0DA1F9B            en
# 5           82D64FDF1966AEB1230F90AF465E41BF            en
#
#                                               acknowledgement  \
# article_id
# 1           Acknowledgments This work was supported by the...
# 2                                                         NaN
# 3           Acknowledgements XW would like to thank Yuanch...
# 4           Acknowledgements We want to acknowledge CSC-Sc...
# 5                                            Acknowledgements
#
#                                                      abstract  \
# article_id
# 1           The limitation of traditional Von Neumann arch...
# 2           For successful applications of machine learnin...
# 3           The generalized stacking fault energies (GSFE)...
# 4           Despite their simplicity, the concepts of oxid...
# 5           This paper concerns on the aluminum foam mater...
#
#                                                          body  \
# article_id
# 1           Introduction Traditional computing system has ...
# 2           Introduction To save time and human efforts, m...
# 3           Introduction Refractory metals are metals with...
# 4           Introduction The concept of valency, formulate...
# 5           Introduction As energy crisis intensified, the...
#
#                                                          file      status  \
# article_id
# 1           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 2           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 3           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 4           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 5           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
#
#                                                      raw_data
# article_id
# 1           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# 2           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# 3           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# 4           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# 5           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...

# %%
df_doc_info.isnull().sum()
# Out:
# grobid_version        0
# grobid_timestamp      0
# pdf_md5               0
# language_code         0
# acknowledgement     126
# abstract             17
# body                  0
# file                  0
# status                0
# raw_data              0
# dtype: int64

# %%
df_doc_head.head()
# Out:
#              date_head                                         title_head  \
# article_id
# 1           2021-08-06  Linearity improvement of HfO x -based memristo...
# 2           2021-01-29  Transfer learning for materials informatics us...
# 3           2021-03-02  Generalized stacking fault energies and Peierl...
# 4           2019-03-04                    Computational Materials Science
# 5           2013-04-09  Identification of material parameters for alum...
#
#            issn_head                         doi_head arxiv_id_head
# article_id
# 1                NaN       10.1016/j.mssp.2021.106131           NaN
# 2                NaN  10.1016/j.commatsci.2021.110314           NaN
# 3                NaN  10.1016/j.commatsci.2021.110364           NaN
# 4                NaN  10.1016/j.commatsci.2019.01.046           NaN
# 5                NaN  10.1016/j.commatsci.2013.02.024           NaN

# %%
df_doc_head.isnull().sum()
# Out:
# date_head        312
# title_head        10
# issn_head        577
# doi_head          15
# arxiv_id_head    580
# dtype: int64

# %%
df_doc_authors.head()
# Out:
#            full_name_author given_name_author middle_name_author  \
# article_id
# 1              Yutong Jiang            Yutong                NaN
# 1            Kailiang Zhang          Kailiang                NaN
# 1                    Kai Hu               Kai                NaN
# 1              Yujian Zhang            Yujian                NaN
# 1                Ange Liang              Ange                NaN
#
#            surname_author                email_author orcid_author  \
# article_id
# 1                   Jiang                         NaN          NaN
# 1                   Zhang  kailiang_zhang@tjut.edu.cn          NaN
# 1                      Hu                         NaN          NaN
# 1                   Zhang                         NaN          NaN
# 1                   Liang                         NaN          NaN
#
#                           institution_author  \
# article_id
# 1           Tianjin University of Technology
# 1           Tianjin University of Technology
# 1           Tianjin University of Technology
# 1                                        NaN
# 1           Tianjin University of Technology
#
#                                           department_author  \
# article_id
# 1           School of Electrical and Electronic Engineering
# 1           School of Electrical and Electronic Engineering
# 1           School of Electrical and Electronic Engineering
# 1                                                       NaN
# 1           School of Electrical and Electronic Engineering
#
#                                             laboratory_author  \
# article_id
# 1           Tianjin Key Laboratory of Film Electronic and ...
# 1           Tianjin Key Laboratory of Film Electronic and ...
# 1           Tianjin Key Laboratory of Film Electronic and ...
# 1                                                         NaN
# 1           Tianjin Key Laboratory of Film Electronic and ...
#
#            addr_line_author post_code_author settlement_author country_author
# article_id
# 1                       NaN           300384           Tianjin       PR China
# 1                       NaN           300384           Tianjin       PR China
# 1                       NaN           300384           Tianjin       PR China
# 1                       NaN              NaN               NaN            NaN
# 1                       NaN           300384           Tianjin       PR China

# %%
df_doc_authors.isnull().sum()
# Out:
# full_name_author         8
# given_name_author       45
# middle_name_author    2036
# surname_author           8
# email_author          2107
# orcid_author          2599
# institution_author     465
# department_author      749
# laboratory_author     2319
# addr_line_author      2140
# post_code_author       889
# settlement_author      584
# country_author         398
# dtype: int64

# %%
df_doc_authors_citations.head()
# Out:
#             id  index full_name_citation given_name_citation  \
# article_id
# 1           b0      0           H L Park                   H
# 1           b0      0              Y Lee                   Y
# 1           b0      0              N Kim                   N
# 1           b0      0            D G Seo                   D
# 1           b0      0             G T Go                   G
#
#            middle_name_citation surname_citation
# article_id
# 1                             L             Park
# 1                           NaN              Lee
# 1                           NaN              Kim
# 1                             G              Seo
# 1                             T               Go

# %%
df_doc_authors_citations.isnull().sum()
# Out:
# id                          0
# index                       0
# full_name_citation        766
# given_name_citation      2024
# middle_name_citation    84248
# surname_citation         1634
# dtype: int64

# %%
dict_dfs.keys()
# Out:
# dict_keys(['df_doc_info', 'df_doc_head', 'df_doc_authors', 'df_doc_citations', 'df_doc_authors_citations'])

# %%
dict_dfs['df_doc_authors_citations'].head()
# Out:
#             id  index full_name_citation given_name_citation  \
# article_id
# 1           b0      0           H L Park                   H
# 1           b0      0              Y Lee                   Y
# 1           b0      0              N Kim                   N
# 1           b0      0            D G Seo                   D
# 1           b0      0             G T Go                   G
#
#            middle_name_citation surname_citation  email_citation  \
# article_id
# 1                             L             Park             NaN
# 1                           NaN              Lee             NaN
# 1                           NaN              Kim             NaN
# 1                             G              Seo             NaN
# 1                             T               Go             NaN
#
#             orcid_citation  institution_citation  department_citation  \
# article_id
# 1                      NaN                   NaN                  NaN
# 1                      NaN                   NaN                  NaN
# 1                      NaN                   NaN                  NaN
# 1                      NaN                   NaN                  NaN
# 1                      NaN                   NaN                  NaN
#
#             laboratory_citation  addr_line_citation  post_code_citation  \
# article_id
# 1                           NaN                 NaN                 NaN
# 1                           NaN                 NaN                 NaN
# 1                           NaN                 NaN                 NaN
# 1                           NaN                 NaN                 NaN
# 1                           NaN                 NaN                 NaN
#
#             settlement_citation  country_citation
# article_id
# 1                           NaN               NaN
# 1                           NaN               NaN
# 1                           NaN               NaN
# 1                           NaN               NaN
# 1                           NaN               NaN

# %%
dict_dfs['df_doc_authors_citations'].head().T
# Out:
# article_id                   1      1      1        1       1
# id                          b0     b0     b0       b0      b0
# index                        0      0      0        0       0
# full_name_citation    H L Park  Y Lee  N Kim  D G Seo  G T Go
# given_name_citation          H      Y      N        D       G
# middle_name_citation         L    NaN    NaN        G       T
# surname_citation          Park    Lee    Kim      Seo      Go
# email_citation             NaN    NaN    NaN      NaN     NaN
# orcid_citation             NaN    NaN    NaN      NaN     NaN
# institution_citation       NaN    NaN    NaN      NaN     NaN
# department_citation        NaN    NaN    NaN      NaN     NaN
# laboratory_citation        NaN    NaN    NaN      NaN     NaN
# addr_line_citation         NaN    NaN    NaN      NaN     NaN
# post_code_citation         NaN    NaN    NaN      NaN     NaN
# settlement_citation        NaN    NaN    NaN      NaN     NaN
# country_citation           NaN    NaN    NaN      NaN     NaN

# %%
df_doc_authors_citations = dict_dfs['df_doc_authors_citations'].loc[:,getColumnsWithData(dict_dfs['df_doc_authors_citations'])]

# %%
df_doc_authors_citations.head()
# Out:
#             id  index full_name_citation given_name_citation  \
# article_id
# 1           b0      0        Young H Kim               Young
# 1           b0      0           S J Song                   S
# 1           b0      0            J Y Kim                   J
# 1           b1      1     T Saniie Jafar                   T
# 1           b1      1           N M Wang                   N
#
#            middle_name_citation surname_citation
# article_id
# 1                             H              Kim
# 1                             J             Song
# 1                             Y              Kim
# 1                           NaN     Saniie Jafar
# 1                             M             Wang

# %%
df_doc_authors_citations.shape
# Out:
# (121910, 6)

# %%
df_doc_authors_citations.full_name_citation.value_counts()
# Out:
# J Behler       374
# Y Zhang        339
# R Ramprasad    318
# G Ceder        277
# S Curtarolo    268
#               ...
# A Ameli          1
# S Azari          1
# I Barsoum        1
# M Churchill      1
# N Vinod          1
# Name: full_name_citation, Length: 46789, dtype: int64

# %%
df_doc_authors.head()
# Out:
#            full_name_author given_name_author middle_name_author  \
# article_id
# 1                  Qiuji Yi             Qiuji                NaN
# 1               Haitao Wang            Haitao                NaN
# 1               Ruipeng Guo           Ruipeng                NaN
# 1                 Suyuan Li            Suyuan                NaN
# 1                  Yi Jiang                Yi                NaN
#
#            surname_author email_author orcid_author institution_author  \
# article_id
# 1                      Yi          NaN          NaN                NaN
# 1                    Wang          NaN          NaN                NaN
# 1                     Guo          NaN          NaN                NaN
# 1                      Li          NaN          NaN                NaN
# 1                   Jiang          NaN          NaN                NaN
#
#            department_author laboratory_author addr_line_author  \
# article_id
# 1                        NaN               NaN              NaN
# 1                        NaN               NaN              NaN
# 1                        NaN               NaN              NaN
# 1                        NaN               NaN              NaN
# 1                        NaN               NaN              NaN
#
#            post_code_author settlement_author country_author
# article_id
# 1                       NaN               NaN            NaN
# 1                       NaN               NaN            NaN
# 1                       NaN               NaN            NaN
# 1                       NaN               NaN            NaN
# 1                       NaN               NaN            NaN

# %%
def agg_citations(grupo):
    dictR = {}
    dictR['citation_name'] = grupo['full_name_citation'].iat[0]
    dictR['citation_count'] = grupo.shape[0]
    dictR['number_authors'] = grupo['full_name_author'].nunique()
    dictR['number_countries'] = grupo['country_author'].nunique()
    return pd.Series(dictR)

df_authors_citations = df_doc_authors_citations.loc[:,['full_name_citation']].reset_index()
df_authors = df_doc_authors.loc[:,['full_name_author','country_author']].reset_index()

df_authors_citations = df_authors_citations.drop_duplicates(subset=['article_id','full_name_citation'])
df_authors = df_authors.drop_duplicates(subset=['article_id','full_name_author'])

df_authors_and_citations = df_authors.merge(df_authors_citations, on='article_id')

df_citation_plot = df_authors_and_citations.groupby(by=['full_name_citation'], as_index=False).apply(lambda g: agg_citations(g))

df_citation_plot = df_citation_plot.sort_values(by=['citation_count'], ascending=False)
df_citation_plot = df_citation_plot.head(100)

import plotly.express as px

fig = px.treemap(df_citation_plot, path=[px.Constant("CITATIONS"),
                                         'full_name_citation'],
                 values='citation_count',
                 color='number_authors',
                 hover_data=['number_countries'],
                 color_continuous_scale='RdBu')
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))

# %%
import plotly.express as px

fig = px.treemap(df_citation_plot, path=[px.Constant("CITATIONS"),
                                         'full_name_citation'],
                 values='citation_count',
                 color='number_authors',
                 hover_name=['Author Cited',
                             'Number of Citations by Other Authors',
                             'Type',
                             'ID',
                             'Number of Countries Cited',
                             'Unique Authors Using This Citation'],
                 hover_data=['number_countries'],
                 color_continuous_scale='RdBu',
                 width=800,
                 height=500)
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))

fig.show()
# Out:
# c:\Users\vierb\anaconda3\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\vierb\anaconda3\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
