# %% [markdown]
# # Features de TextMining:

# %% [markdown]
# ---------------------------------

# %%
import os
import sys
import re
import datetime
import dateutil

sys.path.insert(0,os.path.dirname(os.getcwd()))
sys.path.insert(0,os.path.join(os.getcwd(),'grobid'))
sys.path.insert(0,os.getcwd())

import numpy as np
import pandas as pd

from grobid import grobid_client
import grobid_tei_xml
from grobid_to_dataframe import grobid_cli, xmltei_to_dataframe

import plotly

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

from pyvis.network import Network
import nltk

import random

# %% [markdown]
# !pip install markupsafe==2.0.1

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ### Comandos Docker

# %% [markdown]
# docker run -t --rm --init -p 8080:8070 -p 8081:8071 --memory="9g" lfoppiano/grobid:0.7.0
#
# docker run -t --rm --init -p 8080:8070 -p 8081:8071 lfoppiano/grobid:0.6.2

# %% [markdown]
# ### Definindo variáveis e caminhos

# %%
path = os.path.dirname(os.getcwd())
path_input = os.path.join(path,'artifacts','articles','ml_material','teste')

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ### Funções para execução em batch

# %%
def get_path(path_input_path):
    """"""
    if os.path.exists(path_input_path):
        return path_input_path
    
    return os.getcwd()


def batch_process_path(path_input_path, n_workers=2,
                       check_cache=True,
                       cache_folder_name='summarticles_cache',
                       config_path="./grobid/config.json"):
    
    """"""
    
    gcli = grobid_cli(config_path=config_path)
    result_batch = gcli.process_pdfs(input_path=path_input_path,
                                     check_cache=check_cache,
                                     cache_folder_name=cache_folder_name,
                                     n_workers=n_workers,
                                     service="processFulltextDocument",
                                     generateIDs=True,
                                     include_raw_citations=True,
                                     include_raw_affiliations=True,
                                     consolidate_header=False,
                                     consolidate_citations=False,
                                     tei_coordinates=False,
                                     segment_sentences=True,
                                     verbose=True)
    return result_batch


def get_dataframes(result_batch):
    
    """"""
    
    xml_to_df = xmltei_to_dataframe()
    dict_dfs, dic_errors = xml_to_df.get_dataframe_articles(result_batch)
    
    return dict_dfs, dic_errors


def files_path(path):
    list_dir = os.listdir(path)
    files = []
    for file in list_dir:
        if os.path.isfile(os.path.join(path,file)):
            files.append(os.path.join(path,file))
    return files

# %%
def run_batch_process(path_input, n_workers=6, check_cache=True, 
                      cache_folder_name='summarticles_cache', 
                      config_path="./grobid/config.json"):

    dict_exec = {'path':path_input}
    dict_exec['start_datetime'] = datetime.datetime.now()
    
    # path_input = os.path.join(path,'artifacts','test_article')
    config_path = os.path.join(os.getcwd(),'grobid','config.json')
    dict_exec['grobid_config'] = config_path
    
    gcli = grobid_client.GrobidClient(config_path=config_path, check_server=False)
    
    dict_exec['files'] = gcli.get_input_files(path_input)
    dict_exec['num_files'] = len(dict_exec['files'])
    dict_exec['n_workers'] = n_workers
    
    path_input_path = get_path(path_input)
    result_batch = batch_process_path(path_input_path, n_workers=dict_exec['n_workers'], check_cache=check_cache)
    dict_dfs, dic_errors = get_dataframes(result_batch)
    
    gcli.save_xmltei_files(result_batch, input_folder_path, cache_folder_name=cache_folder_name)
    
    dict_exec['end_datetime'] = datetime.datetime.now()
    dict_exec['time_exec_sec'] = (dict_exec['end_datetime']-dict_exec['start_datetime']).seconds
    dict_exec['time_exec_min'] = (dict_exec['end_datetime']-dict_exec['start_datetime']).seconds
    
    return dict_dfs, dict_exec, dic_errors

# %%
input_folder_path = r"""C:\Users\vierb\OneDrive\Área de Trabalho\Projetos\PGC\artifacts\articles\ml_material"""

# %%
# %%time
dict_dfs, dict_exec, dic_errors = run_batch_process(path_input=input_folder_path, 
                                                    n_workers=10, 
                                                    check_cache=True, 
                                                    cache_folder_name='summarticles_cache', 
                                                    config_path="./grobid/config.json")
# Out:
# GROBID server is up and running
# 587 files to process in current batch
# [Input Files] 587
# [Cache Files] 587
# In the end, we have: 0  new files to process!
# And we have : 587  files to back from cache!
# Processed articles: 581
# Number articles with errors: 6
# Wall time: 23 s

# %% [markdown]
# ---------------------------------

# %%
def getColumnsWithData(df, return_percent=False, n_round=2):
    
    """"""
    
    list_col_with_data = []
    for col in df.columns.tolist():
        rows = df[col].shape
        n_null = df[col].isnull().sum()
        not_null_data_perc = (1-n_null/rows)
        if not_null_data_perc:
            if return_percent:
                list_col_with_data.append((col,np.round(not_null_data_perc, n_round)))
            list_col_with_data.append(col)
            
    return list_col_with_data

# %%
dict_dfs.keys()
# Out:
# dict_keys(['df_doc_info', 'df_doc_head', 'df_doc_authors', 'df_doc_citations', 'df_doc_authors_citations'])

# %% [markdown]
# ### df_doc_info

# %%
100*(1-dict_dfs['df_doc_info'].isnull().sum()/dict_dfs['df_doc_info'].shape[0])
# Out:
# grobid_version      100.000000
# grobid_timestamp    100.000000
# pdf_md5             100.000000
# language_code       100.000000
# acknowledgement      78.313253
# abstract             97.074010
# body                100.000000
# annex                 0.000000
# file                100.000000
# status              100.000000
# raw_data            100.000000
# dtype: float64

# %%
df_doc_info = dict_dfs['df_doc_info'].loc[:,getColumnsWithData(dict_dfs['df_doc_info'])]

# %%
df_doc_info.head()
# Out:
#            grobid_version     grobid_timestamp  \
# article_id
# 1                   0.7.0  2022-05-15 02:11:00
# 2                   0.7.0  2022-05-15 02:09:00
# 3                   0.7.0  2022-05-15 02:10:00
# 4                   0.7.0  2022-05-15 02:09:00
# 5                   0.7.0  2022-05-15 02:09:00
#
#                                      pdf_md5 language_code  \
# article_id
# 1           915208F947D9A8C5F93F958AF4435A39            en
# 2           BD5CAA459269F9DDAEED89D25B28B4C8            en
# 3           A8D795899D1DE7A3D9CDA47F45F8885C            en
# 4           A89985654AE252596EE14410E0DA1F9B            en
# 5           82D64FDF1966AEB1230F90AF465E41BF            en
#
#                                               acknowledgement  \
# article_id
# 1           Acknowledgments This work was supported by the...
# 2                                                         NaN
# 3           Acknowledgements XW would like to thank Yuanch...
# 4           Acknowledgements We want to acknowledge CSC-Sc...
# 5                                            Acknowledgements
#
#                                                      abstract  \
# article_id
# 1           The limitation of traditional Von Neumann arch...
# 2           For successful applications of machine learnin...
# 3           The generalized stacking fault energies (GSFE)...
# 4           Despite their simplicity, the concepts of oxid...
# 5           This paper concerns on the aluminum foam mater...
#
#                                                          body  \
# article_id
# 1           Introduction Traditional computing system has ...
# 2           Introduction To save time and human efforts, m...
# 3           Introduction Refractory metals are metals with...
# 4           Introduction The concept of valency, formulate...
# 5           Introduction As energy crisis intensified, the...
#
#                                                          file      status  \
# article_id
# 1           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 2           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 3           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 4           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 5           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
#
#                                                      raw_data
# article_id
# 1           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# 2           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# 3           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# 4           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# 5           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...

# %% [markdown]
# ### df_doc_head

# %%
100*(1-dict_dfs['df_doc_head'].isnull().sum()/dict_dfs['df_doc_head'].shape[0])
# Out:
# index_head              0.000000
# id_head                 0.000000
# unstructured_head       0.000000
# date_head              46.299484
# title_head             98.278830
# book_title_head         0.000000
# series_title_head       0.000000
# journal_head            0.000000
# journal_abbrev_head     0.000000
# publisher_head          0.000000
# institution_head        0.000000
# issn_head               0.688468
# eissn_head              0.000000
# volume_head             0.000000
# issue_head              0.000000
# pages_head              0.000000
# first_page_head         0.000000
# last_page_head          0.000000
# note_head               0.000000
# doi_head               97.418244
# pmid_head               0.000000
# pmcid_head              0.000000
# arxiv_id_head           0.172117
# ark_head                0.000000
# istex_id_head           0.000000
# url_head                0.000000
# dtype: float64

# %%
dict_dfs['df_doc_head'].dtypes
# Out:
# index_head             float64
# id_head                float64
# unstructured_head      float64
# date_head               object
# title_head              object
# book_title_head        float64
# series_title_head      float64
# journal_head           float64
# journal_abbrev_head    float64
# publisher_head         float64
# institution_head       float64
# issn_head               object
# eissn_head             float64
# volume_head            float64
# issue_head             float64
# pages_head             float64
# first_page_head        float64
# last_page_head         float64
# note_head              float64
# doi_head                object
# pmid_head              float64
# pmcid_head             float64
# arxiv_id_head           object
# ark_head               float64
# istex_id_head          float64
# url_head               float64
# dtype: object

# %%
df_doc_head = dict_dfs['df_doc_head'].loc[:,getColumnsWithData(dict_dfs['df_doc_head'])]

# %%
df_doc_head
# Out:
#              date_head                                         title_head  \
# article_id
# 1           2021-08-06  Linearity improvement of HfO x -based memristo...
# 2           2021-01-29  Transfer learning for materials informatics us...
# 3           2021-03-02  Generalized stacking fault energies and Peierl...
# 4           2019-03-04                    Computational Materials Science
# 5           2013-04-09  Identification of material parameters for alum...
# ...                ...                                                ...
# 583         2010-03-15  Prediction of the hot deformation behavior for...
# 584                NaN  Journal Pre-proof Interactive-quantum-chemical...
# 585         2015-04-05  A c c e p t e d M a n u s c r i p t An impleme...
# 586         2014-03-19  Study on the hot deformation behavior of TC4-D...
# 587                NaN  Numerical simulation of Cr 2 N age-precipitati...
#
#            issn_head                         doi_head arxiv_id_head
# article_id
# 1                NaN       10.1016/j.mssp.2021.106131           NaN
# 2                NaN  10.1016/j.commatsci.2021.110314           NaN
# 3                NaN  10.1016/j.commatsci.2021.110364           NaN
# 4                NaN  10.1016/j.commatsci.2019.01.046           NaN
# 5                NaN  10.1016/j.commatsci.2013.02.024           NaN
# ...              ...                              ...           ...
# 583              NaN  10.1016/j.commatsci.2010.02.031           NaN
# 584              NaN    10.1016/j.polymer.2020.122738           NaN
# 585              NaN     10.1016/j.cplett.2015.04.019           NaN
# 586              NaN       10.1016/j.msea.2014.03.047           NaN
# 587              NaN       10.1016/j.msea.2004.07.003           NaN
#
# [581 rows x 5 columns]

# %%
df_doc_info_head = df_doc_info.join(df_doc_head, how='left')

# %%
df_doc_info_head.head(5)
# Out:
#            grobid_version     grobid_timestamp  \
# article_id
# 1                   0.7.0  2022-05-15 02:11:00
# 2                   0.7.0  2022-05-15 02:09:00
# 3                   0.7.0  2022-05-15 02:10:00
# 4                   0.7.0  2022-05-15 02:09:00
# 5                   0.7.0  2022-05-15 02:09:00
#
#                                      pdf_md5 language_code  \
# article_id
# 1           915208F947D9A8C5F93F958AF4435A39            en
# 2           BD5CAA459269F9DDAEED89D25B28B4C8            en
# 3           A8D795899D1DE7A3D9CDA47F45F8885C            en
# 4           A89985654AE252596EE14410E0DA1F9B            en
# 5           82D64FDF1966AEB1230F90AF465E41BF            en
#
#                                               acknowledgement  \
# article_id
# 1           Acknowledgments This work was supported by the...
# 2                                                         NaN
# 3           Acknowledgements XW would like to thank Yuanch...
# 4           Acknowledgements We want to acknowledge CSC-Sc...
# 5                                            Acknowledgements
#
#                                                      abstract  \
# article_id
# 1           The limitation of traditional Von Neumann arch...
# 2           For successful applications of machine learnin...
# 3           The generalized stacking fault energies (GSFE)...
# 4           Despite their simplicity, the concepts of oxid...
# 5           This paper concerns on the aluminum foam mater...
#
#                                                          body  \
# article_id
# 1           Introduction Traditional computing system has ...
# 2           Introduction To save time and human efforts, m...
# 3           Introduction Refractory metals are metals with...
# 4           Introduction The concept of valency, formulate...
# 5           Introduction As energy crisis intensified, the...
#
#                                                          file      status  \
# article_id
# 1           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 2           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 3           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 4           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 5           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
#
#                                                      raw_data   date_head  \
# article_id
# 1           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...  2021-08-06
# 2           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...  2021-01-29
# 3           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...  2021-03-02
# 4           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...  2019-03-04
# 5           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...  2013-04-09
#
#                                                    title_head issn_head  \
# article_id
# 1           Linearity improvement of HfO x -based memristo...       NaN
# 2           Transfer learning for materials informatics us...       NaN
# 3           Generalized stacking fault energies and Peierl...       NaN
# 4                             Computational Materials Science       NaN
# 5           Identification of material parameters for alum...       NaN
#
#                                    doi_head arxiv_id_head
# article_id
# 1                10.1016/j.mssp.2021.106131           NaN
# 2           10.1016/j.commatsci.2021.110314           NaN
# 3           10.1016/j.commatsci.2021.110364           NaN
# 4           10.1016/j.commatsci.2019.01.046           NaN
# 5           10.1016/j.commatsci.2013.02.024           NaN

# %%
df_doc_info_head.date_head = df_doc_info_head.date_head.apply(lambda e: pd.to_datetime(e))

# %%
df_doc_info_head['year'] = df_doc_info_head.date_head.apply(lambda e: e if pd.isna(e) else int(e.year))

# %%
df_doc_info_head.date_head.value_counts(dropna=False)
# Out:
# NaT           312
# 2021-08-02      4
# 2021-03-02      3
# 2021-03-10      3
# 2021-04-23      3
#              ...
# 2020-04-27      1
# 2017-11-06      1
# 2011-02-17      1
# 2020-05-05      1
# 2015-04-05      1
# Name: date_head, Length: 240, dtype: int64

# %%
df_doc_info_head.year.value_counts(dropna=False).to_dict()
# Out:
# {NaT: 312,
#  2021: 109,
#  2020: 45,
#  2019: 25,
#  2011: 13,
#  2012: 12,
#  2008: 11,
#  2010: 10,
#  2009: 9,
#  2015: 8,
#  2018: 7,
#  2013: 5,
#  2017: 5,
#  2016: 4,
#  2014: 2,
#  2007: 1,
#  2000: 1,
#  2005: 1,
#  2006: 1}

# %%
pd.DataFrame(df_doc_info_head.year.value_counts(dropna=False).to_dict(), columns=['year','count'])
# Out:
# Empty DataFrame
# Columns: [year, count]
# Index: []

# %%
import plotly.express as px

df_doc_info_head.year = df_doc_info_head.year.fillna('Null Value')

fig = px.pie(df_doc_info_head, 
             values='year', 
             names='year',
             title='Number of Articles by Year',
             hover_data=['year'], 
             labels={'values':'Percentage','year':'Year of Article'}, hole=.5)

fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(showlegend=False)
fig.show()

# %% [markdown]
# ### df_doc_authors

# %%
100*(1-dict_dfs['df_doc_authors'].isnull().sum()/dict_dfs['df_doc_authors'].shape[0])
# Out:
# full_name_author      99.701715
# given_name_author     98.322148
# middle_name_author    24.086503
# surname_author        99.701715
# email_author          21.439224
# orcid_author           3.094705
# institution_author    82.662192
# department_author     72.073080
# laboratory_author     13.534676
# addr_line_author      20.208799
# post_code_author      66.853095
# settlement_author     78.225205
# country_author        85.160328
# dtype: float64

# %%
df_doc_authors = dict_dfs['df_doc_authors'].loc[:,getColumnsWithData(dict_dfs['df_doc_authors'])]

# %%
df_doc_authors.head()
# Out:
#            full_name_author given_name_author middle_name_author  \
# article_id
# 1               Heesoo Park            Heesoo                NaN
# 1           Raghvendra Mall        Raghvendra                NaN
# 1                 Adnan Ali             Adnan                NaN
# 1           Stefano Sanvito           Stefano                NaN
# 1           Halima Bensmail            Halima                NaN
#
#            surname_author       email_author orcid_author  \
# article_id
# 1                    Park  hpark@hbku.edu.qa          NaN
# 1                    Mall                NaN          NaN
# 1                     Ali                NaN          NaN
# 1                 Sanvito                NaN          NaN
# 1                Bensmail                NaN          NaN
#
#                       institution_author  \
# article_id
# 1           Hamad Bin Khalifa University
# 1           Hamad Bin Khalifa University
# 1           Hamad Bin Khalifa University
# 1                        Trinity College
# 1           Hamad Bin Khalifa University
#
#                                        department_author laboratory_author  \
# article_id
# 1                                                    NaN               NaN
# 1                                                    NaN               NaN
# 1                                                    NaN               NaN
# 1           School of Physics, AMBER and CRANN Institute               NaN
# 1                                                    NaN               NaN
#
#            addr_line_author post_code_author settlement_author country_author
# article_id
# 1                       NaN              NaN              Doha          Qatar
# 1                       NaN              NaN              Doha          Qatar
# 1                       NaN              NaN              Doha          Qatar
# 1                  Dublin 2              NaN               NaN        Ireland
# 1                       NaN              NaN              Doha          Qatar

# %%
columns_select = ['country_author','settlement_author']
df_sun_agg = df_doc_authors.groupby(by=columns_select, as_index=False, dropna=True)['full_name_author'].count()

# %%
df_sun_agg = df_sun_agg.fillna("")
df_sun_agg.rename(columns={'country_author':'Author Country',
                           'settlement_author':'Author Settlement',
                           'full_name_author':'Number of Authors'},
                  inplace=True)

# %%
df_sun_agg.head()
# Out:
#   Author Country Author Settlement  Number of Authors
# 0        Algeria           Tlemcen                  2
# 1      Argentina      Bahía Blanca                  4
# 2      Argentina      Buenos Aires                  5
# 3      Argentina          La Plata                  1
# 4      Argentina             Salta                  1

# %%
import plotly.express as px
fig = px.sunburst(df_sun_agg, 
                  path=['Author Country',
                        'Author Settlement'],
                  values='Number of Authors')
fig.show()
# Out:
# c:\Users\vierb\anaconda3\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# c:\Users\vierb\anaconda3\lib\site-packages\plotly\express\_core.py:1637: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
df_doc_authors.full_name_author.value_counts(dropna=False)
# Out:
# A R T I C L E I N F O    10
# Acta Materialia           8
# NaN                       8
# Yu Sun                    6
# Dane Morgan               6
#                          ..
# Y X Li                    1
# X X Wang                  1
# G Qin                     1
# P F Gao                   1
# J H Chen                  1
# Name: full_name_author, Length: 2324, dtype: int64

# %%
list_delete_authors = ['A R T I C L E I N F O', np.nan, 'Null', 'NaN','nan', 'null', '', ' ']
filter_delete_authors = ~(df_doc_authors.full_name_author.isin(list_delete_authors))
df_doc_authors = df_doc_authors.loc[filter_delete_authors].copy()

# %%
top_authors = df_doc_authors.full_name_author.value_counts()
df_top_authors = pd.DataFrame({'Full Name':top_authors.index,
                               'Number of Articles':top_authors.values.tolist()})

df_top_authors
# Out:
#             Full Name  Number of Articles
# 0     Acta Materialia                   8
# 1           N S Reddy                   6
# 2        Weidong Zeng                   6
# 3              Yu Sun                   6
# 4         Dane Morgan                   6
# ...               ...                 ...
# 2317           Y X Li                   1
# 2318         X X Wang                   1
# 2319            G Qin                   1
# 2320          P F Gao                   1
# 2321         J H Chen                   1
#
# [2322 rows x 2 columns]

# %%
import plotly.express as px

top_authors = df_top_authors.nlargest(20,'Number of Articles')
top_authors = top_authors.sort_values('Number of Articles',ascending=True)
fig = px.bar(top_authors,
             y='Full Name',
             x='Number of Articles',
             color='Number of Articles',
             width=600,
             height=700,text='Number of Articles')
fig.update(layout_coloraxis_showscale=False)
# fig.update_traces(showlegend=False)
# fig.update_traces(marker_showscale=False)
fig.update_xaxes(visible=False)
fig.update_layout(yaxis_title=None, xaxis_title=None)
fig.show()

# %% [markdown]
# ### df_doc_authors_citations

# %%
100*(1-dict_dfs['df_doc_authors_citations'].isnull().sum()/dict_dfs['df_doc_authors_citations'].shape[0])
# Out:
# id                      100.000000
# index                   100.000000
# full_name_citation       99.371668
# given_name_citation      98.339759
# middle_name_citation     30.893282
# surname_citation         98.659667
# email_citation            0.000000
# orcid_citation            0.000000
# institution_citation      0.000000
# department_citation       0.000000
# laboratory_citation       0.000000
# addr_line_citation        0.000000
# post_code_citation        0.000000
# settlement_citation       0.000000
# country_citation          0.000000
# dtype: float64

# %%
df_doc_authors_citations = dict_dfs['df_doc_authors_citations'].loc[:,getColumnsWithData(dict_dfs['df_doc_authors_citations'])]

# %%
df_doc_authors_citations
# Out:
#              id  index   full_name_citation given_name_citation  \
# article_id
# 1            b0      0            D B Mitzi                   D
# 1            b0      0  C D Dimitrakopoulos                   C
# 1            b0      0           L L Kosbar                   L
# 1            b1      1             H.-S Kim                H.-S
# 1            b1      1             C.-R Lee                C.-R
# ...         ...    ...                  ...                 ...
# 587         b42     42          P D Nellist                   P
# 587         b42     42        S J Pennycook                   S
# 587         b43     43              J Frank                   J
# 587         b44     44             J H Chen                   J
# 587         b44     44       G Van Tendeloo                   G
#
#            middle_name_citation surname_citation
# article_id
# 1                             B            Mitzi
# 1                             D  Dimitrakopoulos
# 1                             L           Kosbar
# 1                           NaN              Kim
# 1                           NaN              Lee
# ...                         ...              ...
# 587                           D          Nellist
# 587                           J        Pennycook
# 587                         NaN            Frank
# 587                           H             Chen
# 587                         NaN     Van Tendeloo
#
# [121910 rows x 6 columns]

# %%
df_doc_authors_citations.full_name_citation.value_counts(dropna=False)
# Out:
# NaN            766
# J Behler       374
# Y Zhang        339
# R Ramprasad    318
# G Ceder        277
#               ...
# T Gabel          1
# L Bisbee         1
# C Jewett         1
# O Harling        1
# J Radon          1
# Name: full_name_citation, Length: 46790, dtype: int64

# %%
path_geo = os.path.join(path,'data','external')

# %%
shapes_geometry = pd.read_csv(os.path.join(path_geo,'shapes_geometry.csv'), sep=';', decimal='.')
shapes_correct = pd.read_csv(os.path.join(path_geo,'shapes_correct.csv'), encoding='latin-1',sep=';', decimal='.')

# %%
df_country_agg = df_doc_authors.groupby(by=['country_author'], as_index=False, dropna=True)['full_name_author'].count()

dictCorrectShapes = {e[0]:e[1] for e in zip(shapes_correct.convert,shapes_correct.name)}

df_country_agg.country_author = df_country_agg.country_author.apply(lambda e: dictCorrectShapes.get(e,e))

# %%
df_country_agg.head()
# Out:
#   country_author  full_name_author
# 0        Algeria                 6
# 1      Argentina                14
# 2      Australia                47
# 3        Austria                14
# 4     Bangladesh                 3

# %%
shapes_geometry.head()
# Out:
#        continent                      name iso_a3  \
# 0        Oceania                      Fiji    FJI
# 1         Africa                  Tanzania    TZA
# 2         Africa                 W. Sahara    ESH
# 3  North America                    Canada    CAN
# 4  North America  United States of America    USA
#
#                                             geometry
# 0  MULTIPOLYGON (((180 -16.067132663642447, 180 -...
# 1  POLYGON ((33.90371119710453 -0.950000000000000...
# 2  POLYGON ((-8.665589565454809 27.65642588959235...
# 3  MULTIPOLYGON (((-122.84000000000003 49.0000000...
# 4  MULTIPOLYGON (((-122.84000000000003 49.0000000...

# %%
df_geo_plot = shapes_geometry.merge(df_country_agg, left_on='name', right_on='country_author')

# %%
df_geo_plot.head()
# Out:
#        continent                      name iso_a3  \
# 0  North America                    Canada    CAN
# 1  North America  United States of America    USA
# 2  North America  United States of America    USA
# 3  North America  United States of America    USA
# 4  South America                 Argentina    ARG
#
#                                             geometry  \
# 0  MULTIPOLYGON (((-122.84000000000003 49.0000000...
# 1  MULTIPOLYGON (((-122.84000000000003 49.0000000...
# 2  MULTIPOLYGON (((-122.84000000000003 49.0000000...
# 3  MULTIPOLYGON (((-122.84000000000003 49.0000000...
# 4  MULTIPOLYGON (((-68.63401022758323 -52.6363704...
#
#              country_author  full_name_author
# 0                    Canada                30
# 1  United States of America               489
# 2  United States of America               159
# 3  United States of America                18
# 4                 Argentina                14

# %%
df_geo_plot.full_name_author = df_geo_plot.full_name_author.fillna(0)

# %% [markdown]
# df_geo_plot = df_geo_plot.reset_index().set_index('index')
# df_geo_plot.geometry.to_json()

# %%
df_geo_plot.rename(columns={'full_name_author':'Number of Authors','name':'Country'}, inplace=True)

# %% [markdown]
# df_geo_plot.geometry.iat[0]

# %%
import folium

my_map = folium.Map()
# Add the data
folium.Choropleth(
    geo_data=pd.read_json(os.path.join(path_geo,'geometry.json')).to_json(),
    name='choropleth',
    data=df_geo_plot,
    columns=['name'],
    key_on='feature.properties.id',
    fill_color='OrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Authors by Location'
).add_to(my_map)
my_map.save('meat.html')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-255-8ec243541f3c> in <module>
#       3 my_map = folium.Map()
#       4 # Add the data
# ----> 5 folium.Choropleth(
#       6     geo_data=pd.read_json(os.path.join(path_geo,'geometry.json')).to_json(),
#       7     name='choropleth',
#
# c:\Users\vierb\anaconda3\lib\site-packages\folium\features.py in __init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, **kwargs)
#    1198         if hasattr(data, 'set_index'):
#    1199             # This is a pd.DataFrame
# -> 1200             color_data = data.set_index(columns[0])[columns[1]].to_dict()
#    1201         elif hasattr(data, 'to_dict'):
#    1202             # This is a pd.Series
#
# IndexError: list index out of range

# %%
# !conda install geopandas
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# Building graph of deps:   0%|          | 0/310 [00:00<?, ?it/s]
# Examining threadpoolctl:   0%|          | 0/310 [00:00<?, ?it/s]
# Examining babel:   0%|          | 1/310 [00:00<00:09, 32.73it/s]
# Examining anaconda-navigator:   1%|          | 2/310 [00:00<00:15, 19.89it/s]
# Examining anaconda-navigator:   1%|          | 3/310 [00:00<00:10, 29.84it/s]
# Examining cloudpickle:   1%|          | 3/310 [00:04<00:10, 29.84it/s]
# Examining cloudpickle:   1%|▏         | 4/310 [00:04<06:35,  1.29s/it]
# Examining requests:   1%|▏         | 4/310 [00:04<06:35,  1.29s/it]
# Examining requests:   2%|▏         | 5/310 [00:04<04:48,  1.06it/s]
# Examining zope.interface:   2%|▏         | 5/310 [00:04<04:48,  1.06it/s]
# Examining zope.interface:   2%|▏         | 6/310 [00:04<03:54,  1.30it/s]
# Examining python-jsonrpc-server:   2%|▏         | 6/310 [00:05<03:54,  1.30it/s]
# Examining python-jsonrpc-server:   2%|▏         | 7/310 [00:05<03:14,  1.56it/s]
# Examining vs2015_runtime:   2%|▏         | 7/310 [00:05<03:14,  1.56it/s]
# Examining click:   3%|▎         | 8/310 [00:05<03:13,  1.56it/s]
# Examining matplotlib-base:   3%|▎         | 9/310 [00:05<03:13,  1.56it/s]
# Examining matplotlib-base:   3%|▎         | 10/310 [00:05<02:18,  2.16it/s]
# Examining webencodings:   3%|▎         | 10/310 [00:06<02:18,  2.16it/s]
# Examining webencodings:   4%|▎         | 11/310 [00:06<04:03,  1.23it/s]
# Examining mkl-service:   4%|▎         | 11/310 [00:06<04:03,  1.23it/s]
# Examining locket:   4%|▍         | 12/310 [00:07<04:02,  1.23it/s]
# Examining locket:   4%|▍         | 13/310 [00:07<02:58,  1.67it/s]
# Examining sip:   4%|▍         | 13/310 [00:07<02:58,  1.67it/s]
# Examining pip:   5%|▍         | 14/310 [00:07<02:57,  1.67it/s]
# Examining pip:   5%|▍         | 15/310 [00:07<02:08,  2.29it/s]
# Examining tifffile:   5%|▍         | 15/310 [00:09<02:08,  2.29it/s]
# Examining sphinxcontrib-qthelp:   5%|▌         | 16/310 [00:09<02:08,  2.29it/s]
# Examining sphinxcontrib-qthelp:   5%|▌         | 17/310 [00:10<03:30,  1.39it/s]
# Examining json5:   5%|▌         | 17/310 [00:10<03:30,  1.39it/s]
# Examining regex:   6%|▌         | 18/310 [00:10<03:29,  1.39it/s]
# Examining regex:   6%|▌         | 19/310 [00:10<02:30,  1.93it/s]
# Examining tornado:   6%|▌         | 19/310 [00:10<02:30,  1.93it/s]
# Examining sympy:   6%|▋         | 20/310 [00:10<02:30,  1.93it/s]
# Examining sympy:   7%|▋         | 21/310 [00:10<01:57,  2.47it/s]
# Examining pywin32:   7%|▋         | 21/310 [00:10<01:57,  2.47it/s]
# Examining pywin32:   7%|▋         | 22/310 [00:10<01:44,  2.76it/s]
# Examining python-dateutil:   7%|▋         | 22/310 [00:10<01:44,  2.76it/s]
# Examining hdf5:   7%|▋         | 23/310 [00:10<01:43,  2.76it/s]
# Examining hdf5:   8%|▊         | 24/310 [00:10<01:17,  3.68it/s]
# Examining mkl:   8%|▊         | 24/310 [00:10<01:17,  3.68it/s]
# Examining multipledispatch:   8%|▊         | 25/310 [00:10<01:17,  3.68it/s]
# Examining simplegeneric:   8%|▊         | 26/310 [00:10<01:17,  3.68it/s]
# Examining pywinpty:   9%|▊         | 27/310 [00:10<01:16,  3.68it/s]
# Examining @/win-64::__win==0=0:   9%|▉         | 28/310 [00:10<01:16,  3.68it/s]
# Examining @/win-64::__win==0=0:   9%|▉         | 29/310 [00:10<00:55,  5.07it/s]
# Examining pycodestyle:   9%|▉         | 29/310 [00:10<00:55,  5.07it/s]
# Examining geopandas:  10%|▉         | 30/310 [00:10<00:55,  5.07it/s]
# Examining pyrsistent:  10%|█         | 31/310 [00:11<00:55,  5.07it/s]
# Examining pyrsistent:  10%|█         | 32/310 [00:11<00:54,  5.07it/s]
# Examining setuptools:  10%|█         | 32/310 [00:11<00:54,  5.07it/s]
# Examining patsy:  11%|█         | 33/310 [00:12<00:54,  5.07it/s]
# Examining patsy:  11%|█         | 34/310 [00:12<01:11,  3.88it/s]
# Examining intervaltree:  11%|█         | 34/310 [00:13<01:11,  3.88it/s]
# Examining xmltodict:  11%|█▏        | 35/310 [00:13<01:10,  3.88it/s]
# Examining xmltodict:  12%|█▏        | 36/310 [00:13<01:24,  3.26it/s]
# Examining sphinxcontrib-htmlhelp:  12%|█▏        | 36/310 [00:13<01:24,  3.26it/s]
# Examining pysocks:  12%|█▏        | 37/310 [00:13<01:23,  3.26it/s]
# Examining ipywidgets:  12%|█▏        | 38/310 [00:13<01:23,  3.26it/s]
anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\vierb\\AppData\\Local\\Temp\\pip-install-c8m3jwnd\\fiona\\setup.py'"'"'; __file__='"'"'C:\\Users\\vierb\\AppData\\Local\\Temp\\pip-install-c8m3jwnd\\fiona\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\vierb\AppData\Local\Temp\pip-pip-egg-info-weqxohpt'
#          cwd: C:\Users\vierb\AppData\Local\Temp\pip-install-c8m3jwnd\fiona\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.

# %%
pip install wheel
pip install pipwin

pipwin install numpy
pipwin install pandas
pipwin install shapely
pipwin install gdal
pipwin install fiona
pipwin install pyproj
pipwin install six
pipwin install rtree
pipwin install geopandas

# %%
pip install r"C:\Users\vierb\OneDrive\Área de Trabalho\Projetos\PGC\notebooks\GDAL-3.4.3-pp38-pypy38_pp73-win_amd64.whl"
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Requirement 'rC:\\Users\\vierb\\OneDrive\\Área de Trabalho\\Projetos\\PGC\\notebooks\\GDAL-3.4.3-pp38-pypy38_pp73-win_amd64.whl' looks like a filename, but the file does not exist
# ERROR: Could not install packages due to an EnvironmentError: Bad path: c:\Users\vierb\OneDrive\Área de Trabalho\Projetos\PGC\notebooks\rC:\Users\vierb\OneDrive\Área de Trabalho\Projetos\PGC\notebooks\GDAL-3.4.3-pp38-pypy38_pp73-win_amd64.whl

# %%
# !conda install -c conda-forge gdal

# %%
dict_dfs.keys()
# Out:
# dict_keys(['df_doc_info', 'df_doc_head', 'df_doc_authors', 'df_doc_citations', 'df_doc_authors_citations'])

# %%
    df_doc_info = dict_dfs['df_doc_info'].loc[:,getColumnsWithData(dict_dfs['df_doc_info'])]
    df_doc_head = dict_dfs['df_doc_head'].loc[:,getColumnsWithData(dict_dfs['df_doc_head'])]
    df_doc_authors = dict_dfs['df_doc_authors'].loc[:,getColumnsWithData(dict_dfs['df_doc_authors'])]
    df_doc_authors_citations = dict_dfs['df_doc_authors_citations'].loc[:,getColumnsWithData(dict_dfs['df_doc_authors_citations'])]

# %%
df_doc_info.head()
# Out:
#            grobid_version     grobid_timestamp  \
# article_id
# 1                   0.7.0  2022-05-15 02:11:00
# 2                   0.7.0  2022-05-15 02:09:00
# 3                   0.7.0  2022-05-15 02:10:00
# 4                   0.7.0  2022-05-15 02:09:00
# 5                   0.7.0  2022-05-15 02:09:00
#
#                                      pdf_md5 language_code  \
# article_id
# 1           915208F947D9A8C5F93F958AF4435A39            en
# 2           BD5CAA459269F9DDAEED89D25B28B4C8            en
# 3           A8D795899D1DE7A3D9CDA47F45F8885C            en
# 4           A89985654AE252596EE14410E0DA1F9B            en
# 5           82D64FDF1966AEB1230F90AF465E41BF            en
#
#                                               acknowledgement  \
# article_id
# 1           Acknowledgments This work was supported by the...
# 2                                                         NaN
# 3           Acknowledgements XW would like to thank Yuanch...
# 4           Acknowledgements We want to acknowledge CSC-Sc...
# 5                                            Acknowledgements
#
#                                                      abstract  \
# article_id
# 1           The limitation of traditional Von Neumann arch...
# 2           For successful applications of machine learnin...
# 3           The generalized stacking fault energies (GSFE)...
# 4           Despite their simplicity, the concepts of oxid...
# 5           This paper concerns on the aluminum foam mater...
#
#                                                          body  \
# article_id
# 1           Introduction Traditional computing system has ...
# 2           Introduction To save time and human efforts, m...
# 3           Introduction Refractory metals are metals with...
# 4           Introduction The concept of valency, formulate...
# 5           Introduction As energy crisis intensified, the...
#
#                                                          file      status  \
# article_id
# 1           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 2           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 3           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 4           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
# 5           C:\Users\vierb\OneDrive\Área de Trabalho\Proje...  status 200
#
#                                                      raw_data
# article_id
# 1           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# 2           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# 3           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# 4           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# 5           <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...

# %%
df_doc_info.isnull().sum()
# Out:
# grobid_version        0
# grobid_timestamp      0
# pdf_md5               0
# language_code         0
# acknowledgement     126
# abstract             17
# body                  0
# file                  0
# status                0
# raw_data              0
# dtype: int64

# %%
df_doc_head.head()
# Out:
#              date_head                                         title_head  \
# article_id
# 1           2021-08-06  Linearity improvement of HfO x -based memristo...
# 2           2021-01-29  Transfer learning for materials informatics us...
# 3           2021-03-02  Generalized stacking fault energies and Peierl...
# 4           2019-03-04                    Computational Materials Science
# 5           2013-04-09  Identification of material parameters for alum...
#
#            issn_head                         doi_head arxiv_id_head
# article_id
# 1                NaN       10.1016/j.mssp.2021.106131           NaN
# 2                NaN  10.1016/j.commatsci.2021.110314           NaN
# 3                NaN  10.1016/j.commatsci.2021.110364           NaN
# 4                NaN  10.1016/j.commatsci.2019.01.046           NaN
# 5                NaN  10.1016/j.commatsci.2013.02.024           NaN

# %%
df_doc_head.isnull().sum()
# Out:
# date_head        312
# title_head        10
# issn_head        577
# doi_head          15
# arxiv_id_head    580
# dtype: int64

# %%
df_doc_authors.head()
# Out:
#            full_name_author given_name_author middle_name_author  \
# article_id
# 1              Yutong Jiang            Yutong                NaN
# 1            Kailiang Zhang          Kailiang                NaN
# 1                    Kai Hu               Kai                NaN
# 1              Yujian Zhang            Yujian                NaN
# 1                Ange Liang              Ange                NaN
#
#            surname_author                email_author orcid_author  \
# article_id
# 1                   Jiang                         NaN          NaN
# 1                   Zhang  kailiang_zhang@tjut.edu.cn          NaN
# 1                      Hu                         NaN          NaN
# 1                   Zhang                         NaN          NaN
# 1                   Liang                         NaN          NaN
#
#                           institution_author  \
# article_id
# 1           Tianjin University of Technology
# 1           Tianjin University of Technology
# 1           Tianjin University of Technology
# 1                                        NaN
# 1           Tianjin University of Technology
#
#                                           department_author  \
# article_id
# 1           School of Electrical and Electronic Engineering
# 1           School of Electrical and Electronic Engineering
# 1           School of Electrical and Electronic Engineering
# 1                                                       NaN
# 1           School of Electrical and Electronic Engineering
#
#                                             laboratory_author  \
# article_id
# 1           Tianjin Key Laboratory of Film Electronic and ...
# 1           Tianjin Key Laboratory of Film Electronic and ...
# 1           Tianjin Key Laboratory of Film Electronic and ...
# 1                                                         NaN
# 1           Tianjin Key Laboratory of Film Electronic and ...
#
#            addr_line_author post_code_author settlement_author country_author
# article_id
# 1                       NaN           300384           Tianjin       PR China
# 1                       NaN           300384           Tianjin       PR China
# 1                       NaN           300384           Tianjin       PR China
# 1                       NaN              NaN               NaN            NaN
# 1                       NaN           300384           Tianjin       PR China

# %%
df_doc_authors.isnull().sum()
# Out:
# full_name_author         8
# given_name_author       45
# middle_name_author    2036
# surname_author           8
# email_author          2107
# orcid_author          2599
# institution_author     465
# department_author      749
# laboratory_author     2319
# addr_line_author      2140
# post_code_author       889
# settlement_author      584
# country_author         398
# dtype: int64

# %%
df_doc_authors_citations.head()
# Out:
#             id  index full_name_citation given_name_citation  \
# article_id
# 1           b0      0           H L Park                   H
# 1           b0      0              Y Lee                   Y
# 1           b0      0              N Kim                   N
# 1           b0      0            D G Seo                   D
# 1           b0      0             G T Go                   G
#
#            middle_name_citation surname_citation
# article_id
# 1                             L             Park
# 1                           NaN              Lee
# 1                           NaN              Kim
# 1                             G              Seo
# 1                             T               Go

# %%
df_doc_authors_citations.isnull().sum()
# Out:
# id                          0
# index                       0
# full_name_citation        766
# given_name_citation      2024
# middle_name_citation    84248
# surname_citation         1634
# dtype: int64

# %%
dict_dfs.keys()
# Out:
# dict_keys(['df_doc_info', 'df_doc_head', 'df_doc_authors', 'df_doc_citations', 'df_doc_authors_citations'])

# %%
dict_dfs['df_doc_authors_citations'].head()
# Out:
#             id  index full_name_citation given_name_citation  \
# article_id
# 1           b0      0           H L Park                   H
# 1           b0      0              Y Lee                   Y
# 1           b0      0              N Kim                   N
# 1           b0      0            D G Seo                   D
# 1           b0      0             G T Go                   G
#
#            middle_name_citation surname_citation  email_citation  \
# article_id
# 1                             L             Park             NaN
# 1                           NaN              Lee             NaN
# 1                           NaN              Kim             NaN
# 1                             G              Seo             NaN
# 1                             T               Go             NaN
#
#             orcid_citation  institution_citation  department_citation  \
# article_id
# 1                      NaN                   NaN                  NaN
# 1                      NaN                   NaN                  NaN
# 1                      NaN                   NaN                  NaN
# 1                      NaN                   NaN                  NaN
# 1                      NaN                   NaN                  NaN
#
#             laboratory_citation  addr_line_citation  post_code_citation  \
# article_id
# 1                           NaN                 NaN                 NaN
# 1                           NaN                 NaN                 NaN
# 1                           NaN                 NaN                 NaN
# 1                           NaN                 NaN                 NaN
# 1                           NaN                 NaN                 NaN
#
#             settlement_citation  country_citation
# article_id
# 1                           NaN               NaN
# 1                           NaN               NaN
# 1                           NaN               NaN
# 1                           NaN               NaN
# 1                           NaN               NaN

# %%
dict_dfs['df_doc_authors_citations'].head().T
# Out:
# article_id                   1      1      1        1       1
# id                          b0     b0     b0       b0      b0
# index                        0      0      0        0       0
# full_name_citation    H L Park  Y Lee  N Kim  D G Seo  G T Go
# given_name_citation          H      Y      N        D       G
# middle_name_citation         L    NaN    NaN        G       T
# surname_citation          Park    Lee    Kim      Seo      Go
# email_citation             NaN    NaN    NaN      NaN     NaN
# orcid_citation             NaN    NaN    NaN      NaN     NaN
# institution_citation       NaN    NaN    NaN      NaN     NaN
# department_citation        NaN    NaN    NaN      NaN     NaN
# laboratory_citation        NaN    NaN    NaN      NaN     NaN
# addr_line_citation         NaN    NaN    NaN      NaN     NaN
# post_code_citation         NaN    NaN    NaN      NaN     NaN
# settlement_citation        NaN    NaN    NaN      NaN     NaN
# country_citation           NaN    NaN    NaN      NaN     NaN
