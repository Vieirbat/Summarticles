# %% [markdown]
# # Usando processo bath em um conjunto maior de artigos - Cliente do GROBID:

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ### Importando dependências

# %%
import os
import sys
import re

sys.path.insert(0,os.path.dirname(os.getcwd()))
sys.path.insert(0,os.path.join(os.getcwd(),'grobid'))
sys.path.insert(0,os.getcwd())

import numpy as np
import pandas as pd

from grobid import grobid_client
import grobid_tei_xml
from grobid_to_dataframe import grobid_cli, xmltei_to_dataframe

import plotly

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ### Comandos Docker

# %% [markdown]
# docker run -t --rm --init -p 8080:8070 -p 8081:8071 --memory="9g" lfoppiano/grobid:0.7.0
#
# docker run -t --rm --init -p 8080:8070 -p 8081:8071 lfoppiano/grobid:0.6.2

# %% [markdown]
# pip install grobid-tei-xml

# %% [markdown]
# ### Definindo variáveis e caminhos

# %%
path = os.path.dirname(os.getcwd())
path_input = os.path.join(path,'artifacts','test_article')
path_output = os.path.join(path,'output','xml')
path_article = os.path.join(path,'artifacts','test_article','b617684b.pdf')

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ### Definindo variáveis e caminhos

# %%
def get_path(path_input_path):
    """"""
    if os.path.exists(path_input_path):
        return path_input_path
    
    return os.getcwd()


def batch_process_path(path_input_path, config_path="./grobid/config.json"):
    """"""
    gcli = grobid_cli(config_path=config_path)
    result_batch = gcli.process_pdfs(input_path=path_input_path,
                                     n_workers=2,
                                     service="processFulltextDocument",
                                     generateIDs=True,
                                     include_raw_citations=True,
                                     include_raw_affiliations=True,
                                     consolidate_header=False,
                                     consolidate_citations=False,
                                     tei_coordinates=False,
                                     segment_sentences=True,
                                     verbose=True)
    return result_batch


def get_dataframes(result_batch):
    """"""
    xml_to_df = xmltei_to_dataframe()
    dict_dfs = xml_to_df.get_dataframe_articles(result_batch)
    
    return dict_dfs

def files_path(path):
    list_dir = os.listdir(path)
    files = []
    for file in list_dir:
        if os.path.isfile(os.path.join(path,file)):
            files.append(os.path.join(path,file))
    return files

# %%
def run_batch_process(path_input):

    # path_input = os.path.join(path,'artifacts','test_article')
    path_input_path = get_path(path_input)
    
    result_batch = batch_process_path(path_input_path)
    dict_dfs = get_dataframes(result_batch)
    
    print('[Process has been finished!!!]')
    
    return dict_dfs

# %%
gcli = grobid_cli(config_path="./grobid/config.json")
# Out:
# GROBID server is up and running

# %%
input_folder_path = """C:/Users/vierb/OneDrive/Área de Trabalho/Projetos/PGC/artifacts/test_article"""

# %%
dict_dfs = run_batch_process(input_folder_path)

# %%
result_batch = gcli.process_pdfs(input_path=path_input,
                                 n_workers=2,
                                 service="processFulltextDocument",
                                 generateIDs=True,
                                 include_raw_citations=True,
                                 include_raw_affiliations=True,
                                 consolidate_header=False,
                                 consolidate_citations=False,
                                 tei_coordinates=False,
                                 segment_sentences=True,
                                 verbose=True)
# Out:
# 2 files to process in current batch

# %% [markdown]
# https://komax.github.io/blog/text/mining/grobid/
#
# https://komax.github.io/blog/text/python/xml/parsing_tei_xml_python/
#
# https://github.com/allenai/s2orc-doc2json
#
# https://gitlab.com/internetarchive/grobid_tei_xml
#
# https://github.com/delb-xml/delb-py

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ### Transformando JSON em um DataFrame

# %% [markdown]
# - Há as seguintes entendidades: artigo, autores, instituições e referências;
# - Compondo uma publicação científica;
#     - Dentro do artigo temos várias informações da entidade de dados;
#     - E as referências possuem vários artigos, uma lista de artigos;

# %%
xml_to_df = xmltei_to_dataframe()

# %%
import concurrent

# %%
dict_dfs = xml_to_df.get_dataframe_articles(result_batch)

# %%
dict_dfs.keys()
# Out:
# dict_keys(['df_doc_info', 'df_doc_head', 'df_doc_authors', 'df_doc_citations', 'df_doc_authors_citations'])

# %%
dict_dfs['df_doc_info']
# Out:
#                                  grobid_version     grobid_timestamp  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2          0.7.0  2022-04-25 22:06:00
# EDC05F16295D6502DECA9A504932B81E          0.7.0  2022-04-25 22:06:00
#
#                                  language_code  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2            en
# EDC05F16295D6502DECA9A504932B81E            en
#
#                                                                     acknowledgement  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  Acknowledgements This work was carried out wit...
# EDC05F16295D6502DECA9A504932B81E  Acknowledgements This work was supported by th...
#
#                                                                            abstract  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  This article surveys and highlights the integr...
# EDC05F16295D6502DECA9A504932B81E  We have performed powder neutron diffraction m...
#
#                                                                                body  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  Introduction It is foreseeable that artificial...
# EDC05F16295D6502DECA9A504932B81E  Introduction In recent years, the solid-state ...
#
#                                   annex   \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2     NaN
# EDC05F16295D6502DECA9A504932B81E     NaN
#
#                                                                                file  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  c:\Users\vierb\OneDrive\Área de Trabalho\Proje...
# EDC05F16295D6502DECA9A504932B81E  c:\Users\vierb\OneDrive\Área de Trabalho\Proje...
#
#                                   status  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2     200
# EDC05F16295D6502DECA9A504932B81E     200
#
#                                                                            raw_data
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...
# EDC05F16295D6502DECA9A504932B81E  <?xml version="1.0" encoding="UTF-8"?>\n<TEI x...

# %%
list_chars = []
for id,row in dict_dfs['df_doc_info'].iterrows():
    for c in row['raw_data']:
        list_chars.append(c)
        
df_counts = pd.DataFrame({'chars':pd.value_counts(list_chars).index.tolist(),'counts':pd.value_counts(list_chars).tolist()})
df_counts = df_counts.sort_values(by='counts',ascending=False)

import plotly.express as px
fig = px.bar(df_counts.head(20), x='chars', y='counts')
fig.show()

# %%
df_counts.sort_values(by='counts',ascending=False)
# Out:
#     chars  counts
# 0       e   22756
# 1           19787
# 2       r   14747
# 3       a   14519
# 4       t   12488
# ..    ...     ...
# 101     ?       4
# 102     *       3
# 103     $       2
# 104     ¯       2
# 105     @       2
#
# [106 rows x 2 columns]

# %%
dict_dfs['df_doc_head'].T
# Out:
# pdf_md5                               5B70A65B9D2AEC3DD3E6A64B4BD94CB2  \
# index_head                                                         NaN
# id_head                                                            NaN
# unstructured_head                                                  NaN
# date_head                                                   2007-02-08
# title_head           Nanometer scale carbon structures for charge-t...
# book_title_head                                                    NaN
# series_title_head                                                  NaN
# journal_head                                                       NaN
# journal_abbrev_head                                                NaN
# publisher_head                                                     NaN
# institution_head                                                   NaN
# issn_head                                                          NaN
# eissn_head                                                         NaN
# volume_head                                                        NaN
# issue_head                                                         NaN
# pages_head                                                         NaN
# first_page_head                                                    NaN
# last_page_head                                                     NaN
# note_head                                                          NaN
# doi_head                                              10.1039/b617684b
# pmid_head                                                          NaN
# pmcid_head                                                         NaN
# arxiv_id_head                                                      NaN
# ark_head                                                           NaN
# istex_id_head                                                      NaN
# url_head                                                           NaN
#
# pdf_md5                               EDC05F16295D6502DECA9A504932B81E
# index_head                                                         NaN
# id_head                                                            NaN
# unstructured_head                                                  NaN
# date_head                                                   2000-06-21
# title_head           Magnetic properties and crystal structures of ...
# book_title_head                                                    NaN
# series_title_head                                                  NaN
# journal_head                                                       NaN
# journal_abbrev_head                                                NaN
# publisher_head                                                     NaN
# institution_head                                                   NaN
# issn_head                                                          NaN
# eissn_head                                                         NaN
# volume_head                                                        NaN
# issue_head                                                         NaN
# pages_head                                                         NaN
# first_page_head                                                    NaN
# last_page_head                                                     NaN
# note_head                                                          NaN
# doi_head                                              10.1039/b000689k
# pmid_head                                                          NaN
# pmcid_head                                                         NaN
# arxiv_id_head                                                      NaN
# ark_head                                                           NaN
# istex_id_head                                                      NaN
# url_head                                                           NaN

# %%
dict_dfs['df_doc_authors'].T
# Out:
# pdf_md5                            5B70A65B9D2AEC3DD3E6A64B4BD94CB2  \
# full_name_author                                       Dirk M Guldi
# given_name_author                                              Dirk
# middle_name_author                                                M
# surname_author                                                Guldi
# email_author                                                    NaN
# orcid_author                                                    NaN
# institution_author                            Universita¨t Erlangen
# department_author   Institute of Physical and Theoretical Chemistry
# laboratory_author                                               NaN
# addr_line_author                                                NaN
# post_code_author                                              91058
# settlement_author                                          Erlangen
# country_author                                              Germany
#
# pdf_md5            EDC05F16295D6502DECA9A504932B81E  \
# full_name_author                      Yoshihiro Doi
# given_name_author                         Yoshihiro
# middle_name_author                              NaN
# surname_author                                  Doi
# email_author                                    NaN
# orcid_author                                    NaN
# institution_author              Hokkaido University
# department_author        Graduate School of Science
# laboratory_author                               NaN
# addr_line_author                                NaN
# post_code_author                           060-0810
# settlement_author                           Sapporo
# country_author                                Japan
#
# pdf_md5            EDC05F16295D6502DECA9A504932B81E  \
# full_name_author                      Yukio Hinatsu
# given_name_author                             Yukio
# middle_name_author                              NaN
# surname_author                              Hinatsu
# email_author                                    NaN
# orcid_author                                    NaN
# institution_author              Hokkaido University
# department_author        Graduate School of Science
# laboratory_author                               NaN
# addr_line_author                                NaN
# post_code_author                           060-0810
# settlement_author                           Sapporo
# country_author                                Japan
#
# pdf_md5                   EDC05F16295D6502DECA9A504932B81E  \
# full_name_author                           Ken-Ichi Oikawa
# given_name_author                                 Ken-Ichi
# middle_name_author                                     NaN
# surname_author                                      Oikawa
# email_author                                           NaN
# orcid_author                                           NaN
# institution_author  Japan Atomic Energy Research Institute
# department_author                                      NaN
# laboratory_author                                      NaN
# addr_line_author                                       NaN
# post_code_author                                  319-1195
# settlement_author                      Tokai-mura, Ibaraki
# country_author                                       Japan
#
# pdf_md5                   EDC05F16295D6502DECA9A504932B81E  \
# full_name_author                            Yutaka Shimojo
# given_name_author                                   Yutaka
# middle_name_author                                     NaN
# surname_author                                     Shimojo
# email_author                                           NaN
# orcid_author                                           NaN
# institution_author  Japan Atomic Energy Research Institute
# department_author                                      NaN
# laboratory_author                                      NaN
# addr_line_author                                       NaN
# post_code_author                                  319-1195
# settlement_author                      Tokai-mura, Ibaraki
# country_author                                       Japan
#
# pdf_md5                   EDC05F16295D6502DECA9A504932B81E
# full_name_author                               Yukio Morii
# given_name_author                                    Yukio
# middle_name_author                                     NaN
# surname_author                                       Morii
# email_author                                           NaN
# orcid_author                                           NaN
# institution_author  Japan Atomic Energy Research Institute
# department_author                                      NaN
# laboratory_author                                      NaN
# addr_line_author                                       NaN
# post_code_author                                  319-1195
# settlement_author                      Tokai-mura, Ibaraki
# country_author                                       Japan

# %%
dict_dfs['df_doc_citations']
# Out:
#                                   index_citation id_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2               0          b0
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2               1          b1
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2               2          b2
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2               3          b3
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2               4          b4
# ...                                          ...         ...
# EDC05F16295D6502DECA9A504932B81E               4          b4
# EDC05F16295D6502DECA9A504932B81E               5          b5
# EDC05F16295D6502DECA9A504932B81E               6          b6
# EDC05F16295D6502DECA9A504932B81E               7          b7
# EDC05F16295D6502DECA9A504932B81E               8          b8
#
#                                                               unstructured_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  Basic Research Needs for Solar Energy Utilizat...
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  V. Balzani, Electron Transfer in Chemistry, Wi...
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  A. Hirsch and M. Brettreich, Fullerenes: Chemi...
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  F. Diederich, L. Isaacs and D. Philp, Chem. So...
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  S. Reich, C. Thomsen and J. Maultzsch, Carbon ...
# ...                                                                             ...
# EDC05F16295D6502DECA9A504932B81E  P. D. Battle, C. W. Jones and F. Studer, J. So...
# EDC05F16295D6502DECA9A504932B81E  D. Harada, M. Wakeshima and Y. Hinatsu, J. Sol...
# EDC05F16295D6502DECA9A504932B81E  D. Harada, M. Wakeshima, Y. Hinatsu K. Ohoyama...
# EDC05F16295D6502DECA9A504932B81E  F. Izumi, in The Rietveld Method, ed. R. A. Yo...
# EDC05F16295D6502DECA9A504932B81E  K. Tezuka, Y. Hinatsu, K. Oikawa, Y. Shimojo a...
#
#                                  date_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2          2005
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2          2001
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2          2000
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2          1994
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2          2004
# ...                                        ...
# EDC05F16295D6502DECA9A504932B81E          1991
# EDC05F16295D6502DECA9A504932B81E          1999
# EDC05F16295D6502DECA9A504932B81E          2000
# EDC05F16295D6502DECA9A504932B81E          1993
# EDC05F16295D6502DECA9A504932B81E          2000
#
#                                                                      title_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  Basic Research Needs for Solar Energy Utilization
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                     Electron Transfer in Chemistry
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  Fullerenes: From Synthesis to Optoelectronic P...
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                                NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  Carbon Nanotubes: Basic Concepts and Physical ...
# ...                                                                             ...
# EDC05F16295D6502DECA9A504932B81E                                                NaN
# EDC05F16295D6502DECA9A504932B81E                                                NaN
# EDC05F16295D6502DECA9A504932B81E                                                NaN
# EDC05F16295D6502DECA9A504932B81E                                The Rietveld Method
# EDC05F16295D6502DECA9A504932B81E                                                NaN
#
#                                                                 book_title_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                                NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                                NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  Nuclear and Radiation Chemical Approaches to F...
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                                NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                                NaN
# ...                                                                             ...
# EDC05F16295D6502DECA9A504932B81E                                                NaN
# EDC05F16295D6502DECA9A504932B81E                                                NaN
# EDC05F16295D6502DECA9A504932B81E                                                NaN
# EDC05F16295D6502DECA9A504932B81E                                                NaN
# EDC05F16295D6502DECA9A504932B81E                                                NaN
#
#                                  series_title_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                   NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                   NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                   NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                   NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                   NaN
# ...                                                ...
# EDC05F16295D6502DECA9A504932B81E                   NaN
# EDC05F16295D6502DECA9A504932B81E                   NaN
# EDC05F16295D6502DECA9A504932B81E                   NaN
# EDC05F16295D6502DECA9A504932B81E                   NaN
# EDC05F16295D6502DECA9A504932B81E                   NaN
#
#                                                                    journal_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  Report of the Basic Energy Sciences Workshop o...
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                           Weinheim
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                                NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                  Compt. Rend. Chim
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                                NaN
# ...                                                                             ...
# EDC05F16295D6502DECA9A504932B81E                                J. Solid State Chem
# EDC05F16295D6502DECA9A504932B81E                                J. Solid State Chem
# EDC05F16295D6502DECA9A504932B81E                          J. Phys.: Condens. Matter
# EDC05F16295D6502DECA9A504932B81E                                                NaN
# EDC05F16295D6502DECA9A504932B81E                          J. Phys.: Condens. Matter
#
#                                   journal_abbrev_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                      NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                      NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                      NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                      NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                      NaN
# ...                                                   ...
# EDC05F16295D6502DECA9A504932B81E                      NaN
# EDC05F16295D6502DECA9A504932B81E                      NaN
# EDC05F16295D6502DECA9A504932B81E                      NaN
# EDC05F16295D6502DECA9A504932B81E                      NaN
# EDC05F16295D6502DECA9A504932B81E                      NaN
#
#                                        publisher_citation  ...  \
# pdf_md5                                                    ...
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                      NaN  ...
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                Wiley-VCH  ...
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2          Kluwer Academic  ...
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                      NaN  ...
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                Wiley-VCH  ...
# ...                                                   ...  ...
# EDC05F16295D6502DECA9A504932B81E                      NaN  ...
# EDC05F16295D6502DECA9A504932B81E                      NaN  ...
# EDC05F16295D6502DECA9A504932B81E                      NaN  ...
# EDC05F16295D6502DECA9A504932B81E  Oxford University Press  ...
# EDC05F16295D6502DECA9A504932B81E                      NaN  ...
#
#                                   first_page_citation  last_page_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                  NaN                 NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                  NaN                 NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                  NaN                 NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                  NaN                 NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                  NaN                 NaN
# ...                                               ...                 ...
# EDC05F16295D6502DECA9A504932B81E                  NaN                 NaN
# EDC05F16295D6502DECA9A504932B81E                  NaN                 NaN
# EDC05F16295D6502DECA9A504932B81E                  NaN                 NaN
# EDC05F16295D6502DECA9A504932B81E                  NaN                 NaN
# EDC05F16295D6502DECA9A504932B81E                  NaN                 NaN
#
#                                                                    note_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                             NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                             NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  Fullerenes: Chemistry, Physics, and Technology
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                 Chem. Soc. Rev.
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                             NaN
# ...                                                                          ...
# EDC05F16295D6502DECA9A504932B81E                                             NaN
# EDC05F16295D6502DECA9A504932B81E                                             NaN
# EDC05F16295D6502DECA9A504932B81E                                             NaN
# EDC05F16295D6502DECA9A504932B81E                                             NaN
# EDC05F16295D6502DECA9A504932B81E                                             NaN
#
#                                  doi_citation  pmid_citation pmcid_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2          NaN            NaN            NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2          NaN            NaN            NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2          NaN            NaN            NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2          NaN            NaN            NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2          NaN            NaN            NaN
# ...                                       ...            ...            ...
# EDC05F16295D6502DECA9A504932B81E          NaN            NaN            NaN
# EDC05F16295D6502DECA9A504932B81E          NaN            NaN            NaN
# EDC05F16295D6502DECA9A504932B81E          NaN            NaN            NaN
# EDC05F16295D6502DECA9A504932B81E          NaN            NaN            NaN
# EDC05F16295D6502DECA9A504932B81E          NaN            NaN            NaN
#
#                                   arxiv_id_citation  ark_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                NaN           NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                NaN           NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                NaN           NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                NaN           NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                NaN           NaN
# ...                                             ...           ...
# EDC05F16295D6502DECA9A504932B81E                NaN           NaN
# EDC05F16295D6502DECA9A504932B81E                NaN           NaN
# EDC05F16295D6502DECA9A504932B81E                NaN           NaN
# EDC05F16295D6502DECA9A504932B81E                NaN           NaN
# EDC05F16295D6502DECA9A504932B81E                NaN           NaN
#
#                                  istex_id_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2               NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2               NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2               NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2               NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2               NaN
# ...                                            ...
# EDC05F16295D6502DECA9A504932B81E               NaN
# EDC05F16295D6502DECA9A504932B81E               NaN
# EDC05F16295D6502DECA9A504932B81E               NaN
# EDC05F16295D6502DECA9A504932B81E               NaN
# EDC05F16295D6502DECA9A504932B81E               NaN
#
#                                                                        url_citation
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  http://www.sc.doe.gov/bes/reports/files/SEU_rp...
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                                NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                                NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                                NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                                                NaN
# ...                                                                             ...
# EDC05F16295D6502DECA9A504932B81E                                                NaN
# EDC05F16295D6502DECA9A504932B81E                                                NaN
# EDC05F16295D6502DECA9A504932B81E                                                NaN
# EDC05F16295D6502DECA9A504932B81E                                                NaN
# EDC05F16295D6502DECA9A504932B81E                                                NaN
#
# [88 rows x 26 columns]

# %%
dict_dfs['df_doc_authors_citations']
# Out:
#                                   id  index full_name_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  b0      0                NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  b1      1          V Balzani
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  b2      2           A Hirsch
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  b2      2       M Brettreich
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2  b2      2       : Fullerenes
# ...                               ..    ...                ...
# EDC05F16295D6502DECA9A504932B81E  b8      8           K Tezuka
# EDC05F16295D6502DECA9A504932B81E  b8      8          Y Hinatsu
# EDC05F16295D6502DECA9A504932B81E  b8      8           K Oikawa
# EDC05F16295D6502DECA9A504932B81E  b8      8          Y Shimojo
# EDC05F16295D6502DECA9A504932B81E  b8      8            Y Morii
#
#                                  given_name_citation middle_name_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                 NaN                  NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                   V                  NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                   A                  NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                   M                  NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                   :                  NaN
# ...                                              ...                  ...
# EDC05F16295D6502DECA9A504932B81E                   K                  NaN
# EDC05F16295D6502DECA9A504932B81E                   Y                  NaN
# EDC05F16295D6502DECA9A504932B81E                   K                  NaN
# EDC05F16295D6502DECA9A504932B81E                   Y                  NaN
# EDC05F16295D6502DECA9A504932B81E                   Y                  NaN
#
#                                  surname_citation  email_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2              NaN             NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2          Balzani             NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2           Hirsch             NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2       Brettreich             NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2       Fullerenes             NaN
# ...                                           ...             ...
# EDC05F16295D6502DECA9A504932B81E           Tezuka             NaN
# EDC05F16295D6502DECA9A504932B81E          Hinatsu             NaN
# EDC05F16295D6502DECA9A504932B81E           Oikawa             NaN
# EDC05F16295D6502DECA9A504932B81E          Shimojo             NaN
# EDC05F16295D6502DECA9A504932B81E            Morii             NaN
#
#                                   orcid_citation  institution_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2             NaN                   NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2             NaN                   NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2             NaN                   NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2             NaN                   NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2             NaN                   NaN
# ...                                          ...                   ...
# EDC05F16295D6502DECA9A504932B81E             NaN                   NaN
# EDC05F16295D6502DECA9A504932B81E             NaN                   NaN
# EDC05F16295D6502DECA9A504932B81E             NaN                   NaN
# EDC05F16295D6502DECA9A504932B81E             NaN                   NaN
# EDC05F16295D6502DECA9A504932B81E             NaN                   NaN
#
#                                   department_citation  laboratory_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                  NaN                  NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                  NaN                  NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                  NaN                  NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                  NaN                  NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                  NaN                  NaN
# ...                                               ...                  ...
# EDC05F16295D6502DECA9A504932B81E                  NaN                  NaN
# EDC05F16295D6502DECA9A504932B81E                  NaN                  NaN
# EDC05F16295D6502DECA9A504932B81E                  NaN                  NaN
# EDC05F16295D6502DECA9A504932B81E                  NaN                  NaN
# EDC05F16295D6502DECA9A504932B81E                  NaN                  NaN
#
#                                   addr_line_citation  post_code_citation  \
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                 NaN                 NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                 NaN                 NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                 NaN                 NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                 NaN                 NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                 NaN                 NaN
# ...                                              ...                 ...
# EDC05F16295D6502DECA9A504932B81E                 NaN                 NaN
# EDC05F16295D6502DECA9A504932B81E                 NaN                 NaN
# EDC05F16295D6502DECA9A504932B81E                 NaN                 NaN
# EDC05F16295D6502DECA9A504932B81E                 NaN                 NaN
# EDC05F16295D6502DECA9A504932B81E                 NaN                 NaN
#
#                                   settlement_citation  country_citation
# pdf_md5
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                  NaN               NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                  NaN               NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                  NaN               NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                  NaN               NaN
# 5B70A65B9D2AEC3DD3E6A64B4BD94CB2                  NaN               NaN
# ...                                               ...               ...
# EDC05F16295D6502DECA9A504932B81E                  NaN               NaN
# EDC05F16295D6502DECA9A504932B81E                  NaN               NaN
# EDC05F16295D6502DECA9A504932B81E                  NaN               NaN
# EDC05F16295D6502DECA9A504932B81E                  NaN               NaN
# EDC05F16295D6502DECA9A504932B81E                  NaN               NaN
#
# [754 rows x 15 columns]

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.8.1-py2.py3-none-any.whl (10.1 MB)
# Requirement already satisfied: requests in c:\users\vierb\anaconda3\lib\site-packages (from streamlit) (2.24.0)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\vierb\anaconda3\lib\site-packages (from streamlit) (2.0.0)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
# Requirement already satisfied: pandas>=0.21.0 in c:\users\vierb\anaconda3\lib\site-packages (from streamlit) (1.1.3)
# Collecting validators
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Requirement already satisfied: watchdog; platform_system != "Darwin" in c:\users\vierb\anaconda3\lib\site-packages (from streamlit) (0.10.3)
# Requirement already satisfied: click<8.1,>=7.0 in c:\users\vierb\anaconda3\lib\site-packages (from streamlit) (7.1.2)
# Requirement already satisfied: attrs in c:\users\vierb\anaconda3\lib\site-packages (from streamlit) (20.3.0)
# Requirement already satisfied: toml in c:\users\vierb\anaconda3\lib\site-packages (from streamlit) (0.10.1)
# Collecting protobuf!=3.11,>=3.6.0
#   Downloading protobuf-3.20.1-cp38-cp38-win_amd64.whl (904 kB)
# Collecting pyarrow
#   Downloading pyarrow-7.0.0-cp38-cp38-win_amd64.whl (16.1 MB)
# Requirement already satisfied: python-dateutil in c:\users\vierb\anaconda3\lib\site-packages (from streamlit) (2.8.1)
# Collecting tzlocal
#   Downloading tzlocal-4.2-py3-none-any.whl (19 kB)
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
# Requirement already satisfied: tornado>=5.0 in c:\users\vierb\anaconda3\lib\site-packages (from streamlit) (6.0.4)
# Collecting altair>=3.2.0
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
# Requirement already satisfied: packaging in c:\users\vierb\anaconda3\lib\site-packages (from streamlit) (20.4)
# Collecting cachetools>=4.0
#   Downloading cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vierb\anaconda3\lib\site-packages (from streamlit) (8.0.1)
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy in c:\users\vierb\anaconda3\lib\site-packages (from streamlit) (1.19.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\vierb\anaconda3\lib\site-packages (from requests->streamlit) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\vierb\anaconda3\lib\site-packages (from requests->streamlit) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\vierb\anaconda3\lib\site-packages (from requests->streamlit) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vierb\anaconda3\lib\site-packages (from requests->streamlit) (2020.6.20)
# Requirement already satisfied: ipykernel>=5.1.2; python_version >= "3.4" in c:\users\vierb\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.3.4)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\vierb\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (5.0.5)
# Requirement already satisfied: jinja2>=2.10.1 in c:\users\vierb\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (2.11.2)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\vierb\anaconda3\lib\site-packages (from pydeck>=0.1.dev5->streamlit) (7.5.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\vierb\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.4.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
# Requirement already satisfied: pytz>=2017.2 in c:\users\vierb\anaconda3\lib\site-packages (from pandas>=0.21.0->streamlit) (2020.1)
# Requirement already satisfied: six>=1.4.0 in c:\users\vierb\anaconda3\lib\site-packages (from validators->streamlit) (1.15.0)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\vierb\anaconda3\lib\site-packages (from validators->streamlit) (4.4.2)
# Requirement already satisfied: pathtools>=0.1.1 in c:\users\vierb\anaconda3\lib\site-packages (from watchdog; platform_system != "Darwin"->streamlit) (0.1.2)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting backports.zoneinfo; python_version < "3.9"
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-win_amd64.whl (38 kB)
# Collecting tzdata; platform_system == "Windows"
#   Downloading tzdata-2022.1-py2.py3-none-any.whl (339 kB)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\vierb\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (3.2.0)
# Requirement already satisfied: entrypoints in c:\users\vierb\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: toolz in c:\users\vierb\anaconda3\lib\site-packages (from altair>=3.2.0->streamlit) (0.11.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\vierb\anaconda3\lib\site-packages (from packaging->streamlit) (2.4.7)
# Requirement already satisfied: jupyter-client in c:\users\vierb\anaconda3\lib\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (6.1.7)
# Requirement already satisfied: ipython>=5.0.0 in c:\users\vierb\anaconda3\lib\site-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (7.19.0)
# Requirement already satisfied: ipython-genutils in c:\users\vierb\anaconda3\lib\site-packages (from traitlets>=4.3.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\vierb\anaconda3\lib\site-packages (from jinja2>=2.10.1->pydeck>=0.1.dev5->streamlit) (1.1.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\vierb\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.0.8)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\vierb\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\vierb\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (0.17.3)
# Requirement already satisfied: setuptools in c:\users\vierb\anaconda3\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit) (51.2.0)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\vierb\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (4.6.3)
# Requirement already satisfied: pyzmq>=13 in c:\users\vierb\anaconda3\lib\site-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (19.0.2)
# Requirement already satisfied: pygments in c:\users\vierb\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (2.7.2)
# Requirement already satisfied: jedi>=0.10 in c:\users\vierb\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.17.1)
# Requirement already satisfied: pickleshare in c:\users\vierb\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\vierb\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (3.0.8)
# Requirement already satisfied: backcall in c:\users\vierb\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\vierb\anaconda3\lib\site-packages (from ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\vierb\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.1.4)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in c:\users\vierb\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (227)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\vierb\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\vierb\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: Send2Trash in c:\users\vierb\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: prometheus-client in c:\users\vierb\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\vierb\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.9.1)
# Requirement already satisfied: argon2-cffi in c:\users\vierb\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (20.1.0)
# Requirement already satisfied: nbconvert in c:\users\vierb\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (6.0.7)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\vierb\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\vierb\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.14.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\vierb\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.3)
# Requirement already satisfied: defusedxml in c:\users\vierb\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.6.0)
# Requirement already satisfied: bleach in c:\users\vierb\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.2.1)
# Requirement already satisfied: testpath in c:\users\vierb\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\vierb\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\vierb\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\vierb\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: pycparser in c:\users\vierb\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.20)
# Requirement already satisfied: webencodings in c:\users\vierb\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)
# Requirement already satisfied: async-generator in c:\users\vierb\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\vierb\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.2)
# Building wheels for collected packages: blinker
#   Building wheel for blinker (setup.py): started
#   Building wheel for blinker (setup.py): finished with status 'done'
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13454 sha256=e583bbe8daf0e9eda96407d3265d3e2b55828835ff2dcc46cec10aac555a0beb
#   Stored in directory: c:\users\vierb\appdata\local\pip\cache\wheels\b7\a5\68\fe632054a5eadd531c7a49d740c50eb6adfbeca822b4eab8d4
# Successfully built blinker
# Installing collected packages: blinker, pydeck, smmap, gitdb, gitpython, validators, protobuf, pyarrow, tzdata, backports.zoneinfo, pytz-deprecation-shim, tzlocal, pympler, altair, cachetools, semver, streamlit
# Successfully installed altair-4.2.0 backports.zoneinfo-0.2.1 blinker-1.4 cachetools-5.0.0 gitdb-4.0.9 gitpython-3.1.27 protobuf-3.20.1 pyarrow-7.0.0 pydeck-0.7.1 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 semver-2.13.0 smmap-5.0.0 streamlit-1.8.1 tzdata-2022.1 tzlocal-4.2 validators-0.18.2
