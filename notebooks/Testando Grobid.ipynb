# %% [markdown]
# # Testando Cliente do GROBID:

# %%
import numpy as np
import pandas as pd
import os
import sys
import re

# %%
# !pip install pygrobid
# Out:
# Collecting pygrobid
#   Downloading pygrobid-0.1.6.tar.gz (3.8 kB)
# Requirement already satisfied: requests in c:\users\vierb\anaconda3\lib\site-packages (from pygrobid) (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\vierb\anaconda3\lib\site-packages (from requests->pygrobid) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\vierb\anaconda3\lib\site-packages (from requests->pygrobid) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\vierb\anaconda3\lib\site-packages (from requests->pygrobid) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vierb\anaconda3\lib\site-packages (from requests->pygrobid) (2020.6.20)
# Building wheels for collected packages: pygrobid
#   Building wheel for pygrobid (setup.py): started
#   Building wheel for pygrobid (setup.py): finished with status 'done'
#   Created wheel for pygrobid: filename=pygrobid-0.1.6-py3-none-any.whl size=3961 sha256=eb163f51e5a318eb4b532de285ceeb47ddf975eeb175ccbce8710e1383784299
#   Stored in directory: c:\users\vierb\appdata\local\pip\cache\wheels\6d\5b\72\7926d204710863d439328bf895614d1c2bc18d50653c9bae7d
# Successfully built pygrobid
# Installing collected packages: pygrobid
# Successfully installed pygrobid-0.1.6

# %%
from grobid.client import GrobidClient

# %%
host = 'http://localhost'
port = 8070

client = GrobidClient(host, port)

# %%
path = os.path.dirname(os.getcwd())
path_article = os.path.join(path,'artifacts','test_article','b000689k.pdf')

# %%
rsp = client.serve("processFulltextDocument", path_article)

# %%
rsp
# Out:
# (<Response [200]>, 200)

# %%
type(rsp)
# Out:
# tuple

# %%
dir(rsp)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']
