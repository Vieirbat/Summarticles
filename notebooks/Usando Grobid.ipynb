# %% [markdown]
# # Testando Cliente do GROBID:

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ### Importando dependências

# %%
import os
import sys
import re

sys.path.insert(0,os.path.dirname(os.getcwd()))
sys.path.insert(0,os.path.join(os.getcwd(),'grobid'))
sys.path.insert(0,os.getcwd())

import numpy as np
import pandas as pd

from grobid import grobid_client
import grobid_tei_xml

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ### Comandos Docker

# %% [markdown]
# docker run -t --rm --init -p 8080:8070 -p 8081:8071 --memory="9g" lfoppiano/grobid:0.7.0
#
# docker run -t --rm --init -p 8080:8070 -p 8081:8071 lfoppiano/grobid:0.6.2

# %% [markdown]
# pip install grobid-tei-xml

# %% [markdown]
# ### Definindo variáveis e caminhos

# %%
path = os.path.dirname(os.getcwd())
path_input = os.path.join(path,'artifacts','test_article')
path_output = os.path.join(path,'output','xml')
path_article = os.path.join(path,'artifacts','test_article','b617684b.pdf')

host = 'http://localhost'
port = 8070

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ### Definindo variáveis e caminhos

# %%
client = grobid_client.GrobidClient(config_path="./grobid/config.json",timeout=360,grobid_port='8070')
# Out:
# GROBID server is up and running

# %%
pdf_file, status, xml = client.process_pdf(service="processFulltextDocument",
                                           pdf_file=path_article,
                                           generateIDs=True,
                                           consolidate_header=False, # Usa informações externas para consolidar informações de cabeçalho
                                           consolidate_citations=False, # Usa informações externas para consolidar informações de bibliografia
                                           include_raw_citations=True, # Citações
                                           include_raw_affiliations=True, # Afiliações
                                           tei_coordinates=False, # Gera coordenadas para gerar visualização de marcações no PDF
                                           segment_sentences=True) # Usa um motor externo para segmentar as sentenças

# %%
pdf_file
# Out:
# 'c:\\Users\\vierb\\OneDrive\\Área de Trabalho\\Projetos\\PGC\\artifacts\\test_article\\b617684b.pdf'

# %%
status # Status 408 é timeout
# Out:
# 200

# %%
xml[0:2000]
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<TEI xml:space="preserve" xmlns="http://www.tei-c.org/ns/1.0" \nxmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" \nxsi:schemaLocation="http://www.tei-c.org/ns/1.0 https://raw.githubusercontent.com/kermitt2/grobid/master/grobid-home/schemas/xsd/Grobid.xsd"\n xmlns:xlink="http://www.w3.org/1999/xlink">\n\t<teiHeader xml:lang="en">\n\t\t<fileDesc>\n\t\t\t<titleStmt>\n\t\t\t\t<title level="a" type="main" xml:id="_yK77Q7w">Nanometer scale carbon structures for charge-transfer systems and photovoltaic applications</title>\n\t\t\t</titleStmt>\n\t\t\t<publicationStmt>\n\t\t\t\t<publisher/>\n\t\t\t\t<availability status="unknown"><licence/></availability>\n\t\t\t\t<date type="published" when="2007-02-08">08 February 2007</date>\n\t\t\t</publicationStmt>\n\t\t\t<sourceDesc>\n\t\t\t\t<biblStruct>\n\t\t\t\t\t<analytic>\n\t\t\t\t\t\t<author>\n\t\t\t\t\t\t\t<persName><forename type="first">Dirk</forename><forename type="middle">M</forename><surname>Guldi</surname></persName>\n\t\t\t\t\t\t\t<affiliation key="aff0">\n\t\t\t\t\t\t\t\t<note type="raw_affiliation">Universita¨t Erlangen, Institute of Physical and Theoretical Chemistry, 91058 Erlangen, Germany</note>\n\t\t\t\t\t\t\t\t<orgName type="department">Institute of Physical and Theoretical Chemistry</orgName>\n\t\t\t\t\t\t\t\t<orgName type="institution">Universita¨t Erlangen</orgName>\n\t\t\t\t\t\t\t\t<address>\n\t\t\t\t\t\t\t\t\t<postCode>91058</postCode>\n\t\t\t\t\t\t\t\t\t<settlement>Erlangen</settlement>\n\t\t\t\t\t\t\t\t\t<country key="DE">Germany</country>\n\t\t\t\t\t\t\t\t</address>\n\t\t\t\t\t\t\t</affiliation>\n\t\t\t\t\t\t</author>\n\t\t\t\t\t\t<title level="a" type="main" xml:id="_gzbyQkQ">Nanometer scale carbon structures for charge-transfer systems and photovoltaic applications</title>\n\t\t\t\t\t</analytic>\n\t\t\t\t\t<monogr>\n\t\t\t\t\t\t<imprint>\n\t\t\t\t\t\t\t<date type="published" when="2007-02-08">08 February 2007</date>\n\t\t\t\t\t\t</imprint>\n\t\t\t\t\t</monogr>\n\t\t\t\t\t<idno type="MD5">5B70A65B9D2AEC3DD3E6A64B4BD94CB2</idno>\n\t\t\t\t\t<idno type="DOI">10.1039/b617684b</idno>\n\t\t\t\t\t<note type="submission">Received 4th December 2006, Accepted 3rd January 2007 First published as an Advan'

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ### Convertendo documento XML TEI em JSON

# %%
dir(grobid_tei_xml)
# Out:
# ['GrobidBiblio',
#  'GrobidDocument',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'parse',
#  'parse_citation_list_xml',
#  'parse_citation_xml',
#  'parse_citations_xml',
#  'parse_document_xml',
#  'types']

# %%
doc = grobid_tei_xml.parse_document_xml(xml)
doc = doc.to_dict()

doc.keys()
# Out:
# dict_keys(['grobid_version', 'grobid_timestamp', 'header', 'pdf_md5', 'language_code', 'citations', 'abstract', 'body', 'acknowledgement'])

# %%
doc['grobid_version']
# Out:
# '0.7.0'

# %%
doc['grobid_timestamp']
# Out:
# '2022-04-23T19:46+0000'

# %%
doc['header']
# Out:
# {'authors': [{'full_name': 'Dirk M Guldi',
#    'given_name': 'Dirk',
#    'middle_name': 'M',
#    'surname': 'Guldi',
#    'affiliation': {'institution': 'Universita¨t Erlangen',
#     'department': 'Institute of Physical and Theoretical Chemistry',
#     'address': {'post_code': '91058',
#      'settlement': 'Erlangen',
#      'country': 'Germany'}}}],
#  'date': '2007-02-08',
#  'title': 'Nanometer scale carbon structures for charge-transfer systems and photovoltaic applications',
#  'doi': '10.1039/b617684b'}

# %%
doc['language_code']
# Out:
# 'en'

# %%
doc['header']
# Out:
# {'authors': [{'full_name': 'Dirk M Guldi',
#    'given_name': 'Dirk',
#    'middle_name': 'M',
#    'surname': 'Guldi',
#    'affiliation': {'institution': 'Universita¨t Erlangen',
#     'department': 'Institute of Physical and Theoretical Chemistry',
#     'address': {'post_code': '91058',
#      'settlement': 'Erlangen',
#      'country': 'Germany'}}}],
#  'date': '2007-02-08',
#  'title': 'Nanometer scale carbon structures for charge-transfer systems and photovoltaic applications',
#  'doi': '10.1039/b617684b'}

# %%
doc['citations']
# Out:
# [{'authors': [],
#   'index': 0,
#   'id': 'b0',
#   'unstructured': 'Basic Research Needs for Solar Energy Utilization, Report of the Basic Energy Sciences Workshop on Solar Energy Utilization April 18-21, 2005-http://www.sc.doe.gov/bes/reports/files/ SEU_rpt.pdf.',
#   'date': '2005',
#   'title': 'Basic Research Needs for Solar Energy Utilization',
#   'journal': 'Report of the Basic Energy Sciences Workshop on Solar Energy',
#   'url': 'http://www.sc.doe.gov/bes/reports/files/SEU_rpt.pdf'},
#  {'authors': [{'full_name': 'V Balzani',
#     'given_name': 'V',
#     'surname': 'Balzani'}],
#   'index': 1,
#   'id': 'b1',
#   'unstructured': 'V. Balzani, Electron Transfer in Chemistry, Wiley-VCH, Wein- heim, 2001, vol. I-V.',
#   'date': '2001',
#   'title': 'Electron Transfer in Chemistry',
#   'journal': 'Weinheim',
#   'publisher': 'Wiley-VCH'},
#  {'authors': [{'full_name': 'A Hirsch',
#     'given_name': 'A',
#     'surname': 'Hirsch'},
#    {'full_name': 'M Brettreich', 'given_name': 'M', 'surname': 'Brettreich'},
#    {'full_name': ': Fullerenes', 'given_name': ':', 'surname': 'Fullerenes'},
#    {'full_name': 'Chemistry', 'surname': 'Chemistry'},
#    {'full_name': 'Wiley-Vch Reactions',
#     'given_name': 'Wiley-Vch',
#     'surname': 'Reactions'},
#    {'full_name': 'M Weinheim ; B) K',
#     'middle_name': 'M',
#     'surname': 'Weinheim ; B) K'},
#    {'full_name': 'R S Kadish',
#     'given_name': 'R',
#     'middle_name': 'S',
#     'surname': 'Kadish'},
#    {'full_name': '; M Ruoff', 'given_name': '; M', 'surname': 'Ruoff'},
#    {'full_name': 'N Guldi', 'given_name': 'N', 'surname': 'Guldi'},
#    {'full_name': 'Martin', 'surname': 'Martin'}],
#   'index': 2,
#   'id': 'b2',
#   'unstructured': 'A. Hirsch and M. Brettreich, Fullerenes: Chemistry and Reactions, Wiley-VCH, Weinheim, 2004; (b) K. M. Kadish and R. S. Ruoff, Fullerenes: Chemistry, Physics, and Technology, Wiley-VCH, Weinheim, 2000; (c) D. M. Guldi and N. Martin, Fullerenes: From Synthesis to Optoelectronic Properties, Series: Developments in Fullerene Science, Kluwer Academic, Dordrecht, 2002; (d) T. Braun, Nuclear and Radiation Chemical Approaches to Fullerene Science Series: Developments in Fullerene Science, Kluwer Academic, Dordrecht, 2000.',
#   'date': '2000',
#   'title': 'Fullerenes: From Synthesis to Optoelectronic Properties, Series: Developments in Fullerene Science',
#   'book_title': 'Nuclear and Radiation Chemical Approaches to Fullerene Science Series: Developments in Fullerene Science',
#   'publisher': 'Kluwer Academic',
#   'note': 'Fullerenes: Chemistry, Physics, and Technology'},
#  {'authors': [{'full_name': 'F Diederich',
#     'given_name': 'F',
#     'surname': 'Diederich'},
#    {'full_name': 'L Isaacs', 'given_name': 'L', 'surname': 'Isaacs'},
#    {'full_name': 'D Philp ; M. Prato',
#     'given_name': 'D',
#     'surname': 'Philp ; M. Prato'},
#    {'full_name': 'M Maggini ; C', 'given_name': 'M', 'surname': 'Maggini ; C'},
#    {'full_name': ') D Tasis',
#     'given_name': ')',
#     'middle_name': 'D',
#     'surname': 'Tasis'},
#    {'full_name': 'N Tagmatarchis',
#     'given_name': 'N',
#     'surname': 'Tagmatarchis'},
#    {'full_name': 'V Georgakilas', 'given_name': 'V', 'surname': 'Georgakilas'},
#    {'full_name': 'C Gamboz', 'given_name': 'C', 'surname': 'Gamboz'},
#    {'full_name': 'M.-R Soranzo', 'given_name': 'M.-R', 'surname': 'Soranzo'},
#    {'full_name': 'M Prato', 'given_name': 'M', 'surname': 'Prato'},
#    {'full_name': '; F Diederich', 'given_name': '; F', 'surname': 'Diederich'},
#    {'full_name': 'M Gomez-Lopez',
#     'given_name': 'M',
#     'surname': 'Gomez-Lopez'}],
#   'index': 3,
#   'id': 'b3',
#   'unstructured': 'F. Diederich, L. Isaacs and D. Philp, Chem. Soc. Rev., 1994, 23, 243; (b) M. Prato and M. Maggini, Acc. Chem. Res., 1998, 31, 519; (c) D. Tasis, N. Tagmatarchis, V. Georgakilas, C. Gamboz, M.-R. Soranzo and M. Prato, Compt. Rend. Chim., 2003, 6, 597; (d) N. Tagmatarchis and M. Prato, Synlett, 2003, 6, 768; (e) F. Diederich and M. Gomez-Lopez, Chem. Soc. Rev., 1999, 28, 263.',
#   'date': '1994',
#   'editors': [{'full_name': 'd) N. Tagmatarchis and M. Prato'}],
#   'journal': 'Compt. Rend. Chim',
#   'volume': '23',
#   'pages': '263',
#   'note': 'Chem. Soc. Rev.'},
#  {'authors': [{'full_name': 'S Reich', 'given_name': 'S', 'surname': 'Reich'},
#    {'full_name': 'C Thomsen', 'given_name': 'C', 'surname': 'Thomsen'},
#    {'full_name': 'J Maultzsch', 'given_name': 'J', 'surname': 'Maultzsch'}],
#   'index': 4,
#   'id': 'b4',
#   'unstructured': 'S. Reich, C. Thomsen and J. Maultzsch, Carbon Nanotubes: Basic Concepts and Physical Properties, Wiley-VCH, Weinheim, Germany, 2004; (b) M. S. Dresselhaus, G. Dresselhaus and P.',
#   'date': '2004',
#   'title': 'Carbon Nanotubes: Basic Concepts and Physical Properties',
#   'publisher': 'Wiley-VCH'},
#  {'authors': [{'full_name': 'Carbon Avouris',
#     'given_name': 'Carbon',
#     'surname': 'Avouris'},
#    {'full_name': '; P J F Nanotubes',
#     'given_name': ';',
#     'middle_name': 'P J F',
#     'surname': 'Nanotubes'},
#    {'full_name': 'D Harris ; Roth',
#     'given_name': 'D',
#     'surname': 'Harris ; Roth'},
#    {'full_name': 'Carroll', 'surname': 'Carroll'}],
#   'index': 5,
#   'id': 'b5',
#   'unstructured': 'Avouris, Carbon Nanotubes: Synthesis, Structure, Properties and Applications, Springer, Berlin, 2001; (c) P. J. F. Harris, Carbon Nanotubes and Related Structures: New Materials for the Twenty- First Century, Cambridge University Press, Cambridge, UK, 2001; (d) Special issue on Carbon Nanotubes, Acc. Chem. Res., 2002, 35, 997; (e) S. Roth and D. Carroll, One-Dimensional Metals: Conjugated Polymers, Organic Crystals, Carbon Nanotubes, Wiley-VCH, Weinheim, Germany, 2004; (f) V. N. Popov and P. Lambin, Carbon Nanotubes, Springer, Dordrecht, 2006.',
#   'date': '2001',
#   'title': 'One-Dimensional Metals: Conjugated Polymers, Organic Crystals, Carbon Nanotubes',
#   'book_title': 'Carbon Nanotubes and Related Structures: New Materials for the Twenty-First Century',
#   'publisher': 'Springer',
#   'volume': '35',
#   'pages': '997',
#   'note': 'Carbon Nanotubes'},
#  {'authors': [{'full_name': 'T W Ebbesen',
#     'given_name': 'T',
#     'middle_name': 'W',
#     'surname': 'Ebbesen'},
#    {'full_name': 'P M Ajayan ; B',
#     'given_name': 'P',
#     'middle_name': 'M',
#     'surname': 'Ajayan ; B'},
#    {'full_name': ') S Iijima',
#     'given_name': ')',
#     'middle_name': 'S',
#     'surname': 'Iijima'},
#    {'full_name': 'T H C Ichihaschi ; C',
#     'given_name': 'T',
#     'middle_name': 'H C',
#     'surname': 'Ichihaschi ; C'},
#    {'full_name': 'M S Bethune',
#     'given_name': 'M',
#     'middle_name': 'S',
#     'surname': 'Bethune'},
#    {'full_name': 'G De Vries', 'given_name': 'G', 'surname': 'De Vries'},
#    {'full_name': 'R Gorman', 'given_name': 'R', 'surname': 'Gorman'},
#    {'full_name': 'J Savoy', 'given_name': 'J', 'surname': 'Savoy'},
#    {'full_name': 'R Vazques', 'given_name': 'R', 'surname': 'Vazques'},
#    {'full_name': 'Beyers', 'surname': 'Beyers'}],
#   'index': 6,
#   'id': 'b6',
#   'unstructured': 'T. W. Ebbesen and P. M. Ajayan, Nature, 1992, 358, 220; (b) S. Iijima and T. Ichihaschi, Nature, 1993, 364, 737; (c) C. H. C. Bethune, M. S. de Vries, G. Gorman, R. Savoy, J. Vazques and R. Beyers, Nature, 1993, 363, 605.',
#   'date': '1992',
#   'journal': 'Nature',
#   'volume': '358',
#   'pages': '605',
#   'note': 'Nature'},
#  {'authors': [{'full_name': 'Y Zhang', 'given_name': 'Y', 'surname': 'Zhang'},
#    {'full_name': 'T Ichihashi', 'given_name': 'T', 'surname': 'Ichihashi'},
#    {'full_name': 'E Landree', 'given_name': 'E', 'surname': 'Landree'},
#    {'full_name': 'F Nihey', 'given_name': 'F', 'surname': 'Nihey'},
#    {'full_name': 'S Iijima', 'given_name': 'S', 'surname': 'Iijima'}],
#   'index': 7,
#   'id': 'b7',
#   'unstructured': 'Y. Zhang, T. Ichihashi, E. Landree, F. Nihey and S. Iijima, Science, 1999, 285, 1719; (b) M. S. Gudiksen, L. J. Lauhon, J. Wang, D. C. Smith and C. M. Lieber, Nature, 2002, 415, 617;',
#   'date': '1719',
#   'editors': [{'full_name': 'b) M. S. Gudiksen, L. J. Lauhon, J. Wang, D. C. Smith and C. M. Lieber'}],
#   'journal': 'Science',
#   'pages': '617',
#   'note': 'Nature'},
#  {'authors': [{'full_name': 'H J Dai ; D) J',
#     'given_name': 'H',
#     'middle_name': 'J',
#     'surname': 'Dai ; D) J'},
#    {'full_name': 'Davis', 'surname': 'Davis'}],
#   'index': 8,
#   'id': 'b8',
#   'unstructured': 'H. Dai, Acc. Chem. Res., 2002, 35, 1035; (d) J. J. Davis, Scheme 21 Molecular building blocks-single wall carbon nano- horns (SWNH)-as electron acceptors. This journal is c the Owner Societies 2007',
#   'date': '1035',
#   'title': 'Scheme 21 Molecular building blocks-single wall carbon nanohorns (SWNH)-as electron acceptors',
#   'journal': 'This journal is c the Owner Societies',
#   'volume': '35',
#   'note': 'Acc. Chem. Res.'},
#  {'authors': [],
#   'index': 9,
#   'id': 'b9',
#   'unstructured': 'Published on 08 February 2007. Downloaded by UNIVERSITY OF OTAGO on 11/09/2014 13:02:54. View Article Online',
#   'date': '2007-02',
#   'title': 'View Article Online',
#   'note': 'Published on 08',
#   'doi': '10.1039/b617684b'},
#  {'authors': [{'full_name': 'K S Coleman',
#     'given_name': 'K',
#     'middle_name': 'S',
#     'surname': 'Coleman'},
#    {'full_name': 'B R Azamian',
#     'given_name': 'B',
#     'middle_name': 'R',
#     'surname': 'Azamian'},
#    {'full_name': 'C B Bagshaw',
#     'given_name': 'C',
#     'middle_name': 'B',
#     'surname': 'Bagshaw'},
#    {'full_name': 'L H Green',
#     'given_name': 'L',
#     'middle_name': 'H',
#     'surname': 'Green'},
#    {'full_name': 'Chem', 'surname': 'Chem'},
#    {'full_name': 'J G G Eur', 'middle_name': 'J G G', 'surname': 'Eur'},
#    {'full_name': 'C E Wildgoose',
#     'given_name': 'C',
#     'middle_name': 'E',
#     'surname': 'Wildgoose'},
#    {'full_name': 'H C Banks',
#     'given_name': 'H',
#     'middle_name': 'C',
#     'surname': 'Banks'},
#    {'full_name': 'R G Leventis',
#     'given_name': 'R',
#     'middle_name': 'G',
#     'surname': 'Leventis'},
#    {'full_name': '; C Compton', 'given_name': '; C', 'surname': 'Compton'},
#    {'full_name': 'X Hu', 'given_name': 'X', 'surname': 'Hu'},
#    {'full_name': 'S Chen', 'given_name': 'S', 'surname': 'Chen'},
#    {'full_name': 'J J Hu',
#     'given_name': 'J',
#     'middle_name': 'J',
#     'surname': 'Hu'},
#    {'full_name': '; E Gooding',
#     'given_name': ';',
#     'middle_name': 'E',
#     'surname': 'Gooding'},
#    {'full_name': 'M Bekyarova', 'given_name': 'M', 'surname': 'Bekyarova'},
#    {'full_name': 'T Davis', 'given_name': 'T', 'surname': 'Davis'},
#    {'full_name': 'M E Burch',
#     'given_name': 'M',
#     'middle_name': 'E',
#     'surname': 'Burch'},
#    {'full_name': 'B Itkis', 'given_name': 'B', 'surname': 'Itkis'},
#    {'full_name': 'S Zhao', 'given_name': 'S', 'surname': 'Zhao'},
#    {'full_name': 'R C Sunshine',
#     'given_name': 'R',
#     'middle_name': 'C',
#     'surname': 'Sunshine'},
#    {'full_name': 'L Haddon ; G', 'middle_name': 'L', 'surname': 'Haddon ; G'},
#    {'full_name': 'N F Luque',
#     'given_name': 'N',
#     'middle_name': 'F',
#     'surname': 'Luque'},
#    {'full_name': 'G A Ferreyra',
#     'given_name': 'G',
#     'middle_name': 'A',
#     'surname': 'Ferreyra'},
#    {'full_name': 'Rivas', 'surname': 'Rivas'}],
#   'index': 10,
#   'id': 'b10',
#   'unstructured': 'K. S. Coleman, B. R. Azamian, C. B. Bagshaw and L. H. Green, Chem.-Eur. J., 2003, 9, 3733; (e) G. G. Wildgoose, C. E. Banks, H. C. Leventis and R. G. Compton, Microchim. Acta, 2006, 152, 187; (f) C. Hu, X. Chen and S. Hu, J. Electroanal. Chem., 2006, 586, 77; (g) J. J. Gooding, Electrochim. Acta, 2005, 50, 3049; (h) E. Bekyarova, M. Davis, T. Burch, M. E. Itkis, B. Zhao, S. Sunshine and R. C. Haddon, J. Phys. Chem. B, 2004, 108, 19717; (i) G. L. Luque, N. F. Ferreyra and G. A. Rivas, Microchim. Acta, 2006, 152, 277; (j) P. W. Barone, S. Baik, D. A. Heller and M. S. Strano, Nat. Mat., 2005, 4, 86; (k) E. S. Snow, F. K. Perkins and J. A. Robinson, Chem. Soc. Rev., 2006, 35, 790; (l)',
#   'date': '2003',
#   'editors': [{'full_name': 'k) E. S. Snow, F. K. Perkins and J. A. Robinson'}],
#   'journal': 'J. Electroanal. Chem',
#   'volume': '9',
#   'pages': '790',
#   'note': 'Chem. Soc. Rev.. (l'},
#  {'authors': [{'full_name': 'P H Calvert ; R',
#     'given_name': 'P',
#     'middle_name': 'H',
#     'surname': 'Calvert ; R'},
#    {'full_name': 'A A Baughman',
#     'given_name': 'A',
#     'middle_name': 'A',
#     'surname': 'Baughman'},
#    {'full_name': 'W A Zakhidov',
#     'given_name': 'W',
#     'middle_name': 'A',
#     'surname': 'Zakhidov'},
#    {'full_name': '; M M J De Heer',
#     'given_name': ';',
#     'middle_name': 'M M J',
#     'surname': 'De Heer'},
#    {'full_name': 'T W Treacy',
#     'given_name': 'T',
#     'middle_name': 'W',
#     'surname': 'Treacy'},
#    {'full_name': 'J M Ebbesen',
#     'given_name': 'J',
#     'middle_name': 'M',
#     'surname': 'Ebbesen'},
#    {'full_name': '; B Gibson', 'given_name': '; B', 'surname': 'Gibson'},
#    {'full_name': 'H Zhao', 'given_name': 'H', 'surname': 'Zhao'},
#    {'full_name': 'S K Hu',
#     'given_name': 'S',
#     'middle_name': 'K',
#     'surname': 'Hu'},
#    {'full_name': 'R C Mandal',
#     'given_name': 'R',
#     'middle_name': 'C',
#     'surname': 'Mandal'},
#    {'full_name': '; J N Haddon',
#     'given_name': '; J',
#     'middle_name': 'N',
#     'surname': 'Haddon'},
#    {'full_name': 'U Coleman', 'given_name': 'U', 'surname': 'Coleman'},
#    {'full_name': 'Y K Khan',
#     'given_name': 'Y',
#     'middle_name': 'K',
#     'surname': 'Khan'},
#    {'full_name': "J Gun'ko ; R) S",
#     'middle_name': 'J',
#     'surname': "Gun'ko ; R) S"},
#    {'full_name': 'J Son', 'given_name': 'J', 'surname': 'Son'},
#    {'full_name': 'B Reichel', 'given_name': 'B', 'surname': 'Reichel'},
#    {'full_name': 'M He', 'given_name': 'M', 'surname': 'He'},
#    {'full_name': 'S B Schuchman',
#     'given_name': 'S',
#     'middle_name': 'B',
#     'surname': 'Schuchman'},
#    {'full_name': 'Lee', 'surname': 'Lee'}],
#   'index': 11,
#   'id': 'b11',
#   'unstructured': "P. Calvert, Nature, 1999, 399, 210; (m) R. H. Baughman, A. A. Zakhidov and W. A. de Heer, Science, 2002, 297, 787; (n) M. M. J. Treacy, T. W. Ebbesen and J. M. Gibson, Nature, 1996, 381, 678; (o) B. Zhao, H. Hu, S. K. Mandal and R. C. Haddon, Chem. Mater., 2005, 17, 3235; (p) J. N. Coleman, U. Khan and Y. K. Gun'ko, Adv. Mater., 2006, 18, 689; (q) N. W. S. Kam, M. O'Connell, J. A. Wisdom and H. J. Dai, Proc. Natl. Acad. Sci. U. S. A., 2005, 102, 11600; (r) S. J. Son, J. Reichel, B. He, M. Schuchman and S. B. Lee, J. Am. Chem. Soc., 2005, 127, 7316; (s)",
#   'date': '1996',
#   'editors': [{'full_name': "q) N. W. S. Kam, M. O'Connell, J. A. Wisdom and H. J. Dai"}],
#   'journal': 'Proc. Natl. Acad. Sci. U. S. A',
#   'volume': '399',
#   'pages': '7316',
#   'note': 'J. Am. Chem. Soc.. (s'},
#  {'authors': [{'full_name': 'C R Martin',
#     'given_name': 'C',
#     'middle_name': 'R',
#     'surname': 'Martin'},
#    {'full_name': 'P Kohli', 'given_name': 'P', 'surname': 'Kohli'}],
#   'index': 12,
#   'id': 'b12',
#   'unstructured': 'C. R. Martin and P. Kohli, Nat. Rev. Drug Discovery, 2003, 2, 29;',
#   'date': '2003',
#   'journal': 'Nat. Rev. Drug Discovery',
#   'volume': '2',
#   'pages': '29'},
#  {'authors': [{'full_name': 'A Bianco',
#     'given_name': 'A',
#     'surname': 'Bianco'},
#    {'full_name': 'M Prato', 'given_name': 'M', 'surname': 'Prato'},
#    {'full_name': '; A Bianco', 'given_name': '; A', 'surname': 'Bianco'},
#    {'full_name': 'K Kostarelos', 'given_name': 'K', 'surname': 'Kostarelos'},
#    {'full_name': 'M S Prato ; R',
#     'given_name': 'M',
#     'middle_name': 'S',
#     'surname': 'Prato ; R'},
#    {'full_name': 'D C Ruoff',
#     'given_name': 'D',
#     'middle_name': 'C',
#     'surname': 'Ruoff'},
#    {'full_name': 'M J Lorents ; M',
#     'middle_name': 'M J',
#     'surname': 'Lorents ; M'},
#    {'full_name': 'T W Treacy',
#     'given_name': 'T',
#     'middle_name': 'W',
#     'surname': 'Treacy'},
#    {'full_name': 'J M Ebbesen',
#     'given_name': 'J',
#     'middle_name': 'M',
#     'surname': 'Ebbesen'},
#    {'full_name': 'R Gibson ; M', 'middle_name': 'R', 'surname': 'Gibson ; M'},
#    {'full_name': 'G J Falvo',
#     'given_name': 'G',
#     'middle_name': 'J',
#     'surname': 'Falvo'},
#    {'full_name': 'R M Clary',
#     'given_name': 'R',
#     'middle_name': 'M',
#     'surname': 'Clary'},
#    {'full_name': 'I I Taylor',
#     'given_name': 'I',
#     'middle_name': 'I',
#     'surname': 'Taylor'},
#    {'full_name': 'V Chi', 'given_name': 'V', 'surname': 'Chi'},
#    {'full_name': 'F P Brooks',
#     'given_name': 'F',
#     'middle_name': 'P',
#     'surname': 'Brooks'},
#    {'full_name': 'S Jr', 'given_name': 'S', 'surname': 'Jr'},
#    {'full_name': 'R Washburn', 'given_name': 'R', 'surname': 'Washburn'},
#    {'full_name': 'G Superfine ; Y) S',
#     'middle_name': 'G',
#     'surname': 'Superfine ; Y) S'},
#    {'full_name': 'L Rao', 'given_name': 'L', 'surname': 'Rao'},
#    {'full_name': 'W Huang', 'given_name': 'W', 'surname': 'Huang'},
#    {'full_name': 'S Setyawan', 'given_name': 'S', 'surname': 'Setyawan'},
#    {'full_name': 'Hong', 'surname': 'Hong'}],
#   'index': 13,
#   'id': 'b13',
#   'unstructured': 'A. Bianco and M. Prato, Adv. Mater., 2003, 15, 1765; (u) A. Bianco, K. Kostarelos and M. Prato, Curr. Opin. Chem. Biol., 2005, 9, 674; (v) R. S. Ruoff and D. C. Lorents, Carbon, 1995, 33, 925; (w) M. M. J. Treacy, T. W. Ebbesen and J. M. Gibson, Nature, 1996, 381, 678; (x) M. R. Falvo, G. J. Clary, R. M. Taylor II, V. Chi, F. P. Brooks, Jr, S. Washburn and R. Superfine, Nature, 1997, 389, 582; (y) S. G. Rao, L. Huang, W. Setyawan and S. Hong, Nature, 2003, 425, 36.',
#   'date': '1765',
#   'journal': 'Curr. Opin. Chem. Biol',
#   'volume': '15',
#   'pages': '36',
#   'note': 'Nature'},
#  {'authors': [{'full_name': 'A Thess', 'given_name': 'A', 'surname': 'Thess'},
#    {'full_name': 'R Lee', 'given_name': 'R', 'surname': 'Lee'},
#    {'full_name': 'P Nikolaev', 'given_name': 'P', 'surname': 'Nikolaev'},
#    {'full_name': 'H Dai', 'given_name': 'H', 'surname': 'Dai'},
#    {'full_name': 'P Petit', 'given_name': 'P', 'surname': 'Petit'},
#    {'full_name': 'J Robert', 'given_name': 'J', 'surname': 'Robert'},
#    {'full_name': 'C Xu', 'given_name': 'C', 'surname': 'Xu'},
#    {'full_name': 'Y H Lee',
#     'given_name': 'Y',
#     'middle_name': 'H',
#     'surname': 'Lee'},
#    {'full_name': 'S G Kim',
#     'given_name': 'S',
#     'middle_name': 'G',
#     'surname': 'Kim'},
#    {'full_name': 'A G Rinzler',
#     'given_name': 'A',
#     'middle_name': 'G',
#     'surname': 'Rinzler'},
#    {'full_name': 'D T Colbert',
#     'given_name': 'D',
#     'middle_name': 'T',
#     'surname': 'Colbert'},
#    {'full_name': 'G E Scuseria',
#     'given_name': 'G',
#     'middle_name': 'E',
#     'surname': 'Scuseria'},
#    {'full_name': 'D Tomanek', 'given_name': 'D', 'surname': 'Tomanek'},
#    {'full_name': 'J E Fischer',
#     'given_name': 'J',
#     'middle_name': 'E',
#     'surname': 'Fischer'},
#    {'full_name': 'R E Smalley',
#     'given_name': 'R',
#     'middle_name': 'E',
#     'surname': 'Smalley'}],
#   'index': 14,
#   'id': 'b14',
#   'unstructured': 'A. Thess, R. Lee, P. Nikolaev, H. Dai, P. Petit, J. Robert, C. Xu, Y. H. Lee, S. G. Kim, A. G. Rinzler, D. T. Colbert, G. E. Scuseria, D. Tomanek, J. E. Fischer and R. E. Smalley, Science, 1996, 273, 483.',
#   'date': '1996',
#   'journal': 'Science',
#   'pages': '483'},
#  {'authors': [{'full_name': 'J Li', 'given_name': 'J', 'surname': 'Li'},
#    {'full_name': 'Y Zhang', 'given_name': 'Y', 'surname': 'Zhang'},
#    {'full_name': 'M Zhang ; M. Yoshida',
#     'given_name': 'M',
#     'surname': 'Zhang ; M. Yoshida'},
#    {'full_name': 'J.-I Aihara', 'given_name': 'J.-I', 'surname': 'Aihara'}],
#   'index': 15,
#   'id': 'b15',
#   'unstructured': 'J. Li, Y. Zhang and M. Zhang, Chem. Phys. Lett., 2002, 364, 328; (b) M. Yoshida and J.-I. Aihara, Phys. Chem. Chem. Phys., 1999, 1, 227; (c) J.-I. Aihara and H. Kanno, Chem. Phys. Lett., 2004, 398, 440.',
#   'date': '1999',
#   'editors': [{'full_name': 'c) J.-I. Aihara and H. Kanno'}],
#   'journal': 'Phys. Chem. Chem. Phys',
#   'volume': '364',
#   'pages': '440',
#   'note': 'Chem. Phys. Lett.'},
#  {'authors': [{'full_name': 'K Kalyanasundaram ; M. Gouterman',
#     'given_name': 'K',
#     'surname': 'Kalyanasundaram ; M. Gouterman'},
#    {'full_name': 'P M Rentzepis',
#     'given_name': 'P',
#     'middle_name': 'M',
#     'surname': 'Rentzepis'},
#    {'full_name': 'K D M Straub ; C) D. Dolphin ; D) K',
#     'given_name': 'K',
#     'middle_name': 'D M',
#     'surname': 'Straub ; C) D. Dolphin ; D) K'},
#    {'full_name': 'K M Kadish',
#     'given_name': 'K',
#     'middle_name': 'M',
#     'surname': 'Kadish'},
#    {'full_name': 'R Smith', 'given_name': 'R', 'surname': 'Smith'},
#    {'full_name': 'A Guilard ; R',
#     'middle_name': 'A',
#     'surname': 'Guilard ; R'},
#    {'full_name': 'N Marcus', 'given_name': 'N', 'surname': 'Marcus'},
#    {'full_name': 'C Sutin ; R', 'middle_name': 'C', 'surname': 'Sutin ; R'},
#    {'full_name': 'Haddon', 'surname': 'Haddon'}],
#   'index': 16,
#   'id': 'b16',
#   'unstructured': 'K. Kalyanasundaram, Photochemistry of Polypyridine and Porphyrin Complexes, Academic Press, 1997; (b) M. Gouterman, P. M. Rentzepis and K. D. Straub, Porphyrins: Excited States and Dynamics, ACS Symposium Series, N1 321, 1987; (c) D. Dolphin, The Porphyrins, Academic Press, 1978; (d) K. M. Kadish, K. M. Smith and R. Guilard, The Porphyrin Handbook, Academic Press, 2003. 11 (a) R. A. Marcus and N. Sutin, Biochim. Biophys. Acta, 1985, 811, 265; (b) R. A. Marcus, Angew. Chem., Int. Ed. Engl., 1993, 32, 1111. 12 (a) R. C. Haddon, Acc. Chem. Res., 1988, 21, 243; (b) R. C. Haddon, Science, 1993, 261, 1545.',
#   'date': '1111',
#   'title': 'Porphyrins: Excited States and Dynamics',
#   'book_title': 'Photochemistry of Polypyridine and Porphyrin Complexes',
#   'series_title': 'ACS Symposium Series',
#   'editors': [{'full_name': ') R A Marcus',
#     'given_name': ')',
#     'middle_name': 'R A',
#     'surname': 'Marcus'}],
#   'publisher': 'Academic Press',
#   'volume': '11',
#   'pages': '1545',
#   'note': 'Science'},
#  {'authors': [{'full_name': 'L Echegoyen',
#     'given_name': 'L',
#     'surname': 'Echegoyen'},
#    {'full_name': 'L E Echegoyen',
#     'given_name': 'L',
#     'middle_name': 'E',
#     'surname': 'Echegoyen'}],
#   'index': 17,
#   'id': 'b17',
#   'unstructured': 'L. Echegoyen and L. E. Echegoyen, Acc. Chem. Res., 1998, 31, 593.',
#   'date': '1998',
#   'journal': 'Acc. Chem. Res',
#   'pages': '593'},
#  {'authors': [{'full_name': 'G Duskesas',
#     'given_name': 'G',
#     'surname': 'Duskesas'},
#    {'full_name': 'S M Larsson ; D',
#     'given_name': 'S',
#     'middle_name': 'M',
#     'surname': 'Larsson ; D'},
#    {'full_name': 'K.-D Guldi', 'given_name': 'K.-D', 'surname': 'Guldi'},
#    {'full_name': 'Asmus', 'surname': 'Asmus'}],
#   'index': 18,
#   'id': 'b18',
#   'unstructured': 'G. Duskesas and S. Larsson, Theor. Chem. Acc., 1997, 97, 110. 15 (a) D. M. Guldi and K.-D. Asmus, J. Phys. Chem. A, 1997, 101, 1472; (b) D. M. Guldi and M. Prato, Acc. Chem. Res., 2000, 33, 695.',
#   'date': '1472',
#   'editors': [{'full_name': 'b) D. M. Guldi and M. Prato'}],
#   'journal': 'Theor. Chem. Acc',
#   'volume': '97',
#   'pages': '695',
#   'note': 'Acc. Chem. Res.'},
#  {'authors': [{'full_name': 'M L Mcglashen',
#     'given_name': 'M',
#     'middle_name': 'L',
#     'surname': 'Mcglashen'},
#    {'full_name': 'M E Blackwood',
#     'given_name': 'M',
#     'middle_name': 'E',
#     'surname': 'Blackwood'},
#    {'full_name': 'T G Spior',
#     'given_name': 'T',
#     'middle_name': 'G',
#     'surname': 'Spior'}],
#   'index': 19,
#   'id': 'b19',
#   'unstructured': 'M. L. McGlashen, M. E. Blackwood and T. G. Spior, J. Am. Chem. Soc., 1993, 115, 2074.',
#   'date': '1993',
#   'journal': 'J. Am. Chem. Soc',
#   'pages': '115'},
#  {'authors': [{'full_name': 'R C Haddon',
#     'given_name': 'R',
#     'middle_name': 'C',
#     'surname': 'Haddon'},
#    {'full_name': 'A F Hebard',
#     'given_name': 'A',
#     'middle_name': 'F',
#     'surname': 'Hebard'},
#    {'full_name': 'M J Rosseinsky',
#     'given_name': 'M',
#     'middle_name': 'J',
#     'surname': 'Rosseinsky'},
#    {'full_name': 'D W Murphy',
#     'given_name': 'D',
#     'middle_name': 'W',
#     'surname': 'Murphy'},
#    {'full_name': 'S J Duclos',
#     'given_name': 'S',
#     'middle_name': 'J',
#     'surname': 'Duclos'},
#    {'full_name': 'K B Lyons',
#     'given_name': 'K',
#     'middle_name': 'B',
#     'surname': 'Lyons'},
#    {'full_name': 'B Miller', 'given_name': 'B', 'surname': 'Miller'},
#    {'full_name': 'J M Rosamilia',
#     'given_name': 'J',
#     'middle_name': 'M',
#     'surname': 'Rosamilia'},
#    {'full_name': 'R M Fleming',
#     'given_name': 'R',
#     'middle_name': 'M',
#     'surname': 'Fleming'},
#    {'full_name': 'A R Kortan',
#     'given_name': 'A',
#     'middle_name': 'R',
#     'surname': 'Kortan'},
#    {'full_name': 'S H Glarum',
#     'given_name': 'S',
#     'middle_name': 'H',
#     'surname': 'Glarum'},
#    {'full_name': 'A V Makhija',
#     'given_name': 'A',
#     'middle_name': 'V',
#     'surname': 'Makhija'},
#    {'full_name': 'A J Muller',
#     'given_name': 'A',
#     'middle_name': 'J',
#     'surname': 'Muller'},
#    {'full_name': 'R H Eick',
#     'given_name': 'R',
#     'middle_name': 'H',
#     'surname': 'Eick'},
#    {'full_name': 'S M Zahurak',
#     'given_name': 'S',
#     'middle_name': 'M',
#     'surname': 'Zahurak'},
#    {'full_name': 'R Tycko', 'given_name': 'R', 'surname': 'Tycko'},
#    {'full_name': 'G Dabbagh', 'given_name': 'G', 'surname': 'Dabbagh'},
#    {'full_name': 'F A Thiel',
#     'given_name': 'F',
#     'middle_name': 'A',
#     'surname': 'Thiel'}],
#   'index': 20,
#   'id': 'b20',
#   'unstructured': 'R. C. Haddon, A. F. Hebard, M. J. Rosseinsky, D. W. Murphy, S. J. Duclos, K. B. Lyons, B. Miller, J. M. Rosamilia, R. M. Fleming, A. R. Kortan, S. H. Glarum, A. V. Makhija, A. J. Muller, R. H. Eick, S. M. Zahurak, R. Tycko, G. Dabbagh and F. A. Thiel, Nature, 1991, 350, 320.',
#   'date': '1991',
#   'journal': 'Nature',
#   'pages': '320'},
#  {'authors': [{'full_name': 'H W Kroto',
#     'given_name': 'H',
#     'middle_name': 'W',
#     'surname': 'Kroto'},
#    {'full_name': 'J R Heath',
#     'given_name': 'J',
#     'middle_name': 'R',
#     'surname': 'Heath'},
#    {'full_name': "S C O'brien",
#     'given_name': 'S',
#     'middle_name': 'C',
#     'surname': "O'brien"},
#    {'full_name': 'S F Curl',
#     'given_name': 'S',
#     'middle_name': 'F',
#     'surname': 'Curl'},
#    {'full_name': 'R E Smalley',
#     'given_name': 'R',
#     'middle_name': 'E',
#     'surname': 'Smalley'}],
#   'index': 21,
#   'id': 'b21',
#   'unstructured': "H. W. Kroto, J. R. Heath, S. C. O'Brien, S. F. Curl and R. E. Smalley, Nature, 1985, 318, 162.",
#   'date': '1985',
#   'journal': 'Nature',
#   'pages': '162'},
#  {'authors': [{'full_name': 'S M Bachilo',
#     'given_name': 'S',
#     'middle_name': 'M',
#     'surname': 'Bachilo'},
#    {'full_name': 'M S Strano',
#     'given_name': 'M',
#     'middle_name': 'S',
#     'surname': 'Strano'},
#    {'full_name': 'C Kittrell', 'given_name': 'C', 'surname': 'Kittrell'},
#    {'full_name': 'R H Hauge',
#     'given_name': 'R',
#     'middle_name': 'H',
#     'surname': 'Hauge'},
#    {'full_name': 'R E Smalley',
#     'given_name': 'R',
#     'middle_name': 'E',
#     'surname': 'Smalley'},
#    {'full_name': 'R B Weisman',
#     'given_name': 'R',
#     'middle_name': 'B',
#     'surname': 'Weisman'}],
#   'index': 22,
#   'id': 'b22',
#   'unstructured': 'S. M. Bachilo, M. S. Strano, C. Kittrell, R. H. Hauge, R. E. Smalley and R. B. Weisman, Science, 2002, 298, 2361.',
#   'date': '2002',
#   'journal': 'Science'},
#  {'authors': [{'full_name': 'M S Dresselaus',
#     'given_name': 'M',
#     'middle_name': 'S',
#     'surname': 'Dresselaus'},
#    {'full_name': 'G Dresselhaus', 'given_name': 'G', 'surname': 'Dresselhaus'},
#    {'full_name': 'R Saito', 'given_name': 'R', 'surname': 'Saito'},
#    {'full_name': 'A Jorio ; N. Mataga',
#     'given_name': 'A',
#     'surname': 'Jorio ; N. Mataga'},
#    {'full_name': 'T Asahi', 'given_name': 'T', 'surname': 'Asahi'},
#    {'full_name': 'Y Kanda', 'given_name': 'Y', 'surname': 'Kanda'},
#    {'full_name': 'T Okada ; N. Mataga',
#     'given_name': 'T',
#     'surname': 'Okada ; N. Mataga'},
#    {'full_name': 'H Miyasaka ; N. Mataga',
#     'given_name': 'H',
#     'surname': 'Miyasaka ; N. Mataga'},
#    {'full_name': 'H Chosrowjan', 'given_name': 'H', 'surname': 'Chosrowjan'},
#    {'full_name': 'Y Shibata', 'given_name': 'Y', 'surname': 'Shibata'},
#    {'full_name': 'N Yoshida', 'given_name': 'N', 'surname': 'Yoshida'},
#    {'full_name': 'A Osuka', 'given_name': 'A', 'surname': 'Osuka'},
#    {'full_name': 'T Kikuzawa', 'given_name': 'T', 'surname': 'Kikuzawa'},
#    {'full_name': 'T Okada ; S. Fukuzumi',
#     'given_name': 'T',
#     'surname': 'Okada ; S. Fukuzumi'},
#    {'full_name': 'K Ohkubo', 'given_name': 'K', 'surname': 'Ohkubo'},
#    {'full_name': 'H Imahori', 'given_name': 'H', 'surname': 'Imahori'},
#    {'full_name': 'D M Guldi',
#     'given_name': 'D',
#     'middle_name': 'M',
#     'surname': 'Guldi'}],
#   'index': 23,
#   'id': 'b23',
#   'unstructured': 'M. S. Dresselaus, G. Dresselhaus, R. Saito and A. Jorio, Phys. Rep., 2005, 409, 47. 21 (a) N. Mataga, T. Asahi, Y. Kanda and T. Okada, Chem. Phys., 1988, 127, 249; (b) N. Mataga and H. Miyasaka, in Electron Transfer from Isolated Molecules to Biomolecules Part 2, ed. J. Jortner and M. Bixon, Wiley, New York, 1999; (c) N. Mataga, H. Chosrowjan, Y. Shibata, N. Yoshida, A. Osuka, T. Kikuzawa and T. Okada, J. Am. Chem. Soc., 2001, 123, 12422. 22 (a) D. M. Guldi and K. D. Asmus, J. Am. Chem. Soc., 1997, 119, 5744; (b) S. Fukuzumi, K. Ohkubo, H. Imahori and D. M. Guldi, Chem.-Eur. J., 2003, 9, 1585.',
#   'date': '1988',
#   'title': 'Electron Transfer from Isolated Molecules to Biomolecules Part',
#   'editors': [{'full_name': 'D M Guldi',
#     'given_name': 'D',
#     'middle_name': 'M',
#     'surname': 'Guldi'},
#    {'full_name': 'K D Asmus',
#     'given_name': 'K',
#     'middle_name': 'D',
#     'surname': 'Asmus'}],
#   'publisher': 'Wiley',
#   'volume': '409',
#   'pages': '1585',
#   'note': 'Chem.-Eur. J.'},
#  {'authors': [{'full_name': 'D M Guldi',
#     'given_name': 'D',
#     'middle_name': 'M',
#     'surname': 'Guldi'},
#    {'full_name': 'P Neta', 'given_name': 'P', 'surname': 'Neta'},
#    {'full_name': 'K D Asmus',
#     'given_name': 'K',
#     'middle_name': 'D',
#     'surname': 'Asmus'}],
#   'index': 24,
#   'id': 'b24',
#   'unstructured': 'D. M. Guldi, P. Neta and K. D. Asmus, J. Phys. Chem., 1994, 98, 4617.',
#   'date': '1994',
#   'journal': 'J. Phys. Chem',
#   'pages': '4617'},
#  {'authors': [{'full_name': 'M E El-Khouly',
#     'given_name': 'M',
#     'middle_name': 'E',
#     'surname': 'El-Khouly'},
#    {'full_name': 'M Fujitsuka', 'given_name': 'M', 'surname': 'Fujitsuka'},
#    {'full_name': 'O Ito', 'given_name': 'O', 'surname': 'Ito'}],
#   'index': 25,
#   'id': 'b25',
#   'unstructured': 'M. E. El-Khouly, M. Fujitsuka and O. Ito, J. Porphyrins Phthalocyanines, 2000, 4, 591; (b) J. Fujisawa, Y. Ohba and S.',
#   'date': '2000',
#   'editors': [{'full_name': 'b) J. Fujisawa, Y. Ohba and S'}],
#   'journal': 'J. Porphyrins Phthalocyanines'},
#  {'authors': [{'full_name': 'M Yamauchi ; C) D',
#     'middle_name': 'M',
#     'surname': 'Yamauchi ; C) D'},
#    {'full_name': 'H Martino', 'given_name': 'H', 'surname': 'Martino'},
#    {'full_name': 'Van Willigen', 'surname': 'Van Willigen'}],
#   'index': 26,
#   'id': 'b26',
#   'unstructured': 'Yamauchi, Chem. Phys. Lett., 1998, 282, 181; (c) D. M. Martino and H. van Willigen, J. Phys. Chem. A, 2000, 104, 10701.',
#   'date': '1998',
#   'journal': 'Chem. Phys. Lett',
#   'volume': '282',
#   'pages': '10701',
#   'note': 'J. Phys. Chem. A'},
#  {'authors': [{'full_name': 'T Nojiri',
#     'given_name': 'T',
#     'surname': 'Nojiri'},
#    {'full_name': 'M M Alam',
#     'given_name': 'M',
#     'middle_name': 'M',
#     'surname': 'Alam'},
#    {'full_name': 'H Konami', 'given_name': 'H', 'surname': 'Konami'},
#    {'full_name': 'A Watanabe', 'given_name': 'A', 'surname': 'Watanabe'},
#    {'full_name': 'O Ito', 'given_name': 'O', 'surname': 'Ito'},
#    {'full_name': '; E Dietel',
#     'given_name': ';',
#     'middle_name': 'E',
#     'surname': 'Dietel'},
#    {'full_name': 'A Hirsch', 'given_name': 'A', 'surname': 'Hirsch'},
#    {'full_name': 'E Eichborn', 'given_name': 'E', 'surname': 'Eichborn'},
#    {'full_name': 'A Rieker', 'given_name': 'A', 'surname': 'Rieker'},
#    {'full_name': 'S Hackbarth', 'given_name': 'S', 'surname': 'Hackbarth'},
#    {'full_name': 'B Ro¨der ; M. Guldi',
#     'given_name': 'B',
#     'surname': 'Ro¨der ; M. Guldi'},
#    {'full_name': 'C Luo', 'given_name': 'C', 'surname': 'Luo'},
#    {'full_name': 'M Prato', 'given_name': 'M', 'surname': 'Prato'},
#    {'full_name': 'E Dietel', 'given_name': 'E', 'surname': 'Dietel'},
#    {'full_name': 'A Hirsch ; M. Guldi',
#     'given_name': 'A',
#     'surname': 'Hirsch ; M. Guldi'},
#    {'full_name': 'C Luo', 'given_name': 'C', 'surname': 'Luo'},
#    {'full_name': 'M Prato', 'given_name': 'M', 'surname': 'Prato'},
#    {'full_name': 'A Troisi', 'given_name': 'A', 'surname': 'Troisi'},
#    {'full_name': 'F Zerbetto', 'given_name': 'F', 'surname': 'Zerbetto'},
#    {'full_name': 'M Scheloske', 'given_name': 'M', 'surname': 'Scheloske'},
#    {'full_name': 'E Dietel', 'given_name': 'E', 'surname': 'Dietel'},
#    {'full_name': 'W Bauer', 'given_name': 'W', 'surname': 'Bauer'},
#    {'full_name': 'A Hirsch', 'given_name': 'A', 'surname': 'Hirsch'}],
#   'index': 27,
#   'id': 'b27',
#   'unstructured': 'T. Nojiri, M. M. Alam, H. Konami, A. Watanabe and O. Ito, J. Phys. Chem. A, 1997, 101, 7943. 26 (a) E. Dietel, A. Hirsch, E. Eichborn, A. Rieker, S. Hackbarth and B. Ro¨der, Chem. Commun., 1998, 1981; (b) D. M. Guldi, C. Luo, M. Prato, E. Dietel and A. Hirsch, Chem. Commun., 2000, 373; (c) D. M. Guldi, C. Luo, M. Prato, A. Troisi, F. Zerbetto, M. Scheloske, E. Dietel, W. Bauer and A. Hirsch, J. Am. Chem. Soc., 2001, 123, 9166.',
#   'date': '1981',
#   'journal': 'J. Am. Chem. Soc',
#   'volume': '101',
#   'pages': '9166',
#   'note': 'J. Phys. Chem. A'},
#  {'authors': [{'full_name': 'N Armaroli',
#     'given_name': 'N',
#     'surname': 'Armaroli'},
#    {'full_name': 'G Marconi', 'given_name': 'G', 'surname': 'Marconi'},
#    {'full_name': 'L Echegoyen', 'given_name': 'L', 'surname': 'Echegoyen'},
#    {'full_name': 'J.-P Bourgeois',
#     'given_name': 'J.-P',
#     'surname': 'Bourgeois'},
#    {'full_name': 'F Diederich', 'given_name': 'F', 'surname': 'Diederich'},
#    {'full_name': 'Chem', 'surname': 'Chem'},
#    {'full_name': 'J Eur', 'middle_name': 'J', 'surname': 'Eur'},
#    {'full_name': 'D M Luo',
#     'given_name': 'D',
#     'middle_name': 'M',
#     'surname': 'Luo'},
#    {'full_name': 'H Guldi', 'given_name': 'H', 'surname': 'Guldi'},
#    {'full_name': 'K Imahori', 'given_name': 'K', 'surname': 'Imahori'},
#    {'full_name': 'Y Tamaki', 'given_name': 'Y', 'surname': 'Tamaki'},
#    {'full_name': 'M E Sakata ; H. Imahori',
#     'given_name': 'M',
#     'middle_name': 'E',
#     'surname': 'Sakata ; H. Imahori'},
#    {'full_name': 'M El-Khouly', 'given_name': 'M', 'surname': 'El-Khouly'},
#    {'full_name': 'O Fujitsuka', 'given_name': 'O', 'surname': 'Fujitsuka'},
#    {'full_name': 'Y Ito', 'given_name': 'Y', 'surname': 'Ito'},
#    {'full_name': 'S Sakata', 'given_name': 'S', 'surname': 'Sakata'},
#    {'full_name': 'K Fukuzumi ; H. Imahori',
#     'given_name': 'K',
#     'surname': 'Fukuzumi ; H. Imahori'},
#    {'full_name': 'D M Tamaki',
#     'given_name': 'D',
#     'middle_name': 'M',
#     'surname': 'Tamaki'},
#    {'full_name': 'C Guldi', 'given_name': 'C', 'surname': 'Guldi'},
#    {'full_name': 'M Luo', 'given_name': 'M', 'surname': 'Luo'},
#    {'full_name': 'O Fujitsuka', 'given_name': 'O', 'surname': 'Fujitsuka'},
#    {'full_name': 'Y Ito', 'given_name': 'Y', 'surname': 'Ito'},
#    {'full_name': 'S Sakata', 'given_name': 'S', 'surname': 'Sakata'},
#    {'full_name': 'D W Fukuzumi ; P',
#     'middle_name': 'D W',
#     'surname': 'Fukuzumi ; P'},
#    {'full_name': 'Boyd', 'surname': 'Boyd'}],
#   'index': 28,
#   'id': 'b28',
#   'unstructured': 'N. Armaroli, G. Marconi, L. Echegoyen, J.-P. Bourgeois and F. Diederich, Chem.-Eur. J., 2000, 6, 1629. 28 (a) C. Luo, D. M. Guldi, H. Imahori, K. Tamaki and Y. Sakata, J. Am. Chem. Soc., 2000, 122, 6535; (b) H. Imahori, M. E. El- Khouly, M. Fujitsuka, O. Ito, Y. Sakata and S. Fukuzumi, J. Phys. Chem. A, 2001, 105, 325; (c) H. Imahori, K. Tamaki, D. M. Guldi, C. Luo, M. Fujitsuka, O. Ito, Y. Sakata and S. Fukuzumi, J. Am. Chem. Soc., 2001, 123, 2607; (d) H. Imahori, N. V. Tkachenko, V. Vehmanen, K. Tamaki, H. Lemmetyinen, Y. Sakata and S. Fukuzumi, J. Phys. Chem. A, 2001, 105, 1750. 29 (a) T. Drovetskaya, C. A. Reed and P. D. W. Boyd, Tetrahedron Lett., 1995, 36, 7971; (b) D. Kuciauskas, S. Lin, G. R. Seely, A. L.',
#   'date': '1629',
#   'editors': [{'full_name': 'd) H. Imahori, N. V. Tkachenko, V. Vehmanen, K. Tamaki, H. Lemmetyinen, Y. Sakata and S. Fukuzumi'}],
#   'journal': 'J. Am. Chem. Soc',
#   'volume': '28',
#   'pages': '325',
#   'note': 'Tetrahedron Lett.. 36, 7971; (b) D. Kuciauskas, S. Lin, G. R. Seely, A. L'},
#  {'authors': [{'full_name': 'T A Moore',
#     'given_name': 'T',
#     'middle_name': 'A',
#     'surname': 'Moore'},
#    {'full_name': 'D Moore', 'given_name': 'D', 'surname': 'Moore'},
#    {'full_name': 'T Gust', 'given_name': 'T', 'surname': 'Gust'},
#    {'full_name': 'C A Drovetskaya',
#     'given_name': 'C',
#     'middle_name': 'A',
#     'surname': 'Drovetskaya'},
#    {'full_name': 'P D W Reed',
#     'given_name': 'P',
#     'middle_name': 'D W',
#     'surname': 'Reed'},
#    {'full_name': 'Boyd', 'surname': 'Boyd'}],
#   'index': 29,
#   'id': 'b29',
#   'unstructured': 'Moore, T. A. Moore, D. Gust, T. Drovetskaya, C. A. Reed and P. D. W. Boyd, J. Phys. Chem., 1996, 100, 15926.',
#   'date': '1996',
#   'journal': 'J. Phys. Chem',
#   'pages': '15926'},
#  {'authors': [{'full_name': 'A Lembo', 'given_name': 'A', 'surname': 'Lembo'},
#    {'full_name': 'P Tagliatesta', 'given_name': 'P', 'surname': 'Tagliatesta'},
#    {'full_name': 'D M Guldi',
#     'given_name': 'D',
#     'middle_name': 'M',
#     'surname': 'Guldi'}],
#   'index': 30,
#   'id': 'b30',
#   'unstructured': 'A. Lembo, P. Tagliatesta and D. M. Guldi, J. Phys. Chem. B, 2006, 110, 11424.',
#   'date': '2006',
#   'journal': 'J. Phys. Chem. B',
#   'pages': '11424'},
#  {'authors': [{'full_name': 'S A Vail',
#     'given_name': 'S',
#     'middle_name': 'A',
#     'surname': 'Vail'},
#    {'full_name': 'P J Krawczuk',
#     'given_name': 'P',
#     'middle_name': 'J',
#     'surname': 'Krawczuk'},
#    {'full_name': 'D M Guldi',
#     'given_name': 'D',
#     'middle_name': 'M',
#     'surname': 'Guldi'},
#    {'full_name': 'A Palkar', 'given_name': 'A', 'surname': 'Palkar'},
#    {'full_name': 'L Echegoyen', 'given_name': 'L', 'surname': 'Echegoyen'},
#    {'full_name': 'J P C Tome',
#     'given_name': 'J',
#     'middle_name': 'P C',
#     'surname': 'Tome'},
#    {'full_name': 'M A Fazio',
#     'given_name': 'M',
#     'middle_name': 'A',
#     'surname': 'Fazio'},
#    {'full_name': 'D I Schuster',
#     'given_name': 'D',
#     'middle_name': 'I',
#     'surname': 'Schuster'}],
#   'index': 31,
#   'id': 'b31',
#   'unstructured': 'S. A. Vail, P. J. Krawczuk, D. M. Guldi, A. Palkar, L. Eche- goyen, J. P. C. Tome, M. A. Fazio and D. I. Schuster, Chem.-Eur. J., 2005, 11, 3375.',
#   'date': '2005',
#   'journal': 'Chem.-Eur. J',
#   'pages': '3375'},
#  {'authors': [{'full_name': 'H Imahori',
#     'given_name': 'H',
#     'surname': 'Imahori'},
#    {'full_name': 'H Yamada', 'given_name': 'H', 'surname': 'Yamada'},
#    {'full_name': 'D M Guldi',
#     'given_name': 'D',
#     'middle_name': 'M',
#     'surname': 'Guldi'},
#    {'full_name': 'Y Endo', 'given_name': 'Y', 'surname': 'Endo'},
#    {'full_name': 'A Shimomura', 'given_name': 'A', 'surname': 'Shimomura'},
#    {'full_name': 'S Kundu', 'given_name': 'S', 'surname': 'Kundu'},
#    {'full_name': 'K Yamada', 'given_name': 'K', 'surname': 'Yamada'},
#    {'full_name': 'T Okada', 'given_name': 'T', 'surname': 'Okada'},
#    {'full_name': 'Y Sakata', 'given_name': 'Y', 'surname': 'Sakata'},
#    {'full_name': 'S Fukuzumi ; H. Imahori',
#     'given_name': 'S',
#     'surname': 'Fukuzumi ; H. Imahori'},
#    {'full_name': 'D M Guldi',
#     'given_name': 'D',
#     'middle_name': 'M',
#     'surname': 'Guldi'},
#    {'full_name': 'K Tamaki', 'given_name': 'K', 'surname': 'Tamaki'},
#    {'full_name': 'Y Yoshida', 'given_name': 'Y', 'surname': 'Yoshida'},
#    {'full_name': 'C Luo', 'given_name': 'C', 'surname': 'Luo'},
#    {'full_name': 'Y Sakata', 'given_name': 'Y', 'surname': 'Sakata'},
#    {'full_name': 'S Fukuzumi', 'given_name': 'S', 'surname': 'Fukuzumi'}],
#   'index': 32,
#   'id': 'b32',
#   'unstructured': 'H. Imahori, H. Yamada, D. M. Guldi, Y. Endo, A. Shimomura, S. Kundu, K. Yamada, T. Okada, Y. Sakata and S. Fukuzumi, Angew. Chem., Int. Ed., 2002, 41, 2344. 33 (a) H. Imahori, D. M. Guldi, K. Tamaki, Y. Yoshida, C. Luo, Y. Sakata and S. Fukuzumi, J. Am. Chem. Soc., 2001, 123, 6617; (b)',
#   'date': '2001',
#   'journal': 'Angew. Chem., Int. Ed',
#   'volume': '41',
#   'pages': '6617',
#   'note': 'J. Am. Chem. Soc.. (b'},
#  {'authors': [{'full_name': 'D M Guldi',
#     'given_name': 'D',
#     'middle_name': 'M',
#     'surname': 'Guldi'},
#    {'full_name': 'H Imahori', 'given_name': 'H', 'surname': 'Imahori'},
#    {'full_name': 'K Tamaki', 'given_name': 'K', 'surname': 'Tamaki'},
#    {'full_name': 'Y Kashiwagi', 'given_name': 'Y', 'surname': 'Kashiwagi'},
#    {'full_name': 'H Yamada', 'given_name': 'H', 'surname': 'Yamada'},
#    {'full_name': 'Y Sakata', 'given_name': 'Y', 'surname': 'Sakata'},
#    {'full_name': 'S Fukuzumi', 'given_name': 'S', 'surname': 'Fukuzumi'}],
#   'index': 33,
#   'id': 'b33',
#   'unstructured': 'D. M. Guldi, H. Imahori, K. Tamaki, Y. Kashiwagi, H. Yamada, Y. Sakata and S. Fukuzumi, J. Phys. Chem. A, 2004, 108, 541; (c)',
#   'date': '2004',
#   'journal': 'J. Phys. Chem. A',
#   'volume': '108',
#   'pages': '541',
#   'note': 'c'},
#  {'authors': [{'full_name': 'C Luo', 'given_name': 'C', 'surname': 'Luo'},
#    {'full_name': 'D M Guldi',
#     'given_name': 'D',
#     'middle_name': 'M',
#     'surname': 'Guldi'},
#    {'full_name': 'H Imahori', 'given_name': 'H', 'surname': 'Imahori'},
#    {'full_name': 'K Tamaki', 'given_name': 'K', 'surname': 'Tamaki'},
#    {'full_name': 'Y Sakata', 'given_name': 'Y', 'surname': 'Sakata'}],
#   'index': 34,
#   'id': 'b34',
#   'unstructured': 'C. Luo, D. M. Guldi, H. Imahori, K. Tamaki and Y. Sakata, J. Am. Chem. Soc., 2000, 122, 6535.',
#   'date': '2000',
#   'journal': 'J. Am. Chem. Soc',
#   'pages': '6535'},
#  {'authors': [{'full_name': 'F Giacalone',
#     'given_name': 'F',
#     'surname': 'Giacalone'},
#    {'full_name': 'J L Segura',
#     'given_name': 'J',
#     'middle_name': 'L',
#     'surname': 'Segura'},
#    {'full_name': 'N Martin', 'given_name': 'N', 'surname': 'Martin'},
#    {'full_name': 'J Ramey', 'given_name': 'J', 'surname': 'Ramey'},
#    {'full_name': 'D M Guldi',
#     'given_name': 'D',
#     'middle_name': 'M',
#     'surname': 'Guldi'}],
#   'index': 35,
#   'id': 'b35',
#   'unstructured': 'F. Giacalone, J. L. Segura, N. Martin, J. Ramey and D. M. Guldi, Chem.-Eur. J., 2005, 11, 4819.',
#   'date': '2005',
#   'journal': 'Chem.-Eur. J',
#   'pages': '4819'},
#  {'authors': [{'full_name': 'D M Guldi',
#     'given_name': 'D',
#     'middle_name': 'M',
#     'surname': 'Guldi'},
#    {'full_name': 'A Gouloumis', 'given_name': 'A', 'surname': 'Gouloumis'},
#    {'full_name': 'P Va´zquez', 'given_name': 'P', 'surname': 'Va´zquez'},
#    {'full_name': 'T Torres', 'given_name': 'T', 'surname': 'Torres'}],
#   'index': 36,
#   'id': 'b36',
#   'unstructured': 'Unpublished results. 36 (a) D. M. Guldi, A. Gouloumis, P. Va´zquez and T. Torres, Chem. Commun., 2002, 205; (b) D. M. Guldi, J. Ramey, M. Victoria Martı´nez-Dı´az, A. de la Escosura, T. Torres and M. Prato, Chem. Commun., 2002, 2774.',
#   'date': '2002',
#   'editors': [{'full_name': 'b) D. M. Guldi, J. Ramey, M. Victoria Martı´nez-Dı´az, A. de la Escosura, T. Torres and M. Prato'}],
#   'journal': 'Chem. Commun',
#   'volume': '36',
#   'pages': '2774',
#   'note': 'Chem. Commun.'},
#  {'authors': [{'full_name': 'T Nishioka',
#     'given_name': 'T',
#     'surname': 'Nishioka'},
#    {'full_name': 'K Tashiro', 'given_name': 'K', 'surname': 'Tashiro'},
#    {'full_name': 'T Aida', 'given_name': 'T', 'surname': 'Aida'},
#    {'full_name': 'J.-Y Zheng', 'given_name': 'J.-Y', 'surname': 'Zheng'},
#    {'full_name': 'K Kinbara', 'given_name': 'K', 'surname': 'Kinbara'},
#    {'full_name': 'K Saigo', 'given_name': 'K', 'surname': 'Saigo'},
#    {'full_name': 'S Sakamoto', 'given_name': 'S', 'surname': 'Sakamoto'},
#    {'full_name': 'K Yamaguchi', 'given_name': 'K', 'surname': 'Yamaguchi'}],
#   'index': 37,
#   'id': 'b37',
#   'unstructured': 'T. Nishioka, K. Tashiro, T. Aida, J.-Y. Zheng, K. Kinbara, K. Saigo, S. Sakamoto and K. Yamaguchi, Macromolecules, 2000, 33, 9182.',
#   'date': '2000',
#   'journal': 'Macromolecules',
#   'pages': '9182'},
#  {'authors': [{'full_name': 'H Luo', 'given_name': 'H', 'surname': 'Luo'},
#    {'full_name': 'M.-S Choi', 'given_name': 'M.-S', 'surname': 'Choi'},
#    {'full_name': 'Y Araki', 'given_name': 'Y', 'surname': 'Araki'},
#    {'full_name': 'O Ito', 'given_name': 'O', 'surname': 'Ito'},
#    {'full_name': 'T Aida', 'given_name': 'T', 'surname': 'Aida'}],
#   'index': 38,
#   'id': 'b38',
#   'unstructured': 'H. Luo, M.-S. Choi, Y. Araki, O. Ito and T. Aida, Bull. Chem. Soc., 2005, 78, 405.',
#   'date': '2005',
#   'journal': 'Bull. Chem. Soc',
#   'pages': '405'},
#  {'authors': [{'full_name': 'W.-S Li', 'given_name': 'W.-S', 'surname': 'Li'},
#    {'full_name': 'K S Kim',
#     'given_name': 'K',
#     'middle_name': 'S',
#     'surname': 'Kim'},
#    {'full_name': 'D.-L Jiang', 'given_name': 'D.-L', 'surname': 'Jiang'},
#    {'full_name': 'H Tanaka', 'given_name': 'H', 'surname': 'Tanaka'},
#    {'full_name': 'T Kawai', 'given_name': 'T', 'surname': 'Kawai'},
#    {'full_name': 'J H Kwon',
#     'given_name': 'J',
#     'middle_name': 'H',
#     'surname': 'Kwon'},
#    {'full_name': 'D Kim', 'given_name': 'D', 'surname': 'Kim'},
#    {'full_name': 'T Aida', 'given_name': 'T', 'surname': 'Aida'}],
#   'index': 39,
#   'id': 'b39',
#   'unstructured': 'W.-S. Li, K. S. Kim, D.-L. Jiang, H. Tanaka, T. Kawai, J. H. Kwon, D. Kim and T. Aida, J. Am. Chem. Soc., 2006, 128, 10527.',
#   'date': '2006',
#   'journal': 'J. Am. Chem. Soc',
#   'pages': '10527'},
#  {'authors': [{'full_name': 'H Li', 'given_name': 'H', 'surname': 'Li'},
#    {'full_name': 'R B Martin',
#     'given_name': 'R',
#     'middle_name': 'B',
#     'surname': 'Martin'},
#    {'full_name': 'B A Harruff',
#     'given_name': 'B',
#     'middle_name': 'A',
#     'surname': 'Harruff'},
#    {'full_name': 'R A Carino',
#     'given_name': 'R',
#     'middle_name': 'A',
#     'surname': 'Carino'},
#    {'full_name': 'L F Allard',
#     'given_name': 'L',
#     'middle_name': 'F',
#     'surname': 'Allard'},
#    {'full_name': 'Y.-P Sun', 'given_name': 'Y.-P', 'surname': 'Sun'}],
#   'index': 40,
#   'id': 'b40',
#   'unstructured': 'H. Li, R. B. Martin, B. A. Harruff, R. A. Carino, L. F. Allard and Y.-P. Sun, Adv. Mater., 2004, 16, 896.',
#   'date': '2004',
#   'journal': 'Adv. Mater',
#   'pages': '896'},
#  {'authors': [{'full_name': 'D Baskaran',
#     'given_name': 'D',
#     'surname': 'Baskaran'},
#    {'full_name': 'J W Mays',
#     'given_name': 'J',
#     'middle_name': 'W',
#     'surname': 'Mays'},
#    {'full_name': 'X P Zhang',
#     'given_name': 'X',
#     'middle_name': 'P',
#     'surname': 'Zhang'},
#    {'full_name': 'M S Bratcher',
#     'given_name': 'M',
#     'middle_name': 'S',
#     'surname': 'Bratcher'}],
#   'index': 41,
#   'id': 'b41',
#   'unstructured': 'D. Baskaran, J. W. Mays, X. P. Zhang and M. S. Bratcher, J. Am. Chem. Soc., 2005, 127, 6916.',
#   'date': '2005',
#   'journal': 'J. Am. Chem. Soc',
#   'pages': '6916'},
#  {'authors': [{'full_name': 'G De La Torre',
#     'given_name': 'G',
#     'surname': 'De La Torre'},
#    {'full_name': 'W Blau', 'given_name': 'W', 'surname': 'Blau'},
#    {'full_name': 'T Torres', 'given_name': 'T', 'surname': 'Torres'}],
#   'index': 42,
#   'id': 'b42',
#   'unstructured': 'G. de la Torre, W. Blau and T. Torres, Nanotechnology, 2003, 14, 765.',
#   'date': '2003',
#   'journal': 'Nanotechnology',
#   'volume': '14',
#   'pages': '765'},
#  {'authors': [{'full_name': 'M Alvaro',
#     'given_name': 'M',
#     'surname': 'Alvaro'},
#    {'full_name': 'P Atienzar', 'given_name': 'P', 'surname': 'Atienzar'},
#    {'full_name': 'P De La Cruz', 'given_name': 'P', 'surname': 'De La Cruz'},
#    {'full_name': 'J L Delgado',
#     'given_name': 'J',
#     'middle_name': 'L',
#     'surname': 'Delgado'},
# ...
#     'given_name': 'J',
#     'middle_name': 'T',
#     'surname': 'Park'}],
#   'index': 71,
#   'id': 'b71',
#   'unstructured': 'Y. J. Cho, T. K. Ahn, H. Song, K. S. Kim, C. Y. Lee, W. S. Seo, K. Lee, S. K. Kim, D. Kim and J. T. Park, J. Am. Chem. Soc., 2005, 127, 2380.',
#   'date': '2005',
#   'journal': 'J. Am. Chem. Soc',
#   'pages': '2380'},
#  {'authors': [{'full_name': 'H Imahori',
#     'given_name': 'H',
#     'surname': 'Imahori'},
#    {'full_name': 'J.-C Liu', 'given_name': 'J.-C', 'surname': 'Liu'},
#    {'full_name': 'K Hosomizu', 'given_name': 'K', 'surname': 'Hosomizu'},
#    {'full_name': 'T Sato', 'given_name': 'T', 'surname': 'Sato'},
#    {'full_name': 'Y Mori', 'given_name': 'Y', 'surname': 'Mori'},
#    {'full_name': 'H Hotta', 'given_name': 'H', 'surname': 'Hotta'},
#    {'full_name': 'Y Matano', 'given_name': 'Y', 'surname': 'Matano'},
#    {'full_name': 'Y Araki', 'given_name': 'Y', 'surname': 'Araki'},
#    {'full_name': 'O Ito', 'given_name': 'O', 'surname': 'Ito'},
#    {'full_name': 'N Maruyama', 'given_name': 'N', 'surname': 'Maruyama'},
#    {'full_name': 'S M Fujita ; B) D',
#     'given_name': 'S',
#     'middle_name': 'M',
#     'surname': 'Fujita ; B) D'},
#    {'full_name': 'I Guldi', 'given_name': 'I', 'surname': 'Guldi'},
#    {'full_name': 'G A Zilbermann',
#     'given_name': 'G',
#     'middle_name': 'A',
#     'surname': 'Zilbermann'},
#    {'full_name': 'K Anderson', 'given_name': 'K', 'surname': 'Anderson'},
#    {'full_name': 'M Kordatos', 'given_name': 'M', 'surname': 'Kordatos'},
#    {'full_name': 'R Prato', 'given_name': 'R', 'surname': 'Prato'},
#    {'full_name': 'L Tafuro', 'given_name': 'L', 'surname': 'Tafuro'},
#    {'full_name': ') S Valli ; C',
#     'given_name': ')',
#     'middle_name': 'S',
#     'surname': 'Valli ; C'},
#    {'full_name': 'D M Conoci',
#     'given_name': 'D',
#     'middle_name': 'M',
#     'surname': 'Conoci'},
#    {'full_name': 'S Guldi', 'given_name': 'S', 'surname': 'Guldi'},
#    {'full_name': 'R Nardis', 'given_name': 'R', 'surname': 'Nardis'},
#    {'full_name': 'K Paolesse', 'given_name': 'K', 'surname': 'Paolesse'},
#    {'full_name': 'M Kordatos', 'given_name': 'M', 'surname': 'Kordatos'},
#    {'full_name': 'G Prato', 'given_name': 'G', 'surname': 'Prato'},
#    {'full_name': 'M G H Ricciardi',
#     'given_name': 'M',
#     'middle_name': 'G H',
#     'surname': 'Ricciardi'},
#    {'full_name': 'I Vicente', 'given_name': 'I', 'surname': 'Vicente'},
#    {'full_name': 'L Zilbermann', 'given_name': 'L', 'surname': 'Zilbermann'},
#    {'full_name': 'K Valli ; T. Vuorinen',
#     'given_name': 'K',
#     'surname': 'Valli ; T. Vuorinen'},
#    {'full_name': 'N V Kaunisto',
#     'given_name': 'N',
#     'middle_name': 'V',
#     'surname': 'Kaunisto'},
#    {'full_name': 'A Tkachenko', 'given_name': 'A', 'surname': 'Tkachenko'},
#    {'full_name': 'H Efimov', 'given_name': 'H', 'surname': 'Efimov'},
#    {'full_name': 'A S Lemmetyinen',
#     'given_name': 'A',
#     'middle_name': 'S',
#     'surname': 'Lemmetyinen'},
#    {'full_name': 'K Alekseev', 'given_name': 'K', 'surname': 'Alekseev'},
#    {'full_name': 'H Hosomizu', 'given_name': 'H', 'surname': 'Hosomizu'},
#    {'full_name': 'I Imahori ; M. Guldi',
#     'given_name': 'I',
#     'surname': 'Imahori ; M. Guldi'},
#    {'full_name': 'G Zilbermann', 'given_name': 'G', 'surname': 'Zilbermann'},
#    {'full_name': 'A Anderson', 'given_name': 'A', 'surname': 'Anderson'},
#    {'full_name': 'D Li', 'given_name': 'D', 'surname': 'Li'},
#    {'full_name': 'N Balbinot', 'given_name': 'N', 'surname': 'Balbinot'},
#    {'full_name': 'M Jux', 'given_name': 'M', 'surname': 'Jux'},
#    {'full_name': 'A Hatzimarinaki',
#     'given_name': 'A',
#     'surname': 'Hatzimarinaki'},
#    {'full_name': 'M Hirsch', 'given_name': 'M', 'surname': 'Hirsch'},
#    {'full_name': 'M Prato ; D', 'middle_name': 'M', 'surname': 'Prato ; D'},
#    {'full_name': 'F Guldi', 'given_name': 'F', 'surname': 'Guldi'},
#    {'full_name': 'M Pellarini', 'given_name': 'M', 'surname': 'Pellarini'},
#    {'full_name': 'C Prato', 'given_name': 'C', 'surname': 'Prato'},
#    {'full_name': 'L Granito', 'given_name': 'L', 'surname': 'Granito'},
#    {'full_name': 'J C Troisi ; H. Imahori',
#     'given_name': 'J',
#     'middle_name': 'C',
#     'surname': 'Troisi ; H. Imahori'},
#    {'full_name': 'H Liu', 'given_name': 'H', 'surname': 'Liu'},
#    {'full_name': 'A Hotta', 'given_name': 'A', 'surname': 'Hotta'},
#    {'full_name': 'T Kira', 'given_name': 'T', 'surname': 'Kira'},
#    {'full_name': 'Y Umeyama', 'given_name': 'Y', 'surname': 'Umeyama'},
#    {'full_name': 'G Matano', 'given_name': 'G', 'surname': 'Matano'},
#    {'full_name': 'S Li', 'given_name': 'S', 'surname': 'Li'},
#    {'full_name': 'M Ye', 'given_name': 'M', 'surname': 'Ye'},
#    {'full_name': 'N V Isosomppi',
#     'given_name': 'N',
#     'middle_name': 'V',
#     'surname': 'Isosomppi'},
#    {'full_name': 'H Tkachenko', 'given_name': 'H', 'surname': 'Tkachenko'},
#    {'full_name': 'A Lemmetyinen ; H. Imahori',
#     'given_name': 'A',
#     'surname': 'Lemmetyinen ; H. Imahori'},
#    {'full_name': 'S Fujimoto', 'given_name': 'S', 'surname': 'Fujimoto'},
#    {'full_name': 'H Kang', 'given_name': 'H', 'surname': 'Kang'},
#    {'full_name': 'K Hotta', 'given_name': 'K', 'surname': 'Hotta'},
#    {'full_name': 'T Yoshida', 'given_name': 'T', 'surname': 'Yoshida'},
#    {'full_name': 'Y Umeyama', 'given_name': 'Y', 'surname': 'Umeyama'},
#    {'full_name': 'S Matano', 'given_name': 'S', 'surname': 'Matano'},
#    {'full_name': 'H Isoda ; T. Hasobe',
#     'given_name': 'H',
#     'surname': 'Isoda ; T. Hasobe'},
#    {'full_name': 'P V Imahori',
#     'given_name': 'P',
#     'middle_name': 'V',
#     'surname': 'Imahori'},
#    {'full_name': 'T K Kamat',
#     'given_name': 'T',
#     'middle_name': 'K',
#     'surname': 'Kamat'},
#    {'full_name': 'S K Ahn',
#     'given_name': 'S',
#     'middle_name': 'K',
#     'surname': 'Ahn'},
#    {'full_name': 'D Kim', 'given_name': 'D', 'surname': 'Kim'},
#    {'full_name': 'A Kim', 'given_name': 'A', 'surname': 'Kim'},
#    {'full_name': 'T Fujimoto', 'given_name': 'T', 'surname': 'Fujimoto'},
#    {'full_name': 'S Hirakawa', 'given_name': 'S', 'surname': 'Hirakawa'},
#    {'full_name': 'Fukuzumi', 'surname': 'Fukuzumi'}],
#   'index': 72,
#   'id': 'b72',
#   'unstructured': 'H. Imahori, J.-C. Liu, K. Hosomizu, T. Sato, Y. Mori, H. Hotta, Y. Matano, Y. Araki, O. Ito, N. Maruyama and S. Fujita, Chem. Commun., 2004, 2066; (b) D. M. Guldi, I. Zilbermann, G. A. Anderson, K. Kordatos, M. Prato, R. Tafuro and L. Valli, J. Mater. Chem., 2004, 14, 303; (c) S. Conoci, D. M. Guldi, S. Nardis, R. Paolesse, K. Kordatos, M. Prato, G. Ricciardi, M. G. H. Vicente, I. Zilbermann and L. Valli, Chem.-Eur. J., 2004, 10, 6523; (d) T. Vuorinen, K. Kaunisto, N. V. Tkachenko, A. Efimov, H. Lemmetyinen, A. S. Alekseev, K. Hosomizu and H. Imahori, Langmuir, 2005, 21, 5383; (e) D. M. Guldi, I. Zilbermann, G. Anderson, A. Li, D. Balbinot, N. Jux, M. Hatzimarinaki, A. Hirsch and M. Prato, Chem. Commun., 2004, 726; (f) D. M. Guldi, F. Pellarini, M. Prato, C. Granito and L. Troisi, Nano Lett., 2002, 2, 965; (g) H. Imahori, J. C. Liu, H. Hotta, A. Kira, T. Umeyama, Y. Matano, G. Li, S. Ye, M. Isosomppi, N. V. Tkachenko and H. Lemmetyinen, J. Phys. Chem. B, 2005, 109, 18465. 75 (a) T. Hasobe, H. Imahori, P. V. Kamat and S. Fukuzumi, J. Am. Chem. Soc., 2003, 125, 14962; (b) H. Imahori, A. Fujimoto, S. Kang, H. Hotta, K. Yoshida, T. Umeyama, Y. Matano and S. Isoda, Adv. Mater., 2005, 17, 1727; (c) T. Hasobe, H. Imahori, P. V. Kamat, T. K. Ahn, S. K. Kim, D. Kim, A. Fujimoto, T. Hirakawa and S. Fukuzumi, J. Am. Chem. Soc., 2005, 127, 1216.',
#   'date': '1727',
#   'editors': [{'full_name': 'T. Hasobe, H. Imahori, P. V. Kamat and S. Fukuzumi'}],
#   'journal': 'J. Am. Chem. Soc',
#   'volume': '14',
#   'pages': '1216',
#   'note': 'J. Am. Chem. Soc.'},
#  {'authors': [{'full_name': 'T Hasobe',
#     'given_name': 'T',
#     'surname': 'Hasobe'},
#    {'full_name': 'P V Kamat',
#     'given_name': 'P',
#     'middle_name': 'V',
#     'surname': 'Kamat'},
#    {'full_name': 'V Troiani', 'given_name': 'V', 'surname': 'Troiani'},
#    {'full_name': 'N Solladie', 'given_name': 'N', 'surname': 'Solladie'},
#    {'full_name': 'T K Ahn',
#     'given_name': 'T',
#     'middle_name': 'K',
#     'surname': 'Ahn'},
#    {'full_name': 'S K Kim',
#     'given_name': 'S',
#     'middle_name': 'K',
#     'surname': 'Kim'},
#    {'full_name': 'D Kim', 'given_name': 'D', 'surname': 'Kim'},
#    {'full_name': 'A Kongkanand', 'given_name': 'A', 'surname': 'Kongkanand'},
#    {'full_name': 'S Kuwabata', 'given_name': 'S', 'surname': 'Kuwabata'},
#    {'full_name': 'S Fukuzumi', 'given_name': 'S', 'surname': 'Fukuzumi'}],
#   'index': 73,
#   'id': 'b73',
#   'unstructured': 'T. Hasobe, P. V. Kamat, V. Troiani, N. Solladie, T. K. Ahn, S. K. Kim, D. Kim, A. Kongkanand, S. Kuwabata and S. Fukuzumi, J. Phys. Chem. B, 2005, 109, 19.',
#   'date': '2005',
#   'journal': 'J. Phys. Chem. B',
#   'volume': '109',
#   'pages': '19'},
#  {'authors': [{'full_name': 'T Hasobe',
#     'given_name': 'T',
#     'surname': 'Hasobe'},
#    {'full_name': 'H Imahori', 'given_name': 'H', 'surname': 'Imahori'},
#    {'full_name': 'S Fukuzumi', 'given_name': 'S', 'surname': 'Fukuzumi'},
#    {'full_name': 'P V Kamat',
#     'given_name': 'P',
#     'middle_name': 'V',
#     'surname': 'Kamat'},
#    {'full_name': '; T Hasobe', 'given_name': '; T', 'surname': 'Hasobe'},
#    {'full_name': 'P V Kamat',
#     'given_name': 'P',
#     'middle_name': 'V',
#     'surname': 'Kamat'},
#    {'full_name': 'M A Absalom',
#     'given_name': 'M',
#     'middle_name': 'A',
#     'surname': 'Absalom'},
#    {'full_name': 'Y Kashiwagi', 'given_name': 'Y', 'surname': 'Kashiwagi'},
#    {'full_name': 'J Sly', 'given_name': 'J', 'surname': 'Sly'},
#    {'full_name': 'M J Crossley',
#     'given_name': 'M',
#     'middle_name': 'J',
#     'surname': 'Crossley'},
#    {'full_name': 'K Hosomizu', 'given_name': 'K', 'surname': 'Hosomizu'},
#    {'full_name': 'H Imahori', 'given_name': 'H', 'surname': 'Imahori'},
#    {'full_name': 'S Fukuzumi ; T. Hasobe',
#     'given_name': 'S',
#     'surname': 'Fukuzumi ; T. Hasobe'},
#    {'full_name': 'Y Kashiwagi', 'given_name': 'Y', 'surname': 'Kashiwagi'},
#    {'full_name': 'M A Absalom',
#     'given_name': 'M',
#     'middle_name': 'A',
#     'surname': 'Absalom'},
#    {'full_name': 'J Sly', 'given_name': 'J', 'surname': 'Sly'},
#    {'full_name': 'K Hosomizu', 'given_name': 'K', 'surname': 'Hosomizu'},
#    {'full_name': 'M J Crossley',
#     'given_name': 'M',
#     'middle_name': 'J',
#     'surname': 'Crossley'},
#    {'full_name': 'H Imahori', 'given_name': 'H', 'surname': 'Imahori'},
#    {'full_name': 'P V Kamat',
#     'given_name': 'P',
#     'middle_name': 'V',
#     'surname': 'Kamat'},
#    {'full_name': 'S Fukuzumi ; H. Imahori',
#     'given_name': 'S',
#     'surname': 'Fukuzumi ; H. Imahori'},
#    {'full_name': 'T Hasobe', 'given_name': 'T', 'surname': 'Hasobe'},
#    {'full_name': 'H Yamada', 'given_name': 'H', 'surname': 'Yamada'},
#    {'full_name': 'P V Kamat',
#     'given_name': 'P',
#     'middle_name': 'V',
#     'surname': 'Kamat'},
#    {'full_name': 'S Barazzouk', 'given_name': 'S', 'surname': 'Barazzouk'},
#    {'full_name': 'M Fujitsuka', 'given_name': 'M', 'surname': 'Fujitsuka'},
#    {'full_name': 'O Ito', 'given_name': 'O', 'surname': 'Ito'},
#    {'full_name': 'S Fukuzumi ; M. Guldi',
#     'given_name': 'S',
#     'surname': 'Fukuzumi ; M. Guldi'},
#    {'full_name': 'G M A Rahman',
#     'given_name': 'G',
#     'middle_name': 'M A',
#     'surname': 'Rahman'},
#    {'full_name': 'M Prato', 'given_name': 'M', 'surname': 'Prato'},
#    {'full_name': 'N Jux', 'given_name': 'N', 'surname': 'Jux'},
#    {'full_name': 'S Qin', 'given_name': 'S', 'surname': 'Qin'},
#    {'full_name': 'W T Ford',
#     'given_name': 'W',
#     'middle_name': 'T',
#     'surname': 'Ford'},
#    {'full_name': '; M Guldi', 'given_name': '; M', 'surname': 'Guldi'},
#    {'full_name': 'G M A Rahman',
#     'given_name': 'G',
#     'middle_name': 'M A',
#     'surname': 'Rahman'},
#    {'full_name': 'V Sgobba', 'given_name': 'V', 'surname': 'Sgobba'},
#    {'full_name': 'S Campidelli', 'given_name': 'S', 'surname': 'Campidelli'},
#    {'full_name': 'M Prato ; M. Guldi',
#     'given_name': 'M',
#     'surname': 'Prato ; M. Guldi'},
#    {'full_name': 'G M A Rahman',
#     'given_name': 'G',
#     'middle_name': 'M A',
#     'surname': 'Rahman'},
#    {'full_name': 'V Sgobba', 'given_name': 'V', 'surname': 'Sgobba'},
#    {'full_name': 'N A Kotov',
#     'given_name': 'N',
#     'middle_name': 'A',
#     'surname': 'Kotov'},
#    {'full_name': 'D Bonifazi', 'given_name': 'D', 'surname': 'Bonifazi'},
#    {'full_name': 'M Prato', 'given_name': 'M', 'surname': 'Prato'}],
#   'index': 74,
#   'id': 'b74',
#   'unstructured': 'T. Hasobe, H. Imahori, S. Fukuzumi and P. V. Kamat, J. Phys. Chem. B, 2003, 107, 12105; (b) T. Hasobe, P. V. Kamat, M. A. Absalom, Y. Kashiwagi, J. Sly, M. J. Crossley, K. Hosomizu, H. Imahori and S. Fukuzumi, J. Phys. Chem. B, 2004, 108, 12865; (c) T. Hasobe, Y. Kashiwagi, M. A. Absalom, J. Sly, K. Hosomizu, M. J. Crossley, H. Imahori, P. V. Kamat and S. Fukuzumi, Adv. Mater., 2004, 16, 975; (d) H. Imahori, T. Hasobe, H. Yamada, P. V. Kamat, S. Barazzouk, M. Fujitsuka, O. Ito and S. Fukuzumi, Chem. Lett., 2001, 8, 784. 78 (a) D. M. Guldi, G. M. A. Rahman, M. Prato, N. Jux, S. Qin and W. T. Ford, Angew. Chem., Int. Ed., 2005, 44, 2015; (b) D. M. Guldi, G. M. A. Rahman, V. Sgobba, S. Campidelli and M. Prato, Adv. Mater., 2006, 18, 2264. 79 (a) D. M. Guldi, G. M. A. Rahman, V. Sgobba, N. A. Kotov, D. Bonifazi and M. Prato, J. Am. Chem. Soc., 2006, 128, 2315;',
#   'date': '2001',
#   'journal': 'Angew. Chem., Int. Ed',
#   'volume': '107',
#   'pages': '128',
#   'note': 'J. Am. Chem. Soc.'},
#  {'authors': [{'full_name': 'G M A Rahman',
#     'given_name': 'G',
#     'middle_name': 'M A',
#     'surname': 'Rahman'},
#    {'full_name': 'D M Guldi',
#     'given_name': 'D',
#     'middle_name': 'M',
#     'surname': 'Guldi'},
#    {'full_name': 'R Cagnoli', 'given_name': 'R', 'surname': 'Cagnoli'},
#    {'full_name': 'A Mucci', 'given_name': 'A', 'surname': 'Mucci'},
#    {'full_name': 'L Schenetti', 'given_name': 'L', 'surname': 'Schenetti'},
#    {'full_name': 'L Vaccari', 'given_name': 'L', 'surname': 'Vaccari'},
#    {'full_name': 'M Prato', 'given_name': 'M', 'surname': 'Prato'}],
#   'index': 75,
#   'id': 'b75',
#   'unstructured': 'G. M. A. Rahman, D. M. Guldi, R. Cagnoli, A. Mucci, L. Schenetti, L. Vaccari and M. Prato, J. Am. Chem. Soc., 2005, 127, 10051.',
#   'date': '2005',
#   'journal': 'J. Am. Chem. Soc',
#   'pages': '10051'},
#  {'authors': [{'full_name': 'T Hasobe',
#     'given_name': 'T',
#     'surname': 'Hasobe'},
#    {'full_name': 'S Fukuzumi', 'given_name': 'S', 'surname': 'Fukuzumi'},
#    {'full_name': 'P V Kamat',
#     'given_name': 'P',
#     'middle_name': 'V',
#     'surname': 'Kamat'}],
#   'index': 76,
#   'id': 'b76',
#   'unstructured': 'T. Hasobe, S. Fukuzumi and P. V. Kamat, J. Phys. Chem. B, 2006, 110, 25477.',
#   'date': '2006',
#   'journal': 'J. Phys. Chem. B'},
#  {'authors': [{'full_name': 'G Pagona',
#     'given_name': 'G',
#     'surname': 'Pagona'},
#    {'full_name': 'A S D Sandanayaka',
#     'given_name': 'A',
#     'middle_name': 'S D',
#     'surname': 'Sandanayaka'},
#    {'full_name': 'Y Araki', 'given_name': 'Y', 'surname': 'Araki'},
#    {'full_name': 'J Fan', 'given_name': 'J', 'surname': 'Fan'},
#    {'full_name': 'N Tagmatarchis',
#     'given_name': 'N',
#     'surname': 'Tagmatarchis'},
#    {'full_name': 'M Yudasaka', 'given_name': 'M', 'surname': 'Yudasaka'},
#    {'full_name': 'S Iijima', 'given_name': 'S', 'surname': 'Iijima'},
#    {'full_name': 'O Ito', 'given_name': 'O', 'surname': 'Ito'}],
#   'index': 77,
#   'id': 'b77',
#   'unstructured': 'G. Pagona, A. S. D. Sandanayaka, Y. Araki, J. Fan, N. Tagma- tarchis, M. Yudasaka, S. Iijima and O. Ito, J. Phys. Chem. B, 2006, 110, 20729.',
#   'date': '2006',
#   'journal': 'J. Phys. Chem. B',
#   'volume': '110',
#   'pages': '20729'},
#  {'authors': [{'full_name': 'N Martı´n',
#     'given_name': 'N',
#     'surname': 'Martı´n'}],
#   'index': 78,
#   'id': 'b78',
#   'unstructured': 'N. Martı´n, Chem. Commun., 2006, 2093.',
#   'date': '2006',
#   'journal': 'Chem. Commun',
#   'pages': '2093'}]

# %%
doc['abstract']
# Out:
# 'This article surveys and highlights the integration of nanometer scale carbon structures-in combination with chromophores that exhibit (i) significant absorption cross section throughout the visible part of the solar spectrum and (ii) good electron donating power-into novel electron donor-acceptor conjugates (i.e., covalent) and hybrids (i.e., non-covalent). The focus of this article is predominantly on performance features-charge-transfer and photovoltaic-of the most promising solar energy conversion systems. Besides documenting fundamental advantages as they emerge around nanometer scale carbon structures, critical evaluations of the most recent developments in the fields are provided. Scheme 1 Molecular building blocks-C 60 and single wall carbon nanotubes (SWNT)-as electron acceptors.'

# %%
doc['acknowledgement']
# Out:
# 'Acknowledgements This work was carried out with partial support from the SFB 583, DFG (GU 517/4-1), FCI, and the Office of Basic Energy Sciences of the U.S. Department of Energy. I am deeply indebted to Profs. Ford, Fukuzumi, Hirsch, Imahori, Jux, Kotov, Maggini, Martin, Prato, Schuster, Sessler, Torres, Valli, and Zilbermann for their productive collaborations and numerous stimulating discussions. This Invited Article is dedicated to Professor Ortwin Brede on the occasion of his 65th birthday and his retirement.'

# %%
doc['body'][0:2000]
# Out:
# 'Introduction It is foreseeable that artificial photosynthetic systems that will ultimately power practical solar fuels production must be based on molecular and supramolecular assemblies.  1  Specific requirements that such assemblies must meet include the collection of light energy, separation of charges, and transport of charges to catalytic sites, where water oxidation and CO 2 reduction will occur. Notable progress has been made on each aspect of these complex problems-yet researchers have not developed components that are both efficient and robust, and have not integrated the existing functional components into a working system.  2  The design and development of light harvesting, photoconversion, and-as a long term aim-catalytic modules capable of self-ordering and self-assembling into an integrated functional unit will make it possible to realize efficient artificial photosynthetic systems based on nanometer scale carbon structures. \n Electron acceptors A first prominent example of nanometer scale carbon structures are fullerenes-see Scheme 1. Ever since their initial discovery, scientists worldwide have studied their solid state properties ranging from superconductivity and nanostructured devices to endohedral fullerene chemistry.  3 Hereby, the three-dimensional structure of fullerenes, which exclusively consist of electron-rich hexagons and electron-deficient pentagons, evoked a lively interest to relate their properties to conventional one-dimensional p-systems. The extraordinary electron acceptor properties of, for example, the most abundant fullerene, namely, C 60 with a diameter of 7.8 A ˚, have led to noteworthy utilizations of such nanoscale architectures in areas of light-induced electron transfer chemistry and solar energy conversion. Importantly, original and well-established synthetic methodologies emerged as potent means en-route to a wide variety of novel fullerene derivatives.  4 Such methodologies ensure the complete control over chemically fu'

# %% [markdown]
# https://komax.github.io/blog/text/mining/grobid/
#
# https://komax.github.io/blog/text/python/xml/parsing_tei_xml_python/
#
# https://github.com/allenai/s2orc-doc2json
#
# https://gitlab.com/internetarchive/grobid_tei_xml
#
# https://github.com/delb-xml/delb-py

# %% [markdown]
# ---------------------------------

# %% [markdown]
# ### Transformando JSON em um DataFrame

# %% [markdown]
# - Há as seguintes entendidades: artigo, autores, instituições e referências;
# - Compondo uma publicação científica;
#     - Dentro do artigo temos várias informações da entidade de dados;
#     - E as referências possuem vários artigos, uma lista de artigos;

# %%
import datetime
import json

# %%
def get_process_datetime(doc,varnull=np.nan,deltah=3):
    r = doc.get('grobid_timestamp',varnull)
    if not pd.isna(r):
        r = pd.to_datetime(doc['grobid_timestamp'],errors='coerce',format='%Y-%m-%dT%H:%M+0000')
        r = r-pd.Timedelta(deltah,unit='hour')
        r = r.strftime('%Y-%m-%d %H:%M:00')
    return r

# %%
def get_doc(doc):
    
    """Get article information from the article documment"""
    
    dict_article = {'grobid_version':doc.get('grobid_version',np.nan),
                    'grobid_timestamp':get_process_datetime(doc,np.nan,3),
                    'pdf_md5':doc.get('pdf_md5',np.nan),
                    'language_code':doc.get('language_code',np.nan),
                    'acknowledgement':doc.get('acknowledgement',np.nan),
                    'abstract':doc.get('abstract',np.nan),
                    'body':doc.get('body',np.nan),
                    'annex ':doc.get('annex ',np.nan)}
    
    return [dict_article]


def get_head(doc, suffix='head'):
    
    """Get head information from the article documment"""

    default_dict = {'pdf_md5':doc.get('pdf_md5',np.nan),
                    '_'.join(['index',suffix]):np.nan,
                    '_'.join(['id',suffix]):np.nan,
                    '_'.join(['unstructured',suffix]):np.nan,
                    '_'.join(['date',suffix]):np.nan,
                    '_'.join(['title',suffix]):np.nan,
                    '_'.join(['book_title',suffix]):np.nan,
                    '_'.join(['series_title',suffix]):np.nan,
                    '_'.join(['journal',suffix]):np.nan,
                    '_'.join(['journal_abbrev',suffix]):np.nan,
                    '_'.join(['publisher',suffix]):np.nan,
                    '_'.join(['institution',suffix]):np.nan,
                    '_'.join(['issn',suffix]):np.nan,
                    '_'.join(['eissn',suffix]):np.nan,
                    '_'.join(['volume',suffix]):np.nan,
                    '_'.join(['issue',suffix]):np.nan,
                    '_'.join(['pages',suffix]):np.nan,
                    '_'.join(['first_page',suffix]):np.nan,
                    '_'.join(['last_page',suffix]):np.nan,
                    '_'.join(['note',suffix]):np.nan,
                    '_'.join(['doi',suffix]):np.nan,
                    '_'.join(['pmid',suffix]):np.nan,
                    '_'.join(['pmcid',suffix]):np.nan,
                    '_'.join(['arxiv_id',suffix]):np.nan,
                    '_'.join(['ark',suffix]):np.nan,
                    '_'.join(['istex_id',suffix]):np.nan,
                    '_'.join(['url',suffix]):np.nan}
    
    head = doc.get('header',np.nan)
    if not pd.isna(head):
        dict_head = {'pdf_md5':doc.get('pdf_md5',np.nan),
                     '_'.join(['index',suffix]):head.get('index',np.nan),
                     '_'.join(['id',suffix]):head.get('id',np.nan),
                     '_'.join(['unstructured',suffix]):head.get('unstructured',np.nan),
                     '_'.join(['date',suffix]):head.get('date',np.nan),
                     '_'.join(['title',suffix]):head.get('title',np.nan),
                     '_'.join(['book_title',suffix]):head.get('book_title',np.nan),
                     '_'.join(['series_title',suffix]):head.get('series_title',np.nan),
                     '_'.join(['journal',suffix]):head.get('journal',np.nan),
                     '_'.join(['journal_abbrev',suffix]):head.get('journal_abbrev',np.nan),
                     '_'.join(['publisher',suffix]):head.get('publisher',np.nan),
                     '_'.join(['institution',suffix]):head.get('institution',np.nan),
                     '_'.join(['issn',suffix]):head.get('issn',np.nan),
                     '_'.join(['eissn',suffix]):head.get('eissn',np.nan),
                     '_'.join(['volume',suffix]):head.get('volume',np.nan),
                     '_'.join(['issue',suffix]):head.get('issue',np.nan),
                     '_'.join(['pages',suffix]):head.get('pages',np.nan),
                     '_'.join(['first_page',suffix]):head.get('first_page',np.nan),
                     '_'.join(['last_page',suffix]):head.get('last_page',np.nan),
                     '_'.join(['note',suffix]):head.get('note',np.nan),
                     '_'.join(['doi',suffix]):head.get('doi',np.nan),
                     '_'.join(['pmid',suffix]):head.get('pmid',np.nan),
                     '_'.join(['pmcid',suffix]):head.get('pmcid',np.nan),
                     '_'.join(['arxiv_id',suffix]):head.get('arxiv_id',np.nan),
                     '_'.join(['ark',suffix]):head.get('ark',np.nan),
                     '_'.join(['istex_id',suffix]):head.get('istex_id',np.nan),
                     '_'.join(['url',suffix]):head.get('url',np.nan)}
        return [dict_head]
    return [default_dict]


def get_authors(doc, key_doc='header',key_authors='authors',suffix='author'):
    
    """Get authors from the article documment"""
    
    default_fict = {'pdf_md5':doc.get('pdf_md5',np.nan),
                    '_'.join(['full_name',suffix]):np.nan,
                    '_'.join(['given_name',suffix]):np.nan,
                    '_'.join(['middle_name',suffix]):np.nan,
                    '_'.join(['surname',suffix]):np.nan,
                    '_'.join(['email',suffix]):np.nan,
                    '_'.join(['orcid',suffix]):np.nan,
                    '_'.join(['institution',suffix]):np.nan,
                    '_'.join(['department',suffix]):np.nan,
                    '_'.join(['laboratory',suffix]):np.nan,
                    '_'.join(['addr_line',suffix]):np.nan,
                    '_'.join(['post_code',suffix]):np.nan,
                    '_'.join(['settlement',suffix]):np.nan,
                    '_'.join(['country',suffix]):np.nan}
    
    head = doc.get(key_doc,np.nan)
    if not pd.isna(head):
        authors = head.get(key_authors,[])
        if len(authors):
            lista_authors = []
            for author in authors:
                affiliation = author.get('affiliation',np.nan)
                address = affiliation.get('address',np.nan) if not pd.isna(affiliation) else np.nan
                dict_authors = {'pdf_md5':doc.get('pdf_md5',np.nan),
                                '_'.join(['full_name',suffix]):author.get('full_name',np.nan),
                                '_'.join(['given_name',suffix]):author.get('given_name',np.nan),
                                '_'.join(['middle_name',suffix]):author.get('middle_name',np.nan),
                                '_'.join(['surname',suffix]):author.get('surname',np.nan),
                                '_'.join(['email',suffix]):author.get('email',np.nan),
                                '_'.join(['orcid',suffix]):author.get('orcid',np.nan),
                                '_'.join(['institution',suffix]):affiliation.get('institution',np.nan) if not pd.isna(affiliation) else np.nan,
                                '_'.join(['department',suffix]):affiliation.get('department',np.nan) if not pd.isna(affiliation) else np.nan,
                                '_'.join(['laboratory',suffix]):affiliation.get('laboratory',np.nan) if not pd.isna(affiliation) else np.nan,
                                '_'.join(['addr_line',suffix]):address.get('addr_line',np.nan) if not pd.isna(address) else np.nan,
                                '_'.join(['post_code',suffix]):address.get('post_code',np.nan) if not pd.isna(address) else np.nan,
                                '_'.join(['settlement',suffix]):address.get('settlement',np.nan) if not pd.isna(address) else np.nan,
                                '_'.join(['country',suffix]):address.get('country',np.nan) if not pd.isna(address) else np.nan}
                lista_authors.append(dict_authors)
            return lista_authors
        return [default_fict]
    return [default_fict]


def get_citations(doc, suffix='citation'):
    
    """Get citations informations from the article documment"""

    default_dict = {'pdf_md5':doc.get('pdf_md5',np.nan),
                    '_'.join(['index',suffix]):np.nan,
                    '_'.join(['id',suffix]):np.nan,
                    '_'.join(['unstructured',suffix]):np.nan,
                    '_'.join(['date',suffix]):np.nan,
                    '_'.join(['title',suffix]):np.nan,
                    '_'.join(['book_title',suffix]):np.nan,
                    '_'.join(['series_title',suffix]):np.nan,
                    '_'.join(['journal',suffix]):np.nan,
                    '_'.join(['journal_abbrev',suffix]):np.nan,
                    '_'.join(['publisher',suffix]):np.nan,
                    '_'.join(['institution',suffix]):np.nan,
                    '_'.join(['issn',suffix]):np.nan,
                    '_'.join(['eissn',suffix]):np.nan,
                    '_'.join(['volume',suffix]):np.nan,
                    '_'.join(['issue',suffix]):np.nan,
                    '_'.join(['pages',suffix]):np.nan,
                    '_'.join(['first_page',suffix]):np.nan,
                    '_'.join(['last_page',suffix]):np.nan,
                    '_'.join(['note',suffix]):np.nan,
                    '_'.join(['doi',suffix]):np.nan,
                    '_'.join(['pmid',suffix]):np.nan,
                    '_'.join(['pmcid',suffix]):np.nan,
                    '_'.join(['arxiv_id',suffix]):np.nan,
                    '_'.join(['ark',suffix]):np.nan,
                    '_'.join(['istex_id',suffix]):np.nan,
                    '_'.join(['url',suffix]):np.nan}
    
    citations = doc.get('citations',[])
    if len(citations):
        lista_citations = []
        for citation in citations:
            dict_cit = {'pdf_md5':doc.get('pdf_md5',np.nan),
                        '_'.join(['index',suffix]):citation.get('index',np.nan),
                        '_'.join(['id',suffix]):citation.get('id',np.nan),
                        '_'.join(['unstructured',suffix]):citation.get('unstructured',np.nan),
                        '_'.join(['date',suffix]):citation.get('date',np.nan),
                        '_'.join(['title',suffix]):citation.get('title',np.nan),
                        '_'.join(['book_title',suffix]):citation.get('book_title',np.nan),
                        '_'.join(['series_title',suffix]):citation.get('series_title',np.nan),
                        '_'.join(['journal',suffix]):citation.get('journal',np.nan),
                        '_'.join(['journal_abbrev',suffix]):citation.get('journal_abbrev',np.nan),
                        '_'.join(['publisher',suffix]):citation.get('publisher',np.nan),
                        '_'.join(['institution',suffix]):citation.get('institution',np.nan),
                        '_'.join(['issn',suffix]):citation.get('issn',np.nan),
                        '_'.join(['eissn',suffix]):citation.get('eissn',np.nan),
                        '_'.join(['volume',suffix]):citation.get('volume',np.nan),
                        '_'.join(['issue',suffix]):citation.get('issue',np.nan),
                        '_'.join(['pages',suffix]):citation.get('pages',np.nan),
                        '_'.join(['first_page',suffix]):citation.get('first_page',np.nan),
                        '_'.join(['last_page',suffix]):citation.get('last_page',np.nan),
                        '_'.join(['note',suffix]):citation.get('note',np.nan),
                        '_'.join(['doi',suffix]):citation.get('doi',np.nan),
                        '_'.join(['pmid',suffix]):citation.get('pmid',np.nan),
                        '_'.join(['pmcid',suffix]):citation.get('pmcid',np.nan),
                        '_'.join(['arxiv_id',suffix]):citation.get('arxiv_id',np.nan),
                        '_'.join(['ark',suffix]):citation.get('ark',np.nan),
                        '_'.join(['istex_id',suffix]):citation.get('istex_id',np.nan),
                        '_'.join(['url',suffix]):citation.get('url',np.nan)}
            lista_citations.append(dict_cit)
        return lista_citations
    return default_dict


def get_citation_authors(citation, suffix='citation'):
    
    """Get authors information from one only citation in the article documment"""

    default_fict = {'id':citation.get('id',np.nan),
                    'index':citation.get('index',np.nan),
                    'pdf_md5':doc.get('pdf_md5',np.nan),
                    '_'.join(['full_name',suffix]):np.nan,
                    '_'.join(['given_name',suffix]):np.nan,
                    '_'.join(['middle_name',suffix]):np.nan,
                    '_'.join(['surname',suffix]):np.nan,
                    '_'.join(['email',suffix]):np.nan,
                    '_'.join(['orcid',suffix]):np.nan,
                    '_'.join(['institution',suffix]):np.nan,
                    '_'.join(['department',suffix]):np.nan,
                    '_'.join(['laboratory',suffix]):np.nan,
                    '_'.join(['addr_line',suffix]):np.nan,
                    '_'.join(['post_code',suffix]):np.nan,
                    '_'.join(['settlement',suffix]):np.nan,
                    '_'.join(['country',suffix]):np.nan}
    
    authors = citation.get('authors',[])
    if len(authors):
        lista_authors = []
        for author in authors:
            affiliation = author.get('affiliation',np.nan)
            address = affiliation.get('address',np.nan) if not pd.isna(affiliation) else np.nan
            dict_authors = {'id':citation.get('id',np.nan),
                            'index':citation.get('index',np.nan),
                            'pdf_md5':doc.get('pdf_md5',np.nan),
                            '_'.join(['full_name',suffix]):author.get('full_name',np.nan),
                            '_'.join(['given_name',suffix]):author.get('given_name',np.nan),
                            '_'.join(['middle_name',suffix]):author.get('middle_name',np.nan),
                            '_'.join(['surname',suffix]):author.get('surname',np.nan),
                            '_'.join(['email',suffix]):author.get('email',np.nan),
                            '_'.join(['orcid',suffix]):author.get('orcid',np.nan),
                            '_'.join(['institution',suffix]):affiliation.get('institution',np.nan) if not pd.isna(affiliation) else np.nan,
                            '_'.join(['department',suffix]):affiliation.get('department',np.nan) if not pd.isna(affiliation) else np.nan,
                            '_'.join(['laboratory',suffix]):affiliation.get('laboratory',np.nan) if not pd.isna(affiliation) else np.nan,
                            '_'.join(['addr_line',suffix]):address.get('addr_line',np.nan) if not pd.isna(address) else np.nan,
                            '_'.join(['post_code',suffix]):address.get('post_code',np.nan) if not pd.isna(address) else np.nan,
                            '_'.join(['settlement',suffix]):address.get('settlement',np.nan) if not pd.isna(address) else np.nan,
                            '_'.join(['country',suffix]):address.get('country',np.nan) if not pd.isna(address) else np.nan}
            lista_authors.append(dict_authors)
        return lista_authors
    return [default_fict]


def get_citations_authors(doc, suffix='citation'):
    
    """Get authors information from all the citations in the article documment"""

    default_fict = {'id':np.nan,
                    'index':np.nan,
                    'pdf_md5':doc.get('pdf_md5',np.nan),
                    '_'.join(['full_name',suffix]):np.nan,
                    '_'.join(['given_name',suffix]):np.nan,
                    '_'.join(['middle_name',suffix]):np.nan,
                    '_'.join(['surname',suffix]):np.nan,
                    '_'.join(['email',suffix]):np.nan,
                    '_'.join(['orcid',suffix]):np.nan,
                    '_'.join(['institution',suffix]):np.nan,
                    '_'.join(['department',suffix]):np.nan,
                    '_'.join(['laboratory',suffix]):np.nan,
                    '_'.join(['addr_line',suffix]):np.nan,
                    '_'.join(['post_code',suffix]):np.nan,
                    '_'.join(['settlement',suffix]):np.nan,
                    '_'.join(['country',suffix]):np.nan}
    
    citations = doc.get('citations',[])
    if len(citations):
        lista_citations_authors = []
        for citation in citations:
            lista_citations_authors += get_citation_authors(citation)
        return lista_citations_authors
    return default_fict


def

# %%
df_doc_info = pd.DataFrame(get_doc(doc))
df_doc_info.head()
# Out:
#   grobid_version     grobid_timestamp                           pdf_md5  \
# 0          0.7.0  2022-04-23 16:46:00  5B70A65B9D2AEC3DD3E6A64B4BD94CB2
#
#   language_code                                    acknowledgement  \
# 0            en  Acknowledgements This work was carried out wit...
#
#                                             abstract  \
# 0  This article surveys and highlights the integr...
#
#                                                 body  annex
# 0  Introduction It is foreseeable that artificial...     NaN

# %%
df_doc_head = pd.DataFrame(get_head(doc))
df_doc_head.head()
# Out:
#                             pdf_md5  index_head  id_head  unstructured_head  \
# 0  5B70A65B9D2AEC3DD3E6A64B4BD94CB2         NaN      NaN                NaN
#
#     date_head                                         title_head  \
# 0  2007-02-08  Nanometer scale carbon structures for charge-t...
#
#    book_title_head  series_title_head  journal_head  journal_abbrev_head  ...  \
# 0              NaN                NaN           NaN                  NaN  ...
#
#    first_page_head  last_page_head  note_head          doi_head  pmid_head  \
# 0              NaN             NaN        NaN  10.1039/b617684b        NaN
#
#    pmcid_head  arxiv_id_head  ark_head  istex_id_head  url_head
# 0         NaN            NaN       NaN            NaN       NaN
#
# [1 rows x 27 columns]

# %%
df_doc_authors = pd.DataFrame(get_authors(doc))
df_doc_authors.head()
# Out:
#                             pdf_md5 full_name_author given_name_author  \
# 0  5B70A65B9D2AEC3DD3E6A64B4BD94CB2     Dirk M Guldi              Dirk
#
#   middle_name_author surname_author  email_author  orcid_author  \
# 0                  M          Guldi           NaN           NaN
#
#       institution_author                                department_author  \
# 0  Universita¨t Erlangen  Institute of Physical and Theoretical Chemistry
#
#    laboratory_author  addr_line_author post_code_author settlement_author  \
# 0                NaN               NaN            91058          Erlangen
#
#   country_author
# 0        Germany

# %%
df_doc_citations = pd.DataFrame(get_citations(doc))
df_doc_citations.head()
# Out:
#                             pdf_md5  index_citation id_citation  \
# 0  5B70A65B9D2AEC3DD3E6A64B4BD94CB2               0          b0
# 1  5B70A65B9D2AEC3DD3E6A64B4BD94CB2               1          b1
# 2  5B70A65B9D2AEC3DD3E6A64B4BD94CB2               2          b2
# 3  5B70A65B9D2AEC3DD3E6A64B4BD94CB2               3          b3
# 4  5B70A65B9D2AEC3DD3E6A64B4BD94CB2               4          b4
#
#                                unstructured_citation date_citation  \
# 0  Basic Research Needs for Solar Energy Utilizat...          2005
# 1  V. Balzani, Electron Transfer in Chemistry, Wi...          2001
# 2  A. Hirsch and M. Brettreich, Fullerenes: Chemi...          2000
# 3  F. Diederich, L. Isaacs and D. Philp, Chem. So...          1994
# 4  S. Reich, C. Thomsen and J. Maultzsch, Carbon ...          2004
#
#                                       title_citation  \
# 0  Basic Research Needs for Solar Energy Utilization
# 1                     Electron Transfer in Chemistry
# 2  Fullerenes: From Synthesis to Optoelectronic P...
# 3                                                NaN
# 4  Carbon Nanotubes: Basic Concepts and Physical ...
#
#                                  book_title_citation series_title_citation  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2  Nuclear and Radiation Chemical Approaches to F...                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
#
#                                     journal_citation  journal_abbrev_citation  \
# 0  Report of the Basic Energy Sciences Workshop o...                      NaN
# 1                                           Weinheim                      NaN
# 2                                                NaN                      NaN
# 3                                  Compt. Rend. Chim                      NaN
# 4                                                NaN                      NaN
#
#    ... first_page_citation  last_page_citation  \
# 0  ...                 NaN                 NaN
# 1  ...                 NaN                 NaN
# 2  ...                 NaN                 NaN
# 3  ...                 NaN                 NaN
# 4  ...                 NaN                 NaN
#
#                                     note_citation  doi_citation pmid_citation  \
# 0                                             NaN           NaN           NaN
# 1                                             NaN           NaN           NaN
# 2  Fullerenes: Chemistry, Physics, and Technology           NaN           NaN
# 3                                 Chem. Soc. Rev.           NaN           NaN
# 4                                             NaN           NaN           NaN
#
#    pmcid_citation arxiv_id_citation  ark_citation  istex_id_citation  \
# 0             NaN               NaN           NaN                NaN
# 1             NaN               NaN           NaN                NaN
# 2             NaN               NaN           NaN                NaN
# 3             NaN               NaN           NaN                NaN
# 4             NaN               NaN           NaN                NaN
#
#                                         url_citation
# 0  http://www.sc.doe.gov/bes/reports/files/SEU_rp...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 27 columns]

# %%
df_doc_authors_citations = pd.DataFrame(get_citations_authors(doc))
df_doc_authors_citations.head()
# Out:
#    id  index                           pdf_md5 full_name_citation  \
# 0  b0      0  5B70A65B9D2AEC3DD3E6A64B4BD94CB2                NaN
# 1  b1      1  5B70A65B9D2AEC3DD3E6A64B4BD94CB2          V Balzani
# 2  b2      2  5B70A65B9D2AEC3DD3E6A64B4BD94CB2           A Hirsch
# 3  b2      2  5B70A65B9D2AEC3DD3E6A64B4BD94CB2       M Brettreich
# 4  b2      2  5B70A65B9D2AEC3DD3E6A64B4BD94CB2       : Fullerenes
#
#   given_name_citation middle_name_citation surname_citation  email_citation  \
# 0                 NaN                  NaN              NaN             NaN
# 1                   V                  NaN          Balzani             NaN
# 2                   A                  NaN           Hirsch             NaN
# 3                   M                  NaN       Brettreich             NaN
# 4                   :                  NaN       Fullerenes             NaN
#
#    orcid_citation  institution_citation  department_citation  \
# 0             NaN                   NaN                  NaN
# 1             NaN                   NaN                  NaN
# 2             NaN                   NaN                  NaN
# 3             NaN                   NaN                  NaN
# 4             NaN                   NaN                  NaN
#
#    laboratory_citation  addr_line_citation  post_code_citation  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
#    settlement_citation  country_citation
# 0                  NaN               NaN
# 1                  NaN               NaN
# 2                  NaN               NaN
# 3                  NaN               NaN
# 4                  NaN               NaN
